# %% [markdown]
# ### Libraries

# %%
import os
import numpy as np
import pandas as pd
from nitime.timeseries import TimeSeries
from nitime.analysis import SpectralAnalyzer, FilterAnalyzer, NormalizationAnalyzer
from scipy.optimize import curve_fit
from scipy.ndimage import gaussian_filter1d
from scipy.signal import butter, filtfilt

# %%
def lorentzian_function(x, s0, corner):
    return (s0*corner**2) / (x**2 + corner**2)

# %%
def multi_fractal_function(x, beta_low, beta_high, A, B, corner):
    return np.where(x < corner, A * x**beta_low, B * x**beta_high)

# %%
def bandpass_filter(data, lowcut, highcut, fs, order=4):
    """
    Apply a band-pass filter to the fMRI time-series data.

    Parameters:
    - data (numpy array): Input time-series data (1D).
    - lowcut (float): Low cutoff frequency in Hz.
    - highcut (float): High cutoff frequency in Hz.
    - fs (float): Sampling frequency (1/TR in Hz).
    - order (int): Order of the Butterworth filter.

    Returns:
    - filtered_data (numpy array): Band-pass filtered data.
    """
    nyquist = 0.5 * fs  # Nyquist frequency
    low = lowcut / nyquist
    high = highcut / nyquist
    b, a = butter(order, [low, high], btype='band')  # Band-pass filter coefficients
    filtered_data = filtfilt(b, a, data)  # Apply the filter
    return filtered_data

# %% [markdown]
# ### Calculate knee frequencies for each site

# %%
# Define the base path where the .tsv files are stored
base_path = '/pscratch/sd/p/pakmasha/MBBN_data'

# Create a dictionary to store knee values for each site
f1_dict = {}
f2_dict = {}
seq_len_dict = {}
error_count = 0

# Walk through all subdirectories and process .npy files
for root, dirs, files in os.walk(base_path):
    for file in files:
        if file.endswith('.npy') and file.split('_')[-2] != "0.01":
            # Construct full path to the .tsv file
            npy_file_path = os.path.join(root, file)
            # print(f"npy_file_path: {npy_file_path}")

            # Calculate the repetition time (TR) depending on the site
            site = file.split('_')[-2]
            if 'Amsterdam-AMC' in site:
                TR = 2.375
            elif 'Amsterdam-VUmc' in site:
                TR = 1.8
            elif 'Barcelona-HCPB' in site:
                TR = 2
            elif 'Bergen' in site:
                TR = 1.8
            elif 'Braga-UMinho-Braga-1.5T' in site:
                TR = 2
            elif 'Braga-UMinho-Braga-1.5T-act' in site:
                TR = 2
            elif 'Braga-UMinho-Braga-3T' in site:
                TR = 1
            elif 'Brazil' in site:
                TR = 2
            elif 'Cape-Town-UCT-Allegra' in site:
                TR = 1.6
            elif 'Cape-Town-UCT-Skyra' in site:
                TR = 1.73
            elif 'Chiba-CHB' in site:
                TR = 2.3
            elif 'Chiba-CHBC' in site:
                TR = 2.3 
            elif 'Chiba-CHBSRPB' in site:
                TR = 2.5 
            elif 'Dresden' in site:
                TR = 0.8 
            elif 'Kyoto-KPU-Kyoto1.5T' in site:
                TR = 2.411 
            elif 'Kyoto-KPU-Kyoto3T' in site:
                TR = 2
            elif 'Kyushu' in site:
                TR = 2.5
            elif 'Milan-HSR' in site:
                TR = 2
            elif 'New-York' in site:
                TR = 1
            elif 'NYSPI-Columbia-Adults' in site:
                TR = 0.85
            elif 'NYSPI-Columbia-Pediatric' in site:
                TR = 0.85
            elif 'Yale-Pittinger-HCP-Prisma' in site:
                TR = 0.8
            elif 'Yale-Pittinger-HCP-Trio' in site:
                TR = 0.7
            elif 'Yale-Pittinger-Yale-2014' in site:
                TR = 2
            elif 'Bangalore-NIMHANS' in site:
                TR = 2 
            elif 'Barcelone-Bellvitge-ANTIGA-1.5T' in site:
                TR = 2
            elif 'Barcelone-Bellvitge-COMPULSE-3T' in site:
                TR = 2
            elif 'Barcelone-Bellvitge-PROV-1.5T' in site:
                TR = 2
            elif 'Barcelone-Bellvitge-RESP-CBT-3T' in site:
                TR = 2
            elif 'Seoul-SNU' in site:
                TR = 3.5
            elif 'Shanghai-SMCH' in site:
                TR = 3
            elif 'UCLA' in site:
                TR = 2
            elif 'Vancouver-BCCHR' in site:
                TR = 2
            elif 'Yale-Gruner' in site:
                TR = 2
            else:
                raise ValueError(f"Site '{site}' does not have a defined TR value in TR_mappings. Please add it.")

            # Load the .npy file and calculate knee frequencies
            # sequence_length = 200
            y = np.load(npy_file_path).T
            sequence_length = y.shape[1]   # use the original number of points
            # y = y[20:20+sequence_length].T   
            # print(f"y: {y}")
            # print(f"y.shape: {y.shape}")

            try:

                sample_whole = np.zeros(sequence_length,) # originally sequence_length   ## aggregates time-series data across ROIs   # sample_whole.shape = # of timepoints,

                ##### DEBUG STATEMENT #####
                # sample_whole = np.zeros(sequence_length - 20,)
                # print(f"sample_whole.shape: {sample_whole.shape}")
                ###########################

                intermediate_vec = y.shape[0]

                for i in range(intermediate_vec):
                    # print(f"y[i] shape: {y[i].shape}")
                    sample_whole+=y[i]

                sample_whole /= intermediate_vec    # averages the time-series signals (y) across a set number of ROIs

                T = TimeSeries(sample_whole, sampling_interval=TR)  # computes power spectral density (PSD) of the averaged time-series signal
                S_original = SpectralAnalyzer(T)

                # Lorentzian function fitting (dividing ultralow ~ low)  ## extracts the PSD data
                xdata = np.array(S_original.spectrum_fourier[0][1:])  # xdata = frequency values  
                ydata = np.abs(S_original.spectrum_fourier[1][1:])    # ydata = corresponding power values
                # print(f"xdata.shape: {xdata.shape}")
                # print(f"ydata.shape: {ydata.shape}")

                # initial parameter setting
                p0 = [0, 0.006]   
                param_bounds = ([-np.inf, 0], [np.inf, 1])

                # fitting Lorentzian function
                popt, pcov = curve_fit(lorentzian_function, xdata, ydata, p0=p0, maxfev = 5000, bounds=param_bounds)   # popt = optimal parameters

                f1 = popt[1]

                knee = round(popt[1]/(1/(sample_whole.shape[0]*TR)))   # calculates knee frequency 
                # print(f"knee: {knee}")

                if knee <= 0:
                    knee = 1

                if knee > ydata.shape[0]:
                    print(f"knee value: {knee}")
                    print(f"ydata.shape: {ydata.shape}")

                # divide low ~ high
                # initial parameter setting
                p1 = [2, 1, 23, 25, 0.16]
            
                # fitting multifractal function
                popt_mo, pcov = curve_fit(multi_fractal_function, xdata[knee:], ydata[knee:], p0=p1, maxfev = 50000)   # fits a multi-fractal model to the high-frequency range (above the knee)
                pink = round(popt_mo[-1]/(1/(sample_whole.shape[0]*TR)))   # pink = an additional boundary
                f2 = popt_mo[-1]

                # Save values to the dictionaries
                # Check if the key exists in the dictionary
                if site in f1_dict:
                    # Append the value to the existing list
                    f1_dict[site].append(f1)
                    f2_dict[site].append(f2)
                    seq_len_dict[site].append(sequence_length)
                else:
                    # Create the key and initialize it with a list containing the value
                    f1_dict[site] = [f1]
                    f2_dict[site] = [f2]   
                    seq_len_dict[site] = [sequence_length] 
                print(f"Successfully processed {file}")  
            except Exception as e:
                print(f"Error processing: {file}")
                print(e)
                error_count += 1
                continue  # Skip the subject if an error occurs
            
print(f"Knee frequencies f1: {f1_dict}")
print(f"\nKnee frequencies f2: {f2_dict}")
print(f"Sequence lengths: {seq_len_dict}")
print(f"Error processing {error_count} files")
# Out:
# knee value: 122
# ydata.shape: (120,)
# Error processing: Barcelona-HCPB_sub-008.npy
# `ydata` must not be empty!
# Successfully processed Brazil_sub-C002061.npy
# Successfully processed Yale-Pittinger-HCP-Prisma_sub-YaleHCPPrismapb3225.npy
# Successfully processed Seoul-SNU_sub-NOR117CSJ.npy
# Successfully processed Dresden_sub-GEROME3073.npy
# Successfully processed Bergen_sub-00059.npy
# Successfully processed Bangalore-NIMHANS_sub-C0181.npy
# Successfully processed Bangalore-NIMHANS_sub-C0128.npy
# Error processing: Seoul-SNU_sub-DNO23LSM.npy
# The number of func parameters=5 must not exceed the number of data points=3
# Successfully processed Bangalore-NIMHANS_sub-ODP004.npy
# Successfully processed Bangalore-NIMHANS_sub-ODP203.npy
# knee value: 61
# ydata.shape: (60,)
# Error processing: Barcelone-Bellvitge-PROV-1.5T_sub-subIDIBELL15224.npy
# `ydata` must not be empty!
# /tmp/ipykernel_1421614/4188049141.py:149: OptimizeWarning: Covariance of the parameters could not be estimated
#   popt_mo, pcov = curve_fit(multi_fractal_function, xdata[knee:], ydata[knee:], p0=p1, maxfev = 50000)   # fits a multi-fractal model to the high-frequency range (above the knee)
# /tmp/ipykernel_1421614/1867528834.py:2: RuntimeWarning: overflow encountered in power
#   return np.where(x < corner, A * x**beta_low, B * x**beta_high)
# /tmp/ipykernel_1421614/1867528834.py:2: RuntimeWarning: overflow encountered in multiply
#   return np.where(x < corner, A * x**beta_low, B * x**beta_high)
# Error processing: Barcelone-Bellvitge-ANTIGA-1.5T_sub-subIDIBELL15C032.npy
# The number of func parameters=5 must not exceed the number of data points=2
# Successfully processed Bangalore-NIMHANS_sub-ODP099.npy
# Error processing: Chiba-CHB_sub-MADHC010.npy
# The number of func parameters=5 must not exceed the number of data points=3
# knee value: 249
# ydata.shape: (149,)
# Error processing: Yale-Pittinger-Yale-2014_sub-Yale2014AdultOCDtr7977.npy
# `ydata` must not be empty!
# Successfully processed Bergen_sub-00066.npy
# Successfully processed Yale-Pittinger-Yale-2014_sub-Yale2014AdultOCDtb0314.npy
# Successfully processed Barcelona-HCPB_sub-C0071.npy
# Error processing: Barcelone-Bellvitge-ANTIGA-1.5T_sub-subIDIBELL15C042.npy
# The number of func parameters=5 must not exceed the number of data points=3
# Successfully processed Barcelona-HCPB_sub-042.npy
# knee value: 67
# ydata.shape: (60,)
# Error processing: Barcelone-Bellvitge-ANTIGA-1.5T_sub-subIDIBELL15P67.npy
# `ydata` must not be empty!
# Successfully processed Braga-UMinho-Braga-3T_sub-MRI201905211BART003.npy
# Successfully processed Barcelone-Bellvitge-RESP-CBT-3T_sub-RESPCBT25CTRPOST.npy
# knee value: 83
# ydata.shape: (56,)
# Error processing: Seoul-SNU_sub-DNO39JHJ.npy
# `ydata` must not be empty!
# Successfully processed Chiba-CHBSRPB_sub-SUA004.npy
# Error processing: Seoul-SNU_sub-UMO27LCY.npy
# `ydata` must not be empty!
# Successfully processed Bangalore-NIMHANS_sub-C0234.npy
# knee value: 134
# ydata.shape: (119,)
# Error processing: Chiba-CHBSRPB_sub-MADHC054.npy
# `ydata` must not be empty!
# Successfully processed Yale-Gruner_sub-S4576MHM.npy
# Successfully processed NYSPI-Columbia-Adults_sub-simpaocd407000.npy
# Successfully processed Barcelone-Bellvitge-RESP-CBT-3T_sub-RESPCBT09CTRPRE.npy
# Successfully processed Bangalore-NIMHANS_sub-ODP241.npy
# Successfully processed Amsterdam-VUmc_sub-916088.npy
# knee value: 100
# ydata.shape: (76,)
# Error processing: Bangalore-NIMHANS_sub-ODP201.npy
# `ydata` must not be empty!
# Successfully processed Yale-Pittinger-Yale-2014_sub-Yale2014AdultOCDtr8623.npy
# Successfully processed Bangalore-NIMHANS_sub-C0052.npy
# Successfully processed Bangalore-NIMHANS_sub-ODP122.npy
# Successfully processed Barcelone-Bellvitge-PROV-1.5T_sub-subIDIBELL15215.npy
# Successfully processed NYSPI-Columbia-Adults_sub-simpaocd577000.npy
# knee value: 67
# ydata.shape: (60,)
# Error processing: Barcelone-Bellvitge-ANTIGA-1.5T_sub-subIDIBELL15C061.npy
# `ydata` must not be empty!
# Successfully processed Barcelone-Bellvitge-RESP-CBT-3T_sub-RESPCBT11CTRPRE.npy
# Successfully processed Braga-UMinho-Braga-1.5T-act_sub-MRI201211284OCD039.npy
# knee value: 598
# ydata.shape: (149,)
# Error processing: Yale-Pittinger-Yale-2014_sub-Yale2014AdultOCDtb1751.npy
# `ydata` must not be empty!
# Successfully processed Bangalore-NIMHANS_sub-C0235.npy
# Successfully processed Bangalore-NIMHANS_sub-ODP211.npy
# Successfully processed Bangalore-NIMHANS_sub-C0075.npy
# Successfully processed Chiba-CHBSRPB_sub-OCD151.npy
# Successfully processed Seoul-SNU_sub-NOR38LSJ.npy
# Successfully processed Chiba-CHBSRPB_sub-MADHC032.npy
# Successfully processed Shanghai-SMCH_sub-045.npy
# Successfully processed Chiba-CHB_sub-MADHC022.npy
# knee value: 100
# ydata.shape: (60,)
# Error processing: Barcelone-Bellvitge-PROV-1.5T_sub-subIDIBELL15C293.npy
# `ydata` must not be empty!
# Successfully processed Yale-Pittinger-Yale-2014_sub-Yale2014AdultOCDtr9380.npy
# Successfully processed Bangalore-NIMHANS_sub-C0198.npy
# knee value: 101
# ydata.shape: (98,)
# Error processing: Chiba-CHB_sub-MADHC023.npy
# `ydata` must not be empty!
# Successfully processed Cape-Town-UCT-Skyra_sub-CIMP127.npy
# Successfully processed Braga-UMinho-Braga-3T_sub-MRI201911121BART043.npy
# Successfully processed Brazil_sub-P00222720150526.npy
# Successfully processed Bangalore-NIMHANS_sub-C0093.npy
# Successfully processed NYSPI-Columbia-Pediatric_sub-KZKLJH.npy
# Successfully processed Shanghai-SMCH_sub-048.npy
# Successfully processed Braga-UMinho-Braga-1.5T-act_sub-MRI201212142OCD042.npy
# Error processing: Bergen_sub-00006.npy
# The number of func parameters=5 must not exceed the number of data points=4
# Successfully processed Braga-UMinho-Braga-1.5T_sub-MRI201503044OCD070.npy
# Successfully processed Braga-UMinho-Braga-3T_sub-MRI201908092BART018.npy
# Successfully processed Chiba-CHBSRPB_sub-MADHC090.npy
# Successfully processed Seoul-SNU_sub-NOR53PSH.npy
# knee value: 155
# ydata.shape: (149,)
# Error processing: Yale-Pittinger-Yale-2014_sub-Yale2014AdultOCDtb0806.npy
# `ydata` must not be empty!
# Successfully processed Bangalore-NIMHANS_sub-ODP002.npy
# Successfully processed Brazil_sub-P00322320170322.npy
# Successfully processed Braga-UMinho-Braga-1.5T-act_sub-MRI201701272OCD134.npy
# Successfully processed Vancouver-BCCHR_sub-027.npy
# Successfully processed Brazil_sub-P00340120170911.npy
# Successfully processed Chiba-CHBSRPB_sub-MADHC063.npy
# Successfully processed Bangalore-NIMHANS_sub-C0164.npy
# knee value: 303
# ydata.shape: (56,)
# Error processing: Seoul-SNU_sub-NOR59KDW.npy
# `ydata` must not be empty!
# Successfully processed Braga-UMinho-Braga-3T_sub-MRI201911151BART045.npy
# Successfully processed Bangalore-NIMHANS_sub-ODP008.npy
# knee value: 82
# ydata.shape: (60,)
# Error processing: Barcelone-Bellvitge-PROV-1.5T_sub-subIDIBELL15250.npy
# `ydata` must not be empty!
# Successfully processed Brazil_sub-P00326620170509.npy
# Successfully processed Yale-Pittinger-HCP-Prisma_sub-YaleHCPPrismapb3003.npy
# Successfully processed Bergen_sub-00056.npy
# Successfully processed Barcelone-Bellvitge-RESP-CBT-3T_sub-RESPCBT18CTRPRE.npy
# Successfully processed Bangalore-NIMHANS_sub-ODP058.npy
# Successfully processed New-York_sub-subSEQ1NKISENR140.npy
# Successfully processed Kyoto-KPU-Kyoto1.5T_sub-subKyoto15Tsubj1033.npy
# Successfully processed Bangalore-NIMHANS_sub-ODP164.npy
# Successfully processed Braga-UMinho-Braga-1.5T-act_sub-MRI201505202OCD075.npy
# Successfully processed Amsterdam-VUmc_sub-916025.npy
# Successfully processed Bangalore-NIMHANS_sub-C0074.npy
# Successfully processed NYSPI-Columbia-Adults_sub-simpaocd517000.npy
# knee value: 221
# ydata.shape: (76,)
# Error processing: Bangalore-NIMHANS_sub-C0049.npy
# `ydata` must not be empty!
# Successfully processed Amsterdam-VUmc_sub-916007.npy
# Successfully processed Kyoto-KPU-Kyoto3T_sub-subKyoto3Tsubj1007.npy
# Successfully processed Chiba-CHBSRPB_sub-MADHC027.npy
# Successfully processed Bangalore-NIMHANS_sub-ODP118.npy
# Successfully processed Braga-UMinho-Braga-1.5T_sub-MRI201510072OCD097.npy
# Successfully processed Yale-Pittinger-HCP-Trio_sub-YaleHCPTriota6327.npy
# knee value: 113
# ydata.shape: (75,)
# Error processing: Yale-Gruner_sub-S0214HUM.npy
# `ydata` must not be empty!
# Successfully processed Bangalore-NIMHANS_sub-C0156.npy
# Successfully processed NYSPI-Columbia-Pediatric_sub-ZFIGFT.npy
# knee value: 217
# ydata.shape: (149,)
# Error processing: Yale-Pittinger-Yale-2014_sub-Yale2014AdultOCDtr8123.npy
# `ydata` must not be empty!
# Successfully processed Barcelona-HCPB_sub-C0069.npy
# knee value: 90
# ydata.shape: (85,)
# Error processing: Shanghai-SMCH_sub-009.npy
# `ydata` must not be empty!
# Successfully processed Chiba-CHB_sub-OCD096.npy
# Successfully processed Brazil_sub-P00196820141124.npy
# knee value: 143
# ydata.shape: (98,)
# Error processing: Amsterdam-VUmc_sub-916052.npy
# `ydata` must not be empty!
# Successfully processed Vancouver-BCCHR_sub-014.npy
# Successfully processed Shanghai-SMCH_sub-030.npy
# knee value: 122
# ydata.shape: (120,)
# Error processing: Barcelone-Bellvitge-RESP-CBT-3T_sub-RESPCBT08CTRPRE.npy
# `ydata` must not be empty!
# Successfully processed Seoul-SNU_sub-NOR71HRK.npy
# Successfully processed UCLA_sub-AOCD008.npy
# knee value: 148
# ydata.shape: (76,)
# Error processing: Bangalore-NIMHANS_sub-C0137.npy
# `ydata` must not be empty!
# Successfully processed NYSPI-Columbia-Adults_sub-simpaocd317000.npy
# Successfully processed Yale-Pittinger-Yale-2014_sub-Yale2014AdultOCDtr8740.npy
# Successfully processed Barcelona-HCPB_sub-C0087.npy
# Successfully processed Bangalore-NIMHANS_sub-ODP156.npy
# knee value: 77
# ydata.shape: (76,)
# Error processing: Bangalore-NIMHANS_sub-ODP159.npy
# `ydata` must not be empty!
# Successfully processed Bangalore-NIMHANS_sub-C0151.npy
# knee value: 116
# ydata.shape: (97,)
# Error processing: Kyoto-KPU-Kyoto1.5T_sub-subKyoto15Tsubj1050.npy
# `ydata` must not be empty!
# Successfully processed Barcelone-Bellvitge-RESP-CBT-3T_sub-RESPCBT28CTRPOST.npy
# Successfully processed Barcelone-Bellvitge-ANTIGA-1.5T_sub-subIDIBELL15C019.npy
# knee value: 167
# ydata.shape: (119,)
# Error processing: Chiba-CHBSRPB_sub-MADHC056.npy
# `ydata` must not be empty!
# Successfully processed Amsterdam-VUmc_sub-916027.npy
# Successfully processed Yale-Pittinger-Yale-2014_sub-Yale2014AdultOCDtb1917.npy
# Successfully processed Barcelone-Bellvitge-ANTIGA-1.5T_sub-subIDIBELL15C051.npy
# Successfully processed Yale-Gruner_sub-S1163AET.npy
# Successfully processed Vancouver-BCCHR_sub-038.npy
# Successfully processed Bergen_sub-00060.npy
# Successfully processed Cape-Town-UCT-Skyra_sub-CIMP114.npy
# Successfully processed Shanghai-SMCH_sub-006.npy
# Successfully processed Bergen_sub-00076.npy
# Successfully processed Chiba-CHBSRPB_sub-OCD134.npy
# Successfully processed Kyoto-KPU-Kyoto3T_sub-subKyoto3Tsubj1042.npy
# Successfully processed Braga-UMinho-Braga-1.5T-act_sub-MRI201306132OCD065.npy
# Successfully processed Bangalore-NIMHANS_sub-C0073.npy
# Successfully processed Dresden_sub-GEROME3028.npy
# knee value: 82
# ydata.shape: (76,)
# Error processing: Bangalore-NIMHANS_sub-ODP017.npy
# `ydata` must not be empty!
# Successfully processed Vancouver-BCCHR_sub-066.npy
# Successfully processed UCLA_sub-AOCD052.npy
# Successfully processed Seoul-SNU_sub-UMO03KHK.npy
# Successfully processed Barcelona-HCPB_sub-036.npy
# knee value: 156
# ydata.shape: (149,)
# Error processing: Yale-Pittinger-Yale-2014_sub-Yale2014AdultOCDtr8240.npy
# `ydata` must not be empty!
# Successfully processed Yale-Pittinger-HCP-Trio_sub-YaleHCPTriota6591.npy
# Successfully processed Bangalore-NIMHANS_sub-C0108.npy
# knee value: 101
# ydata.shape: (76,)
# Error processing: Bangalore-NIMHANS_sub-ODP057.npy
# `ydata` must not be empty!
# knee value: 158
# ydata.shape: (149,)
# Error processing: Yale-Pittinger-Yale-2014_sub-Yale2014AdultOCDtb2073.npy
# `ydata` must not be empty!
# Successfully processed Barcelone-Bellvitge-ANTIGA-1.5T_sub-subIDIBELL15P01.npy
# Successfully processed Chiba-CHBSRPB_sub-MADHC092.npy
# Successfully processed Braga-UMinho-Braga-1.5T-act_sub-MRI201304172OCD050.npy
# Successfully processed Yale-Pittinger-HCP-Prisma_sub-YaleHCPPrismapb4059.npy
# Successfully processed Bangalore-NIMHANS_sub-C0129.npy
# knee value: 187
# ydata.shape: (149,)
# Error processing: Yale-Pittinger-Yale-2014_sub-Yale2014AdultOCDtb0963.npy
# `ydata` must not be empty!
# Successfully processed Cape-Town-UCT-Skyra_sub-ESC0102.npy
# Successfully processed Seoul-SNU_sub-UMO05HSH.npy
# Successfully processed Chiba-CHBC_sub-HCC003.npy
# knee value: 61
# ydata.shape: (56,)
# Error processing: Seoul-SNU_sub-UMO14PMY.npy
# `ydata` must not be empty!
# knee value: 77
# ydata.shape: (65,)
# Error processing: Brazil_sub-P00240220150831.npy
# `ydata` must not be empty!
# Successfully processed Bangalore-NIMHANS_sub-ODP033.npy
# Successfully processed Bangalore-NIMHANS_sub-C0174.npy
# Successfully processed Braga-UMinho-Braga-3T_sub-MRI201909021BART027.npy
# Successfully processed Chiba-CHBSRPB_sub-MADHC034.npy
# Successfully processed Amsterdam-VUmc_sub-916069.npy
# Successfully processed Yale-Gruner_sub-S4662IIP.npy
# Successfully processed Bangalore-NIMHANS_sub-C0091.npy
# Successfully processed Yale-Pittinger-HCP-Trio_sub-YaleHCPTriopb4304.npy
# Successfully processed Barcelone-Bellvitge-RESP-CBT-3T_sub-RESPCBT26CTRPOST.npy
# Successfully processed Bangalore-NIMHANS_sub-C0202.npy
# Successfully processed Kyoto-KPU-Kyoto3T_sub-subKyoto3Tsubj0017.npy
# Successfully processed Braga-UMinho-Braga-1.5T-act_sub-MRI201305062OCD053.npy
# Successfully processed Brazil_sub-P00328420170524.npy
# Successfully processed Braga-UMinho-Braga-1.5T-act_sub-MRI201207204OCD011.npy
# Successfully processed Bangalore-NIMHANS_sub-ODP015.npy
# Successfully processed Yale-Gruner_sub-S1110MWI.npy
# Successfully processed Yale-Pittinger-HCP-Prisma_sub-YaleHCPPrismapb2235.npy
# Successfully processed Shanghai-SMCH_sub-095.npy
# Error processing: Brazil_sub-P00297220160823.npy
# The number of func parameters=5 must not exceed the number of data points=3
# Successfully processed Yale-Gruner_sub-S0827JSA.npy
# Successfully processed Bangalore-NIMHANS_sub-ODP251.npy
# knee value: 74
# ydata.shape: (60,)
# Error processing: Barcelone-Bellvitge-ANTIGA-1.5T_sub-subIDIBELL15P70.npy
# `ydata` must not be empty!
# Successfully processed Bangalore-NIMHANS_sub-C0051.npy
# knee value: 69
# ydata.shape: (60,)
# Error processing: Barcelone-Bellvitge-ANTIGA-1.5T_sub-subIDIBELL15C015.npy
# `ydata` must not be empty!
# Successfully processed Bergen_sub-00008.npy
# Successfully processed Bangalore-NIMHANS_sub-ODP197.npy
# Successfully processed Braga-UMinho-Braga-3T_sub-MRI202002211BART053.npy
# Successfully processed Yale-Pittinger-Yale-2014_sub-Yale2014AdultOCDtb0650.npy
# Successfully processed Chiba-CHBSRPB_sub-MADHC042.npy
# Successfully processed UCLA_sub-AOCD074.npy
# Successfully processed Cape-Town-UCT-Skyra_sub-CIMP115.npy
# Successfully processed NYSPI-Columbia-Pediatric_sub-MYFIWQ.npy
# knee value: 156
# ydata.shape: (151,)
# Error processing: Bangalore-NIMHANS_sub-ODP235.npy
# `ydata` must not be empty!
# Successfully processed Chiba-CHBC_sub-OCDC039.npy
# Successfully processed Barcelone-Bellvitge-ANTIGA-1.5T_sub-subIDIBELL15C029.npy
# Successfully processed Amsterdam-VUmc_sub-916071.npy
# Successfully processed Kyoto-KPU-Kyoto3T_sub-subKyoto3Tsubj1035.npy
# Successfully processed Bangalore-NIMHANS_sub-C0153.npy
# Error processing: Bangalore-NIMHANS_sub-C0176.npy
# The number of func parameters=5 must not exceed the number of data points=4
# Successfully processed New-York_sub-subSEQ1NKISENR162.npy
# knee value: 487
# ydata.shape: (119,)
# Error processing: Chiba-CHBSRPB_sub-MADHC093.npy
# `ydata` must not be empty!
# Error processing: Chiba-CHBC_sub-HCC027.npy
# The number of func parameters=5 must not exceed the number of data points=2
# Successfully processed Bangalore-NIMHANS_sub-ODP007.npy
# Successfully processed Barcelone-Bellvitge-PROV-1.5T_sub-subIDIBELL15271.npy
# Successfully processed Barcelone-Bellvitge-RESP-CBT-3T_sub-RESPCBT03OCDPRE.npy
# Successfully processed Brazil_sub-C001747.npy
# Successfully processed Barcelone-Bellvitge-RESP-CBT-3T_sub-RESPCBT16CTRPRE.npy
# Successfully processed Vancouver-BCCHR_sub-070.npy
# Successfully processed Bangalore-NIMHANS_sub-ODP215.npy
# Error processing: Yale-Pittinger-Yale-2014_sub-Yale2014AdultOCDtr8222.npy
# `ydata` must not be empty!
# knee value: 100
# ydata.shape: (85,)
# Error processing: Shanghai-SMCH_sub-094.npy
# `ydata` must not be empty!
# Successfully processed Barcelone-Bellvitge-ANTIGA-1.5T_sub-subIDIBELL15C109.npy
# Successfully processed Bangalore-NIMHANS_sub-ODP083.npy
# Successfully processed Yale-Pittinger-HCP-Prisma_sub-YaleHCPPrismapb7364.npy
# Successfully processed Yale-Pittinger-HCP-Trio_sub-YaleHCPTriota7283.npy
# Successfully processed Bangalore-NIMHANS_sub-C0187.npy
# Error processing: Barcelone-Bellvitge-ANTIGA-1.5T_sub-subIDIBELL15C001.npy
# `ydata` must not be empty!
# Successfully processed Yale-Gruner_sub-S4347UXK.npy
# Successfully processed Barcelone-Bellvitge-PROV-1.5T_sub-subIDIBELL15C311.npy
# knee value: 99
# ydata.shape: (90,)
# Error processing: Braga-UMinho-Braga-1.5T-act_sub-MRI201406022OCD068.npy
# `ydata` must not be empty!
# Successfully processed Yale-Pittinger-Yale-2014_sub-Yale2014AdultOCDtr8345.npy
# Successfully processed Chiba-CHBSRPB_sub-MADHC051.npy
# Successfully processed Barcelone-Bellvitge-ANTIGA-1.5T_sub-subIDIBELL15P46.npy
# knee value: 138
# ydata.shape: (85,)
# Error processing: Shanghai-SMCH_sub-091.npy
# `ydata` must not be empty!
# Successfully processed UCLA_sub-AOCD046.npy
# Successfully processed Shanghai-SMCH_sub-096.npy
# Successfully processed Cape-Town-UCT-Skyra_sub-CT02.npy
# Successfully processed Cape-Town-UCT-Skyra_sub-ESCO108.npy
# Successfully processed Yale-Pittinger-HCP-Prisma_sub-YaleHCPPrismapb4591.npy
# Successfully processed Bangalore-NIMHANS_sub-C0081.npy
# Successfully processed Shanghai-SMCH_sub-056.npy
# Successfully processed Seoul-SNU_sub-UMO59KDH.npy
# Successfully processed Barcelone-Bellvitge-PROV-1.5T_sub-subIDIBELL15254.npy
# knee value: 84
# ydata.shape: (76,)
# Error processing: Bangalore-NIMHANS_sub-C0094.npy
# `ydata` must not be empty!
# knee value: 82
# ydata.shape: (75,)
# Error processing: Yale-Gruner_sub-S1446WTO.npy
# `ydata` must not be empty!
# Error processing: Barcelone-Bellvitge-ANTIGA-1.5T_sub-subIDIBELL15P21.npy
# The number of func parameters=5 must not exceed the number of data points=4
# Successfully processed Amsterdam-VUmc_sub-916014.npy
# Successfully processed Bangalore-NIMHANS_sub-C0066.npy
# Successfully processed Yale-Pittinger-Yale-2014_sub-Yale2014AdultOCDtb1680.npy
# knee value: 64
# ydata.shape: (60,)
# Error processing: Barcelone-Bellvitge-PROV-1.5T_sub-subIDIBELL15207.npy
# `ydata` must not be empty!
# Successfully processed Barcelone-Bellvitge-PROV-1.5T_sub-subIDIBELL15C296.npy
# Successfully processed Bangalore-NIMHANS_sub-ODP054.npy
# Successfully processed Braga-UMinho-Braga-3T_sub-MRI201906181BART011.npy
# Successfully processed Barcelone-Bellvitge-ANTIGA-1.5T_sub-subIDIBELL15P25.npy
# Successfully processed Amsterdam-VUmc_sub-916037.npy
# knee value: 89
# ydata.shape: (75,)
# Error processing: Vancouver-BCCHR_sub-031.npy
# `ydata` must not be empty!
# Successfully processed Bangalore-NIMHANS_sub-ODP243.npy
# Successfully processed Kyoto-KPU-Kyoto1.5T_sub-subKyoto15Tsubj0132.npy
# Successfully processed Amsterdam-VUmc_sub-916085.npy
# Successfully processed Cape-Town-UCT-Skyra_sub-CIMP078.npy
# Successfully processed Braga-UMinho-Braga-3T_sub-MRI202009221BART064.npy
# Successfully processed Brazil_sub-C001866.npy
# Successfully processed NYSPI-Columbia-Adults_sub-simpaocd87000.npy
# Successfully processed Barcelona-HCPB_sub-C0070.npy
# Successfully processed New-York_sub-subSEQ1NKISENR131.npy
# knee value: 97
# ydata.shape: (76,)
# Error processing: Bangalore-NIMHANS_sub-C0152.npy
# `ydata` must not be empty!
# Successfully processed NYSPI-Columbia-Adults_sub-simpaocd267000.npy
# Successfully processed Braga-UMinho-Braga-1.5T-act_sub-MRI201307312CogTD016.npy
# knee value: 122
# ydata.shape: (76,)
# Error processing: Bangalore-NIMHANS_sub-C0159.npy
# `ydata` must not be empty!
# Successfully processed Chiba-CHBSRPB_sub-OCD152.npy
# Successfully processed Kyoto-KPU-Kyoto3T_sub-subKyoto3Tsubj0036.npy
# Successfully processed NYSPI-Columbia-Adults_sub-simpaocd167000.npy
# Successfully processed Braga-UMinho-Braga-1.5T-act_sub-MRI201208034OCD019.npy
# Successfully processed Bangalore-NIMHANS_sub-C0165.npy
# Successfully processed Cape-Town-UCT-Skyra_sub-CIMP141.npy
# knee value: 258
# ydata.shape: (104,)
# Error processing: UCLA_sub-AOCD068.npy
# `ydata` must not be empty!
# Successfully processed Dresden_sub-GEROME4016.npy
# Successfully processed Barcelone-Bellvitge-PROV-1.5T_sub-subIDIBELL15277.npy
# Successfully processed Cape-Town-UCT-Skyra_sub-CIMP149.npy
# Successfully processed Barcelone-Bellvitge-PROV-1.5T_sub-subIDIBELL15262.npy
# Successfully processed Yale-Pittinger-HCP-Trio_sub-YaleHCPTriota7832.npy
# Successfully processed Bangalore-NIMHANS_sub-C0126.npy
# knee value: 222
# ydata.shape: (75,)
# Error processing: Yale-Gruner_sub-S2470VCI.npy
# `ydata` must not be empty!
# Successfully processed Yale-Pittinger-HCP-Trio_sub-YaleHCPTriota7806.npy
# Successfully processed Bangalore-NIMHANS_sub-ODP209.npy
# Successfully processed Dresden_sub-GEROME3042.npy
# knee value: 114
# ydata.shape: (85,)
# Error processing: Shanghai-SMCH_sub-072.npy
# `ydata` must not be empty!
# knee value: 127
# ydata.shape: (120,)
# Error processing: Barcelona-HCPB_sub-C0053.npy
# `ydata` must not be empty!
# Successfully processed Braga-UMinho-Braga-1.5T-act_sub-MRI201506083OCD080.npy
# Successfully processed Barcelone-Bellvitge-ANTIGA-1.5T_sub-subIDIBELL15P52.npy
# Successfully processed Bangalore-NIMHANS_sub-C0182.npy
# knee value: 121
# ydata.shape: (104,)
# Error processing: UCLA_sub-AOCD061.npy
# `ydata` must not be empty!
# Successfully processed Yale-Pittinger-Yale-2014_sub-Yale2014AdultOCDtb0639.npy
# Successfully processed Bangalore-NIMHANS_sub-C0141.npy
# knee value: 157
# ydata.shape: (119,)
# Error processing: Chiba-CHBSRPB_sub-OCD139.npy
# `ydata` must not be empty!
# Successfully processed Shanghai-SMCH_sub-025.npy
# Successfully processed NYSPI-Columbia-Adults_sub-simpaocd567000.npy
# Successfully processed Chiba-CHB_sub-MADHC008.npy
# Successfully processed Barcelone-Bellvitge-RESP-CBT-3T_sub-RESPCBT05CTRPRE.npy
# Successfully processed Kyoto-KPU-Kyoto3T_sub-subKyoto3Tsubj1017.npy
# Successfully processed Braga-UMinho-Braga-1.5T-act_sub-MRI201603235OCD124.npy
# Successfully processed NYSPI-Columbia-Pediatric_sub-UAQEKH.npy
# Successfully processed Brazil_sub-P00184120140908.npy
# Successfully processed Barcelona-HCPB_sub-028.npy
# knee value: 153
# ydata.shape: (151,)
# Error processing: Bangalore-NIMHANS_sub-C0225.npy
# `ydata` must not be empty!
# Successfully processed Yale-Pittinger-HCP-Prisma_sub-YaleHCPPrismapb1759.npy
# Successfully processed Bangalore-NIMHANS_sub-ODP026.npy
# Error processing: Bangalore-NIMHANS_sub-ODP071.npy
# Improper input: func input vector length N=5 must not exceed func output vector length M=1
# Successfully processed Seoul-SNU_sub-UMO15KHJ.npy
# Successfully processed NYSPI-Columbia-Adults_sub-simpaocd227000.npy
# Successfully processed Kyoto-KPU-Kyoto1.5T_sub-subKyoto15Tsubj0141.npy
# Successfully processed Bergen_sub-00028.npy
# Successfully processed Braga-UMinho-Braga-1.5T-act_sub-MRI201306121OCD064.npy
# Successfully processed Bangalore-NIMHANS_sub-C0103.npy
# Successfully processed Amsterdam-VUmc_sub-916011.npy
# Successfully processed Amsterdam-VUmc_sub-916019.npy
# Successfully processed Bangalore-NIMHANS_sub-C0047.npy
# Successfully processed Kyoto-KPU-Kyoto3T_sub-subKyoto3Tsubj0006.npy
# Successfully processed Kyoto-KPU-Kyoto3T_sub-subKyoto3Tsubj1041.npy
# knee value: 83
# ydata.shape: (60,)
# Error processing: Barcelone-Bellvitge-PROV-1.5T_sub-subIDIBELL15216.npy
# `ydata` must not be empty!
# Successfully processed Bangalore-NIMHANS_sub-ODP076.npy
# Successfully processed Brazil_sub-P00331820170705.npy
# Successfully processed NYSPI-Columbia-Adults_sub-simpaocd337000.npy
# Successfully processed New-York_sub-subSEQ1NKISENR144.npy
# Successfully processed New-York_sub-subSEQ1NKISENR122.npy
# knee value: 136
# ydata.shape: (60,)
# Error processing: Barcelone-Bellvitge-ANTIGA-1.5T_sub-subIDIBELL15P07.npy
# `ydata` must not be empty!
# Successfully processed Yale-Pittinger-HCP-Prisma_sub-YaleHCPPrismapb1020.npy
# Successfully processed Barcelone-Bellvitge-RESP-CBT-3T_sub-RESPCBT17CTRPRE.npy
# knee value: 179
# ydata.shape: (56,)
# Error processing: Seoul-SNU_sub-UMO63KSY.npy
# `ydata` must not be empty!
# knee value: 94
# ydata.shape: (76,)
# Error processing: Bangalore-NIMHANS_sub-ODP196.npy
# `ydata` must not be empty!
# Successfully processed Cape-Town-UCT-Skyra_sub-ESC030.npy
# knee value: 71
# ydata.shape: (65,)
# Error processing: Brazil_sub-P00247120151005.npy
# `ydata` must not be empty!
# Successfully processed Barcelone-Bellvitge-PROV-1.5T_sub-subIDIBELL15249.npy
# Successfully processed Chiba-CHBC_sub-OCDC057.npy
# Successfully processed NYSPI-Columbia-Pediatric_sub-WDFIFG.npy
# Successfully processed Chiba-CHBSRPB_sub-MADHC045.npy
# knee value: 65
# ydata.shape: (60,)
# Error processing: Barcelone-Bellvitge-PROV-1.5T_sub-subIDIBELL15201.npy
# `ydata` must not be empty!
# Successfully processed Yale-Pittinger-Yale-2014_sub-Yale2014AdultOCDtr9515.npy
# Successfully processed New-York_sub-subSEQ1NKISENR173.npy
# Successfully processed Kyoto-KPU-Kyoto1.5T_sub-subKyoto15Tsubj1039.npy
# Successfully processed UCLA_sub-AOCD025.npy
# Successfully processed Bangalore-NIMHANS_sub-C0130.npy
# Successfully processed Braga-UMinho-Braga-1.5T_sub-MRI201508122OCD087.npy
# Successfully processed Bangalore-NIMHANS_sub-ODP233.npy
# knee value: 141
# ydata.shape: (76,)
# Error processing: Bangalore-NIMHANS_sub-ODP025.npy
# `ydata` must not be empty!
# Successfully processed Barcelona-HCPB_sub-023.npy
# Successfully processed NYSPI-Columbia-Adults_sub-simpaocd507000.npy
# knee value: 126
# ydata.shape: (120,)
# Error processing: Barcelona-HCPB_sub-103.npy
# `ydata` must not be empty!
# knee value: 183
# ydata.shape: (151,)
# Error processing: Bangalore-NIMHANS_sub-C0220.npy
# `ydata` must not be empty!
# Successfully processed Braga-UMinho-Braga-1.5T-act_sub-MRI201602051OCD112.npy
# Successfully processed Dresden_sub-GEROME3064.npy
# Successfully processed Brazil_sub-C001583.npy
# Successfully processed Bergen_sub-00041.npy
# Successfully processed Kyoto-KPU-Kyoto3T_sub-subKyoto3Tsubj0007.npy
# Successfully processed Bergen_sub-00035.npy
# Successfully processed Seoul-SNU_sub-NOR56YIW.npy
# Successfully processed Yale-Gruner_sub-S7623ASD.npy
# knee value: 121
# ydata.shape: (120,)
# Error processing: Barcelone-Bellvitge-RESP-CBT-3T_sub-RESPCBT23CTRPRE.npy
# `ydata` must not be empty!
# Successfully processed Shanghai-SMCH_sub-008.npy
# Error processing: Bangalore-NIMHANS_sub-C0177.npy
# The number of func parameters=5 must not exceed the number of data points=3
# Successfully processed Yale-Pittinger-Yale-2014_sub-Yale2014AdultOCDtr7868.npy
# Successfully processed Barcelona-HCPB_sub-062.npy
# Successfully processed Vancouver-BCCHR_sub-033.npy
# Successfully processed Chiba-CHBC_sub-HCC020.npy
# Error processing: UCLA_sub-AOCD024.npy
# The number of func parameters=5 must not exceed the number of data points=4
# Successfully processed Bangalore-NIMHANS_sub-ODP064.npy
# Successfully processed Seoul-SNU_sub-NOR51CBD.npy
# Successfully processed Braga-UMinho-Braga-3T_sub-MRI201911051BART040.npy
# knee value: 99
# ydata.shape: (65,)
# Error processing: Brazil_sub-P00356020180529.npy
# `ydata` must not be empty!
# Successfully processed Braga-UMinho-Braga-3T_sub-MRI202006191BART055.npy
# Successfully processed Brazil_sub-P00330820170628.npy
# Successfully processed NYSPI-Columbia-Adults_sub-simpaocd717000.npy
# Successfully processed Cape-Town-UCT-Skyra_sub-ESCO66.npy
# knee value: 105
# ydata.shape: (98,)
# Error processing: Amsterdam-VUmc_sub-916076.npy
# `ydata` must not be empty!
# Successfully processed Vancouver-BCCHR_sub-023.npy
# Successfully processed Bangalore-NIMHANS_sub-C0133.npy
# Successfully processed New-York_sub-subSEQ1NKISENR110.npy
# Successfully processed Vancouver-BCCHR_sub-029.npy
# Successfully processed Vancouver-BCCHR_sub-044.npy
# Successfully processed Chiba-CHBSRPB_sub-MADHC060.npy
# knee value: 77
# ydata.shape: (60,)
# Error processing: Barcelone-Bellvitge-ANTIGA-1.5T_sub-subIDIBELL15C078.npy
# `ydata` must not be empty!
# knee value: 65
# ydata.shape: (60,)
# Error processing: Barcelone-Bellvitge-ANTIGA-1.5T_sub-subIDIBELL15P47.npy
# `ydata` must not be empty!
# Successfully processed Brazil_sub-C001419.npy
# knee value: 107
# ydata.shape: (76,)
# Error processing: Bangalore-NIMHANS_sub-ODP139.npy
# `ydata` must not be empty!
# knee value: 74
# ydata.shape: (65,)
# Error processing: Brazil_sub-P00348920180306.npy
# `ydata` must not be empty!
# Successfully processed Braga-UMinho-Braga-3T_sub-MRI202007101BART059.npy
# Successfully processed Shanghai-SMCH_sub-075.npy
# Successfully processed Shanghai-SMCH_sub-001.npy
# Successfully processed Bangalore-NIMHANS_sub-ODP166.npy
# Successfully processed Bangalore-NIMHANS_sub-ODP238.npy
# Successfully processed Barcelone-Bellvitge-ANTIGA-1.5T_sub-subIDIBELL15C080.npy
# Successfully processed Braga-UMinho-Braga-1.5T-act_sub-MRI201307241CogTD008.npy
# Successfully processed New-York_sub-subSEQ1NKISENR92.npy
# knee value: 180
# ydata.shape: (75,)
# Error processing: Vancouver-BCCHR_sub-026.npy
# `ydata` must not be empty!
# knee value: 89
# ydata.shape: (76,)
# Error processing: Bangalore-NIMHANS_sub-C0036.npy
# `ydata` must not be empty!
# Successfully processed Barcelona-HCPB_sub-C0056.npy
# knee value: 107
# ydata.shape: (104,)
# Error processing: UCLA_sub-AOCD051.npy
# `ydata` must not be empty!
# Successfully processed Amsterdam-VUmc_sub-916038.npy
# Successfully processed NYSPI-Columbia-Adults_sub-simpaocd287000.npy
# Successfully processed Chiba-CHBSRPB_sub-MADHC053.npy
# Successfully processed Yale-Pittinger-HCP-Trio_sub-YaleHCPTriota6499.npy
# Successfully processed Bangalore-NIMHANS_sub-C0175.npy
# Successfully processed Shanghai-SMCH_sub-074.npy
# Successfully processed Shanghai-SMCH_sub-023.npy
# Successfully processed Yale-Pittinger-HCP-Trio_sub-YaleHCPTriota7654.npy
# Successfully processed Braga-UMinho-Braga-1.5T-act_sub-MRI201611021OCD129.npy
# Successfully processed Barcelone-Bellvitge-ANTIGA-1.5T_sub-subIDIBELL15C103.npy
# Successfully processed Bergen_sub-00004.npy
# Successfully processed Barcelone-Bellvitge-ANTIGA-1.5T_sub-subIDIBELL15P64.npy
# Successfully processed Bangalore-NIMHANS_sub-C0018.npy
# knee value: 101
# ydata.shape: (98,)
# Error processing: Amsterdam-VUmc_sub-916005.npy
# `ydata` must not be empty!
# Successfully processed Vancouver-BCCHR_sub-040.npy
# Successfully processed NYSPI-Columbia-Pediatric_sub-NYCLJH.npy
# knee value: 62
# ydata.shape: (56,)
# Error processing: Seoul-SNU_sub-NOR112YIS.npy
# `ydata` must not be empty!
# Successfully processed Brazil_sub-C001922.npy
# Successfully processed Bangalore-NIMHANS_sub-ODP232.npy
# Successfully processed Yale-Pittinger-HCP-Trio_sub-YaleHCPTriota6558.npy
# Successfully processed Chiba-CHB_sub-MADHC024.npy
# Successfully processed NYSPI-Columbia-Pediatric_sub-JCHOOH.npy
# Successfully processed Yale-Pittinger-Yale-2014_sub-Yale2014AdultOCDtr9561.npy
# Successfully processed Braga-UMinho-Braga-1.5T-act_sub-MRI201510093OCD099.npy
# Successfully processed Cape-Town-UCT-Skyra_sub-CT09.npy
# Successfully processed Yale-Pittinger-HCP-Prisma_sub-YaleHCPPrismapb7552.npy
# Successfully processed Bangalore-NIMHANS_sub-C0024.npy
# Successfully processed Bangalore-NIMHANS_sub-C0201.npy
# knee value: 72
# ydata.shape: (65,)
# Error processing: Brazil_sub-P00309620161127.npy
# `ydata` must not be empty!
# Successfully processed NYSPI-Columbia-Pediatric_sub-QOGWEC.npy
# Successfully processed Barcelone-Bellvitge-PROV-1.5T_sub-subIDIBELL15C307.npy
# Successfully processed Bangalore-NIMHANS_sub-C0096.npy
# Successfully processed UCLA_sub-AOCD015.npy
# knee value: 92
# ydata.shape: (56,)
# Error processing: Seoul-SNU_sub-NOR40LJH.npy
# `ydata` must not be empty!
# Successfully processed Brazil_sub-C002014.npy
# Successfully processed New-York_sub-subSEQ1NKISENR168.npy
# knee value: 95
# ydata.shape: (85,)
# Error processing: Shanghai-SMCH_sub-052.npy
# `ydata` must not be empty!
# Successfully processed Chiba-CHBC_sub-HCC033.npy
# Successfully processed Shanghai-SMCH_sub-079.npy
# Successfully processed Braga-UMinho-Braga-1.5T_sub-MRI201510213OCD102.npy
# Successfully processed Braga-UMinho-Braga-1.5T-act_sub-MRI201302152OCD044.npy
# Successfully processed Seoul-SNU_sub-NOR91SJY.npy
# Successfully processed Barcelone-Bellvitge-ANTIGA-1.5T_sub-subIDIBELL15P19.npy
# knee value: 100
# ydata.shape: (97,)
# Error processing: Kyoto-KPU-Kyoto3T_sub-subKyoto3Tsubj1012.npy
# `ydata` must not be empty!
# Successfully processed Bangalore-NIMHANS_sub-C0069.npy
# knee value: 97
# ydata.shape: (76,)
# Error processing: Bangalore-NIMHANS_sub-C0079.npy
# `ydata` must not be empty!
# knee value: 97
# ydata.shape: (90,)
# Error processing: Braga-UMinho-Braga-1.5T_sub-MRI201407143CogTD037.npy
# `ydata` must not be empty!
# Successfully processed Barcelone-Bellvitge-ANTIGA-1.5T_sub-subIDIBELL15C077.npy
# knee value: 130
# ydata.shape: (65,)
# Error processing: Brazil_sub-C001437.npy
# `ydata` must not be empty!
# Successfully processed UCLA_sub-AOCD073.npy
# Successfully processed Yale-Gruner_sub-S3416QTW.npy
# Successfully processed Bangalore-NIMHANS_sub-C0014.npy
# Successfully processed Bangalore-NIMHANS_sub-C0037.npy
# Successfully processed Kyoto-KPU-Kyoto3T_sub-subKyoto3Tsubj1010.npy
# Successfully processed NYSPI-Columbia-Pediatric_sub-ESULIA.npy
# Successfully processed Bangalore-NIMHANS_sub-ODP124.npy
# Successfully processed Braga-UMinho-Braga-1.5T-act_sub-MRI201310142CogTD030.npy
# Successfully processed Amsterdam-VUmc_sub-916022.npy
# Successfully processed Cape-Town-UCT-Skyra_sub-ESC074.npy
# Successfully processed Yale-Pittinger-Yale-2014_sub-Yale2014AdultOCDtr7917.npy
# Successfully processed Yale-Pittinger-HCP-Prisma_sub-YaleHCPPrismapb1648.npy
# Successfully processed Dresden_sub-GEROME3026.npy
# Successfully processed Shanghai-SMCH_sub-071.npy
# Successfully processed Chiba-CHB_sub-OCD090.npy
# Successfully processed Braga-UMinho-Braga-1.5T-act_sub-MRI201612091OCD133.npy
# knee value: 94
# ydata.shape: (90,)
# Error processing: Braga-UMinho-Braga-1.5T_sub-MRI201503043OCD069.npy
# `ydata` must not be empty!
# knee value: 127
# ydata.shape: (65,)
# Error processing: Brazil_sub-P00198320141201.npy
# `ydata` must not be empty!
# Successfully processed Chiba-CHBSRPB_sub-MADHC028.npy
# Successfully processed Chiba-CHBSRPB_sub-OCD109.npy
# Successfully processed Braga-UMinho-Braga-3T_sub-MRI201909032BART029.npy
# Successfully processed Yale-Pittinger-HCP-Prisma_sub-YaleHCPPrismapb7399.npy
# Successfully processed Bangalore-NIMHANS_sub-ODP234.npy
# Successfully processed Yale-Pittinger-HCP-Trio_sub-YaleHCPTriota6421.npy
# Successfully processed Chiba-CHBSRPB_sub-MADHC091.npy
# Successfully processed Barcelona-HCPB_sub-002.npy
# Successfully processed Brazil_sub-P00289220160705.npy
# knee value: 66
# ydata.shape: (60,)
# Error processing: Barcelone-Bellvitge-PROV-1.5T_sub-subIDIBELL15270.npy
# `ydata` must not be empty!
# Successfully processed Bangalore-NIMHANS_sub-C0131.npy
# Successfully processed New-York_sub-subSEQ1NKISENR87.npy
# Successfully processed Brazil_sub-P00197320141125.npy
# Successfully processed Chiba-CHB_sub-OCD081.npy
# knee value: 107
# ydata.shape: (65,)
# Error processing: Brazil_sub-P00309520161127.npy
# `ydata` must not be empty!
# Successfully processed Barcelone-Bellvitge-ANTIGA-1.5T_sub-subIDIBELL15C074.npy
# Successfully processed Yale-Pittinger-HCP-Prisma_sub-YaleHCPPrismapb4589.npy
# Successfully processed Shanghai-SMCH_sub-065.npy
# Successfully processed Cape-Town-UCT-Skyra_sub-CIMP128.npy
# Successfully processed Dresden_sub-GEROME3051.npy
# Successfully processed Braga-UMinho-Braga-1.5T-act_sub-MRI201601153OCD110.npy
# Successfully processed Amsterdam-VUmc_sub-916058.npy
# Successfully processed Yale-Gruner_sub-S4682URB.npy
# Successfully processed Kyoto-KPU-Kyoto3T_sub-subKyoto3Tsubj1024.npy
# Successfully processed Barcelone-Bellvitge-ANTIGA-1.5T_sub-subIDIBELL15P09.npy
# Successfully processed Bangalore-NIMHANS_sub-C0162.npy
# Successfully processed Bangalore-NIMHANS_sub-ODP248.npy
# Successfully processed Bangalore-NIMHANS_sub-ODP127.npy
# knee value: 73
# ydata.shape: (65,)
# Error processing: Brazil_sub-C001914.npy
# `ydata` must not be empty!
# Successfully processed Braga-UMinho-Braga-3T_sub-MRI201906052BART008.npy
# Successfully processed Braga-UMinho-Braga-1.5T-act_sub-MRI201603022OCD119.npy
# Successfully processed UCLA_sub-AOCD009.npy
# Successfully processed Brazil_sub-P00309720161127.npy
# Successfully processed Kyoto-KPU-Kyoto3T_sub-subKyoto3Tsubj1019.npy
# Successfully processed NYSPI-Columbia-Adults_sub-simpaocd197000.npy
# Successfully processed Seoul-SNU_sub-NOR12BJW.npy
# knee value: 92
# ydata.shape: (90,)
# Error processing: Braga-UMinho-Braga-1.5T-act_sub-MRI201510071OCD096.npy
# `ydata` must not be empty!
# knee value: 89
# ydata.shape: (76,)
# Error processing: Bangalore-NIMHANS_sub-ODP078.npy
# `ydata` must not be empty!
# Successfully processed Dresden_sub-GEROME3014.npy
# Successfully processed UCLA_sub-AOCD066.npy
# Successfully processed Barcelone-Bellvitge-ANTIGA-1.5T_sub-subIDIBELL15C071.npy
# Successfully processed Braga-UMinho-Braga-1.5T-act_sub-MRI201305202OCD060.npy
# Successfully processed Cape-Town-UCT-Skyra_sub-ESCC55.npy
# Successfully processed Chiba-CHB_sub-MADHC032.npy
# Successfully processed Bergen_sub-00012.npy
# Successfully processed Chiba-CHB_sub-MADHC013.npy
# Successfully processed Barcelone-Bellvitge-RESP-CBT-3T_sub-RESPCBT34CTRPOST.npy
# Successfully processed Bangalore-NIMHANS_sub-ODP043.npy
# Successfully processed Bangalore-NIMHANS_sub-ODP149.npy
# Successfully processed NYSPI-Columbia-Pediatric_sub-YBCQRY.npy
# Error processing: Bangalore-NIMHANS_sub-ODP146.npy
# The number of func parameters=5 must not exceed the number of data points=2
# Successfully processed Braga-UMinho-Braga-3T_sub-MRI201908142BART021.npy
# Successfully processed Barcelone-Bellvitge-RESP-CBT-3T_sub-RESPCBT17CTRPOST.npy
# Successfully processed Kyoto-KPU-Kyoto3T_sub-subKyoto3Tsubj0002.npy
# Successfully processed Bangalore-NIMHANS_sub-C0118.npy
# knee value: 89
# ydata.shape: (85,)
# Error processing: Shanghai-SMCH_sub-061.npy
# `ydata` must not be empty!
# Successfully processed Barcelone-Bellvitge-PROV-1.5T_sub-subIDIBELL15C295.npy
# Successfully processed NYSPI-Columbia-Adults_sub-simpaocd157000.npy
# knee value: 159
# ydata.shape: (149,)
# Error processing: Cape-Town-UCT-Skyra_sub-CIMP117.npy
# `ydata` must not be empty!
# Successfully processed Yale-Pittinger-HCP-Prisma_sub-YaleHCPPrismapb4635.npy
# Successfully processed Yale-Pittinger-HCP-Prisma_sub-YaleHCPPrismapb1728.npy
# Successfully processed Chiba-CHBC_sub-OCDC028.npy
# Successfully processed Chiba-CHBSRPB_sub-MADHC071.npy
# Successfully processed Chiba-CHBC_sub-OCDC030.npy
# Successfully processed Yale-Pittinger-Yale-2014_sub-Yale2014AdultOCDtr8791.npy
# knee value: 81
# ydata.shape: (60,)
# Error processing: Barcelone-Bellvitge-ANTIGA-1.5T_sub-subIDIBELL15C086.npy
# `ydata` must not be empty!
# Successfully processed Vancouver-BCCHR_sub-064.npy
# Successfully processed Yale-Pittinger-HCP-Trio_sub-YaleHCPTriota6458.npy
# Successfully processed Bangalore-NIMHANS_sub-C0163.npy
# Successfully processed Brazil_sub-P00238820150825.npy
# Successfully processed Bangalore-NIMHANS_sub-ODP106.npy
# Successfully processed Yale-Pittinger-Yale-2014_sub-Yale2014AdultOCDtr7640.npy
# Successfully processed Bangalore-NIMHANS_sub-C0072.npy
# Successfully processed Barcelone-Bellvitge-ANTIGA-1.5T_sub-subIDIBELL15C063.npy
# Successfully processed Bangalore-NIMHANS_sub-C0161.npy
# Successfully processed Seoul-SNU_sub-DNO36CSJ.npy
# Successfully processed NYSPI-Columbia-Adults_sub-simpaocd247000.npy
# Successfully processed Braga-UMinho-Braga-3T_sub-MRI201911201BART049.npy
# knee value: 76
# ydata.shape: (65,)
# Error processing: Brazil_sub-P00282120160530.npy
# `ydata` must not be empty!
# knee value: 83
# ydata.shape: (65,)
# Error processing: Brazil_sub-P00235020150811.npy
# `ydata` must not be empty!
# Successfully processed Amsterdam-VUmc_sub-916079.npy
# knee value: 87
# ydata.shape: (85,)
# Error processing: Shanghai-SMCH_sub-046.npy
# `ydata` must not be empty!
# Successfully processed Braga-UMinho-Braga-1.5T_sub-MRI201506082OCD079.npy
# knee value: 80
# ydata.shape: (56,)
# Error processing: Seoul-SNU_sub-NOR87YSH.npy
# `ydata` must not be empty!
# Successfully processed Kyoto-KPU-Kyoto3T_sub-subKyoto3Tsubj1034.npy
# knee value: 81
# ydata.shape: (80,)
# Error processing: Bergen_sub-02158.npy
# `ydata` must not be empty!
# Successfully processed Braga-UMinho-Braga-1.5T-act_sub-MRI201305291OCD062.npy
# Successfully processed UCLA_sub-AOCD035.npy
# Successfully processed Chiba-CHBSRPB_sub-SUA006.npy
# Successfully processed Kyoto-KPU-Kyoto3T_sub-subKyoto3Tsubj1038.npy
# Successfully processed Bangalore-NIMHANS_sub-C0077.npy
# Successfully processed Brazil_sub-P00262220160127.npy
# Successfully processed Barcelona-HCPB_sub-058.npy
# Successfully processed Barcelona-HCPB_sub-080.npy
# Successfully processed Braga-UMinho-Braga-3T_sub-MRI201911082BART042.npy
# Successfully processed Kyoto-KPU-Kyoto1.5T_sub-subKyoto15Tsubj1049.npy
# Successfully processed Shanghai-SMCH_sub-014.npy
# Successfully processed Chiba-CHB_sub-MADHC030.npy
# Successfully processed Chiba-CHBC_sub-OCDC022.npy
# Error processing: Yale-Pittinger-Yale-2014_sub-Yale2014AdultOCDtb0529.npy
# Improper input: func input vector length N=5 must not exceed func output vector length M=1
# Successfully processed NYSPI-Columbia-Pediatric_sub-MAQPMO.npy
# Successfully processed Amsterdam-VUmc_sub-916040.npy
# Successfully processed Bangalore-NIMHANS_sub-ODP079.npy
# knee value: 89
# ydata.shape: (75,)
# Error processing: Vancouver-BCCHR_sub-056.npy
# `ydata` must not be empty!
# Successfully processed NYSPI-Columbia-Adults_sub-simpaocd497000.npy
# Successfully processed Bangalore-NIMHANS_sub-C0013.npy
# Successfully processed Bergen_sub-02152.npy
# Successfully processed Barcelone-Bellvitge-ANTIGA-1.5T_sub-subIDIBELL15P11.npy
# Successfully processed Chiba-CHBC_sub-HCC021.npy
# knee value: 157
# ydata.shape: (120,)
# Error processing: Barcelone-Bellvitge-RESP-CBT-3T_sub-RESPCBT13CTRPOST.npy
# `ydata` must not be empty!
# Successfully processed Bangalore-NIMHANS_sub-ODP145.npy
# Successfully processed Bangalore-NIMHANS_sub-ODP186.npy
# Successfully processed Brazil_sub-P00348820180228.npy
# Successfully processed Chiba-CHBC_sub-OCDC035.npy
# Successfully processed Yale-Pittinger-HCP-Prisma_sub-YaleHCPPrismapb2873.npy
# Successfully processed Barcelone-Bellvitge-PROV-1.5T_sub-subIDIBELL15234.npy
# Successfully processed Yale-Pittinger-Yale-2014_sub-Yale2014AdultOCDtr7604.npy
# knee value: 79
# ydata.shape: (76,)
# Error processing: Bangalore-NIMHANS_sub-C0138.npy
# `ydata` must not be empty!
# Successfully processed Bangalore-NIMHANS_sub-C0135.npy
# Successfully processed UCLA_sub-AOCD069.npy
# Successfully processed Chiba-CHB_sub-OCD099.npy
# Successfully processed Braga-UMinho-Braga-1.5T-act_sub-MRI201208082OCD020.npy
# Successfully processed Braga-UMinho-Braga-1.5T-act_sub-MRI201207134OCD009.npy
# Successfully processed Barcelone-Bellvitge-ANTIGA-1.5T_sub-subIDIBELL15P73.npy
# Successfully processed Bangalore-NIMHANS_sub-C0100.npy
# Successfully processed Chiba-CHBSRPB_sub-OCD130.npy
# Successfully processed Vancouver-BCCHR_sub-075.npy
# Successfully processed NYSPI-Columbia-Adults_sub-simpaocd187000.npy
# Successfully processed Shanghai-SMCH_sub-019.npy
# Successfully processed UCLA_sub-AOCD007.npy
# Successfully processed Bangalore-NIMHANS_sub-C0048.npy
# Successfully processed NYSPI-Columbia-Adults_sub-simpaocd547000.npy
# Successfully processed New-York_sub-subSEQ1NKISENR117.npy
# Successfully processed Barcelone-Bellvitge-ANTIGA-1.5T_sub-subIDIBELL15C087.npy
# Successfully processed NYSPI-Columbia-Adults_sub-simpaocd307000.npy
# Successfully processed Dresden_sub-GEROME4019.npy
# Successfully processed Yale-Pittinger-HCP-Prisma_sub-YaleHCPPrismapb3409.npy
# Successfully processed Dresden_sub-GEROME4018.npy
# Successfully processed Bangalore-NIMHANS_sub-C0223.npy
# Successfully processed Brazil_sub-C001836.npy
# Successfully processed Vancouver-BCCHR_sub-043.npy
# Successfully processed NYSPI-Columbia-Adults_sub-simpaocd857000.npy
# Successfully processed Vancouver-BCCHR_sub-028.npy
# Successfully processed Barcelone-Bellvitge-RESP-CBT-3T_sub-RESPCBT19CTRPOST.npy
# Successfully processed Yale-Pittinger-HCP-Prisma_sub-YaleHCPPrismapb7391.npy
# Successfully processed Braga-UMinho-Braga-3T_sub-MRI201908261BART025.npy
# Successfully processed Bangalore-NIMHANS_sub-C0155.npy
# knee value: 116
# ydata.shape: (85,)
# Error processing: Shanghai-SMCH_sub-040.npy
# `ydata` must not be empty!
# Successfully processed Bangalore-NIMHANS_sub-C0109.npy
# knee value: 242
# ydata.shape: (240,)
# Error processing: New-York_sub-subSEQ1NKISENR159.npy
# `ydata` must not be empty!
# Successfully processed Seoul-SNU_sub-NOR73KMS.npy
# knee value: 125
# ydata.shape: (119,)
# Error processing: Chiba-CHBSRPB_sub-OCD148.npy
# `ydata` must not be empty!
# Successfully processed Chiba-CHBSRPB_sub-MADHC068.npy
# Successfully processed Barcelone-Bellvitge-RESP-CBT-3T_sub-RESPCBT17OCDPRE.npy
# Successfully processed Barcelone-Bellvitge-RESP-CBT-3T_sub-RESPCBT11OCDPOST.npy
# Successfully processed Shanghai-SMCH_sub-032.npy
# Successfully processed Cape-Town-UCT-Skyra_sub-CIMP135.npy
# Successfully processed UCLA_sub-AOCD034.npy
# Successfully processed Barcelone-Bellvitge-RESP-CBT-3T_sub-RESPCBT24CTRPOST.npy
# Successfully processed Bangalore-NIMHANS_sub-C0025.npy
# knee value: 73
# ydata.shape: (60,)
# Error processing: Barcelone-Bellvitge-PROV-1.5T_sub-subIDIBELL15C282.npy
# `ydata` must not be empty!
# Successfully processed Yale-Pittinger-HCP-Prisma_sub-YaleHCPPrismapb4749.npy
# Successfully processed NYSPI-Columbia-Adults_sub-simpaocd627000.npy
# Successfully processed Kyoto-KPU-Kyoto3T_sub-subKyoto3Tsubj1015.npy
# Successfully processed Kyoto-KPU-Kyoto3T_sub-subKyoto3Tsubj0037.npy
# Error processing: Barcelone-Bellvitge-ANTIGA-1.5T_sub-subIDIBELL15C094.npy
# `ydata` must not be empty!
# Successfully processed Bangalore-NIMHANS_sub-C0166.npy
# Successfully processed New-York_sub-subSEQ1NKISENR59.npy
# Successfully processed Yale-Pittinger-HCP-Prisma_sub-YaleHCPPrismapb2351.npy
# Successfully processed Bangalore-NIMHANS_sub-ODP075.npy
# Successfully processed Barcelona-HCPB_sub-C0088.npy
# Successfully processed Dresden_sub-GEROME3017.npy
# Successfully processed Seoul-SNU_sub-DNO17LJH.npy
# Successfully processed Seoul-SNU_sub-NOR29JSH.npy
# Successfully processed Kyoto-KPU-Kyoto3T_sub-subKyoto3Tsubj1027.npy
# knee value: 81
# ydata.shape: (76,)
# Error processing: Bangalore-NIMHANS_sub-ODP001.npy
# `ydata` must not be empty!
# Successfully processed New-York_sub-subSEQ1NKISENR70.npy
# knee value: 161
# ydata.shape: (56,)
# Error processing: Seoul-SNU_sub-NOR21JHK.npy
# `ydata` must not be empty!
# Error processing: Bangalore-NIMHANS_sub-ODP133.npy
# Improper input: func input vector length N=5 must not exceed func output vector length M=1
# Successfully processed Braga-UMinho-Braga-1.5T_sub-MRI201504292OCD072.npy
# knee value: 78
# ydata.shape: (60,)
# Error processing: Barcelone-Bellvitge-ANTIGA-1.5T_sub-subIDIBELL15C017.npy
# `ydata` must not be empty!
# knee value: 480
# ydata.shape: (120,)
# Error processing: Barcelona-HCPB_sub-C0067.npy
# `ydata` must not be empty!
# Successfully processed Bangalore-NIMHANS_sub-ODP055.npy
# Successfully processed NYSPI-Columbia-Pediatric_sub-ARYCFU.npy
# knee value: 123
# ydata.shape: (90,)
# Error processing: Braga-UMinho-Braga-1.5T_sub-MRI201410134CogTD067.npy
# `ydata` must not be empty!
# Successfully processed Chiba-CHB_sub-MADHC001.npy
# Successfully processed Yale-Pittinger-Yale-2014_sub-Yale2014AdultOCDtb1464.npy
# Successfully processed New-York_sub-subSEQ1NKISENR124.npy
# Successfully processed Bangalore-NIMHANS_sub-C0114.npy
# Successfully processed Bangalore-NIMHANS_sub-ODP052.npy
# Successfully processed New-York_sub-subSEQ1NKISENR133.npy
# Successfully processed NYSPI-Columbia-Adults_sub-simpaocd537000.npy
# Successfully processed Bangalore-NIMHANS_sub-ODP192.npy
# Successfully processed Bangalore-NIMHANS_sub-ODP018.npy
# Successfully processed Kyoto-KPU-Kyoto3T_sub-subKyoto3Tsubj1026.npy
# Successfully processed Amsterdam-VUmc_sub-916065.npy
# Successfully processed Shanghai-SMCH_sub-059.npy
# Successfully processed Bangalore-NIMHANS_sub-C0192.npy
# Successfully processed Shanghai-SMCH_sub-043.npy
# Successfully processed Bangalore-NIMHANS_sub-C0226.npy
# Successfully processed Shanghai-SMCH_sub-028.npy
# knee value: 58
# ydata.shape: (56,)
# Error processing: Seoul-SNU_sub-DNO01LYH.npy
# `ydata` must not be empty!
# Successfully processed Chiba-CHBSRPB_sub-MADHC059.npy
# Successfully processed Kyoto-KPU-Kyoto1.5T_sub-subKyoto15Tsubj0127.npy
# knee value: 119
# ydata.shape: (75,)
# Error processing: Vancouver-BCCHR_sub-054.npy
# `ydata` must not be empty!
# Successfully processed Bangalore-NIMHANS_sub-C0180.npy
# ...
# knee value: 77
# ydata.shape: (76,)
# Error processing: Bangalore-NIMHANS_sub-ODP151.npy
# `ydata` must not be empty!
# Successfully processed Braga-UMinho-Braga-1.5T-act_sub-MRI201307242CogTD009.npy
# knee value: 164
# ydata.shape: (149,)
# Error processing: Yale-Pittinger-Yale-2014_sub-Yale2014AdultOCDta0743.npy
# `ydata` must not be empty!
# Successfully processed Barcelone-Bellvitge-ANTIGA-1.5T_sub-subIDIBELL15P75.npy
# Successfully processed Cape-Town-UCT-Skyra_sub-CIMP133.npy
# Successfully processed Barcelone-Bellvitge-PROV-1.5T_sub-subIDIBELL15C308.npy
# knee value: 77
# ydata.shape: (76,)
# Error processing: Bangalore-NIMHANS_sub-C0087.npy
# `ydata` must not be empty!
# Successfully processed Kyoto-KPU-Kyoto3T_sub-subKyoto3Tsubj1023.npy
# knee value: 114
# ydata.shape: (80,)
# Error processing: Bergen_sub-00057.npy
# `ydata` must not be empty!
# Successfully processed Seoul-SNU_sub-NOR72KCK.npy
# Successfully processed Barcelona-HCPB_sub-C0059.npy
# Successfully processed Chiba-CHBC_sub-OCDC036.npy
# Successfully processed Barcelone-Bellvitge-ANTIGA-1.5T_sub-subIDIBELL15C036.npy
# Successfully processed Braga-UMinho-Braga-1.5T-act_sub-MRI201208244OCD025.npy
# Successfully processed Bangalore-NIMHANS_sub-ODP047.npy
# Successfully processed Bergen_sub-00026.npy
# Successfully processed NYSPI-Columbia-Adults_sub-simpaocd737000.npy
# Successfully processed Chiba-CHBC_sub-HCC002.npy
# Successfully processed Barcelona-HCPB_sub-084.npy
# Successfully processed Vancouver-BCCHR_sub-065.npy
# knee value: 104
# ydata.shape: (98,)
# Error processing: Chiba-CHBC_sub-OCDC037.npy
# `ydata` must not be empty!
# Error processing: Shanghai-SMCH_sub-058.npy
# The number of func parameters=5 must not exceed the number of data points=4
# knee value: 244
# ydata.shape: (85,)
# Error processing: Shanghai-SMCH_sub-051.npy
# `ydata` must not be empty!
# Successfully processed UCLA_sub-AOCD043.npy
# Successfully processed Braga-UMinho-Braga-1.5T-act_sub-MRI201303202OCD047.npy
# Successfully processed Bangalore-NIMHANS_sub-ODP188.npy
# Successfully processed Yale-Pittinger-Yale-2014_sub-Yale2014AdultOCDtb0195.npy
# Successfully processed Braga-UMinho-Braga-3T_sub-MRI201906171BART009.npy
# Successfully processed Brazil_sub-P00203820150127.npy
# Successfully processed Yale-Pittinger-Yale-2014_sub-Yale2014AdultOCDtb1366.npy
# Successfully processed Yale-Pittinger-HCP-Trio_sub-YaleHCPTriopb2759.npy
# Successfully processed Amsterdam-VUmc_sub-916008.npy
# knee value: 141
# ydata.shape: (85,)
# Error processing: Shanghai-SMCH_sub-015.npy
# `ydata` must not be empty!
# knee value: 93
# ydata.shape: (75,)
# Error processing: Vancouver-BCCHR_sub-072.npy
# `ydata` must not be empty!
# Successfully processed Vancouver-BCCHR_sub-055.npy
# Successfully processed Yale-Gruner_sub-S8618ECE.npy
# Successfully processed Yale-Pittinger-Yale-2014_sub-Yale2014AdultOCDtr7733.npy
# knee value: 111
# ydata.shape: (76,)
# Error processing: Bangalore-NIMHANS_sub-ODP072.npy
# `ydata` must not be empty!
# Successfully processed Bangalore-NIMHANS_sub-C0119.npy
# Successfully processed Braga-UMinho-Braga-1.5T-act_sub-MRI201303182OCD046.npy
# knee value: 95
# ydata.shape: (76,)
# Error processing: Bangalore-NIMHANS_sub-C0010.npy
# `ydata` must not be empty!
# Successfully processed Bangalore-NIMHANS_sub-C0217.npy
# Successfully processed Barcelone-Bellvitge-RESP-CBT-3T_sub-RESPCBT28CTRPRE.npy
# Successfully processed Barcelone-Bellvitge-ANTIGA-1.5T_sub-subIDIBELL15C095.npy
# knee value: 83
# ydata.shape: (80,)
# Error processing: Bergen_sub-00013.npy
# `ydata` must not be empty!
# Successfully processed Braga-UMinho-Braga-3T_sub-MRI20200717BART061.npy
# Error processing: Shanghai-SMCH_sub-076.npy
# The number of func parameters=5 must not exceed the number of data points=4
# Successfully processed Barcelone-Bellvitge-ANTIGA-1.5T_sub-subIDIBELL15C003.npy
# Successfully processed Kyoto-KPU-Kyoto3T_sub-subKyoto3Tsubj0029.npy
# Successfully processed Vancouver-BCCHR_sub-061.npy
# knee value: 122
# ydata.shape: (80,)
# Error processing: Bergen_sub-00055.npy
# `ydata` must not be empty!
# Knee frequencies f1: {'Brazil': [0.22833289954831545, 0.169428273468225, 0.17089216471408378, 0.12765715594978402, 0.17160032793933397, 0.1684529001007251, 0.21213686284500857, 0.16222921741604518, 0.07283914788937201, 0.17066286305562922, 0.15928805916070798, 0.20401436336526774, 0.02939098957228062, 0.18161694350457824, 0.2025975861241551, 0.15990914417966898, 0.1573580907961872, 0.15326159518203922, 0.16187554760291623, 0.13027081724956555, 0.11111550653211699, 0.17902599573486375, 0.1790251922717498, 0.21397289932814773, 0.18498105614069152, 0.08441451546072215, 0.10770987323159063, 0.19771784297266176, 0.11232443460812551, 0.16999029582282393, 0.22175314836303478, 0.14333222791104253, 0.13552813363541014, 0.12075420761805788, 0.1498883057250215, 0.1465297407798745, 0.1523937561596341, 0.09973189057286275, 0.19000764805265544, 0.1239374614053747, 0.15202062799221092, 0.18021871392323208, 0.13353666263628014, 0.20903407300272644, 0.13400170513526732, 0.2307479717599681, 0.1594592446777831, 0.11678899354941817, 0.2292320102981
[0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16], 'Barcelona-HCPB': [0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16 ...
# Sequence lengths: {'Brazil': [130, 130, 130, 130, 130, 130, 130, 130, 130, 130, 130, 130, 130, 130, 130, 130, 130, 130, 130, 130, 130, 130, 130, 130, 130, 130, 130, 130, 130, 130, 130, 130, 130, 130, 130, 130, 130, 130, 130, 130, 130, 130, 130, 130, 130, 130, 130, 130, 130, 130, 130, 130, 130, 130, 130, 130, 130, 130, 130, 130, 130, 130, 130, 130, 130, 130], 'Yale-Pittinger-HCP-Prisma': [770, 770, 770, 770, 770, 770, 770, 770, 770, 770, 770, 770, 770, 770, 770, 770, 770, 770, 770, 770, 770, 770, 770, 770, 770, 770, 770, 770, 770, 770, 770, 770, 770, 770, 770, 770, 770, 770, 770, 770, 770, 770, 770, 770, 770, 770, 770, 770, 770, 770, 770, 770, 770, 770, 770, 770, 770, 770, 770, 770], 'Seoul-SNU': [112, 112, 112, 112, 112, 112, 112, 112, 112, 112, 112, 112, 112, 112, 112, 112, 112, 112, 112, 112, 112, 112, 112, 112, 112, 112, 112, 112, 112, 112, 112, 112, 112, 112, 112, 112, 112, 112, 112, 112, 112, 112, 112, 112, 112, 112, 112, 112, 112, 112, 112, 112, 112, 112, 112, 112, 112, 112], 'Dresden': [840, 840, 840, 840, 840, 840, 840, 840, 840, 840, 840, 840, 840, 844, 840, 840, 840, 840, 840, 840, 840, 840, 840, 840, 840, 840, 840, 840, 840, 840, 840, 840, 840, 840, 840], 'Bergen': [160, 160, 160, 160, 160, 160, 160, 160, 160, 160, 160, 160, 160, 160, 160, 160, 160, 160, 160, 160, 160, 160, 160, 160, 160, 160, 160, 160, 160, 160, 160, 160, 160, 160, 160, 160, 160, 160, 160, 160, 160, 160], 'Bangalore-NIMHANS': [153, 153, 153, 153, 153, 303, 303, 153, 153, 303, 153, 153, 303, 153, 153, 153, 153, 153, 153, 153, 153, 153, 153, 153, 153, 153, 153, 153, 153, 153, 303, 153, 303, 153, 153, 153, 153, 153, 153, 153, 153, 153, 153, 303, 153, 153, 153, 153, 153, 153, 153, 153, 153, 153, 303, 153, 153, 153, 303, 153, 153, 303, 153, 303, 153, 153, 153, 152, 153, 303, 153, 153, 303, 153, 153, 153, 153, 153, 153, 153, 153, 153, 153, 153, 153, 153, 153, 153, 153, 303, 153, 153, 153, 153, 153, 153, 153, 153, 153, 153, 153, 303, 153, 153, 153, 153, 153, 153, 153, 153, 153, 153, 303, 153, 153, 153, 153, 303, 153, 153, 153, 153, 303, 153, 153, 153, 153, 153, 153, 153, 153, 153, 153, 153, 153, 153, 303, 153, 153, 153, 303, 153, 303, 153, 153, 153, 153, 303, 303, 303, 153, 153, 153, 221, 153, 153, 153, 153, 153, 153, 153, 153, 153, 153, 303, 153, 303, 303, 153, 153, 153, 153, 153, 153, 153, 153, 153, 303, 153, 153, 303, 153, 153, 153, 153, 153, 153, 153, 303, 153, 303, 153, 150, 153, 153, 153, 153, 153, 153, 303, 303, 153, 303, 153, 303, 303, 153, 303, 153, 153, 153, 153, 153, 153, 303, 153, 303, 153, 303, 153, 153, 153, 153, 153, 153, 153, 153, 153, 153, 153, 153, 153, 303, 153, 153, 153, 153, 153, 153, 153, 153, 303, 153, 153, 153, 153, 153, 303, 153, 303, 153, 153, 153, 153, 153, 153, 303, 153, 153, 153, 153, 303, 153, 153, 153, 303, 153, 153, 153, 153, 153, 153, 153, 153, 306, 303], 'Yale-Pittinger-Yale-2014': [299, 299, 299, 299, 299, 299, 299, 299, 299, 299, 299, 299, 299, 299, 299, 299, 299, 299, 299, 299, 299, 299, 299, 299, 299, 299, 299, 299, 299, 299, 299, 299, 299, 299, 299, 299, 299, 299, 299, 299, 299, 299, 299, 299, 299, 299, 299, 299, 299, 299, 299, 299, 299, 299, 299, 299, 299, 299, 299, 299], 'Barcelona-HCPB': [240, 240, 240, 240, 240, 240, 240, 240, 240, 240, 240, 240, 240, 240, 240, 240, 240, 240, 240, 240, 240, 240, 240, 240, 240, 240, 240, 240, 240, 240, 240, 240, 240, 240, 240, 240, 240, 240, 240, 240, 240, 240, 240, 240, 240, 240, 240, 240, 240, 240, 240, 240, 240, 240, 240, 240, 240, 240], 'Braga-UMinho-Braga-3T': [720, 720, 720, 720, 720, 720, 720, 720, 720, 720, 720, 720, 720, 720, 720, 720, 720, 720, 720, 720, 720, 720, 720, 720, 720, 720, 720, 720, 720, 720, 720, 720, 720, 720, 720, 720, 720, 720, 720, 720, 720, 720, 720, 720, 720, 720, 720, 720, 720, 720, 720, 720, 720, 720, 720, 720, 720], 'Barcelone-Bellvitge-RESP-CBT-3T': [240, 240, 240, 240, 240, 240, 240, 240, 240, 240, 240, 240, 240, 240, 240, 240, 240, 240, 240, 240, 240, 240, 240, 240, 240, 240, 240, 240, 240, 240, 240, 240, 240, 240, 240, 240, 240, 240, 240, 240, 24 ...
# Error processing 389 files

# %% [markdown]
# ### Check the results

# %%
# Summarize the data
data = []
for key in f1_dict.keys():
    f1_values = f1_dict[key]
    f2_values = f2_dict[key]
    seq_len_values = seq_len_dict[key]
    
    data.append({
        "key": key,
        "mean_f1": sum(f1_values) / len(f1_values) if f1_values else 0,
        "count_f1": len(f1_values),
        "mean_f2": sum(f2_values) / len(f2_values) if f2_values else 0,
        "count_f2": len(f2_values),
        "mean_seq_len": sum(seq_len_values) / len(seq_len_values) if seq_len_values else 0
    })

# Create DataFrame
df = pd.DataFrame(data)

# Display the DataFrame
print(df)
print(f"\nTotal of {sum(df['count_f1'])} subjects")
# Out:
#                                 key   mean_f1  count_f1  mean_f2  count_f2  \
# 0                            Brazil  0.162404        66     0.16        66
# 1         Yale-Pittinger-HCP-Prisma  0.241915        60     0.16        60
# 2                         Seoul-SNU  0.093293        58     0.16        58
# 3                           Dresden  0.216994        35     0.16        35
# 4                            Bergen  0.165059        42     0.16        42
# 5                 Bangalore-NIMHANS  0.156137       276     0.16       276
# 6          Yale-Pittinger-Yale-2014  0.147052        60     0.16        60
# 7                    Barcelona-HCPB  0.155399        58     0.16        58
# 8             Braga-UMinho-Braga-3T  0.257156        57     0.16        57
# 9   Barcelone-Bellvitge-RESP-CBT-3T  0.156458        53     0.16        53
# 10                    Chiba-CHBSRPB  0.140398        75     0.16        75
# 11                      Yale-Gruner  0.157311        19     0.16        19
# 12            NYSPI-Columbia-Adults  0.220371        70     0.16        70
# 13                   Amsterdam-VUmc  0.163470        50     0.16        50
# 14    Barcelone-Bellvitge-PROV-1.5T  0.165769        39     0.16        39
# 15      Braga-UMinho-Braga-1.5T-act  0.150848        91     0.16        91
# 16                    Shanghai-SMCH  0.116583        58     0.16        58
# 17                        Chiba-CHB  0.115225        39     0.16        39
# 18              Cape-Town-UCT-Skyra  0.158230        38     0.16        38
# 19         NYSPI-Columbia-Pediatric  0.246407        34     0.16        34
# 20          Braga-UMinho-Braga-1.5T  0.148533        35     0.16        35
# 21                  Vancouver-BCCHR  0.158247        36     0.16        36
# 22                         New-York  0.223959        57     0.16        57
# 23              Kyoto-KPU-Kyoto1.5T  0.135525        17     0.16        17
# 24                Kyoto-KPU-Kyoto3T  0.134435        62     0.16        62
# 25          Yale-Pittinger-HCP-Trio  0.265982        41     0.16        41
# 26                             UCLA  0.164465        46     0.16        46
# 27  Barcelone-Bellvitge-ANTIGA-1.5T  0.160418        84     0.16        84
# 28                       Chiba-CHBC  0.125048        49     0.16        49
#
#     mean_seq_len
# 0     130.000000
# 1     770.000000
# 2     112.000000
# 3     840.114286
# 4     160.000000
# 5     179.873188
# 6     299.000000
# 7     240.000000
# 8     720.000000
# 9     240.000000
# 10    239.000000
# 11    150.000000
# 12    528.785714
# 13    197.240000
# 14    120.000000
# 15    179.901099
# 16    170.000000
# 17    196.000000
# 18    298.000000
# 19    526.352941
# 20    180.000000
# 21    150.000000
# 22    480.000000
# 23    195.000000
# 24    194.000000
# 25    500.000000
# 26    208.000000
# 27    120.761905
# 28    196.000000
#
# Total of 1705 subjects

# %%
# Count the number of folders
folder_count = len([f for f in os.listdir(base_path) if os.path.isdir(os.path.join(base_path, f))])

print(f"Number of folders in '{base_path}': {folder_count}")
# Out:
# Number of folders in '/pscratch/sd/p/pakmasha/MBBN_data': 2094

# %% [markdown]
# ### Apply band-pass filtering, calculate knee frequencies, and save filtered time series

# %%
# Define the base path where the .tsv files are stored
base_path = '/pscratch/sd/p/pakmasha/MBBN_data'

# Create a dictionary to store knee values for each site
f1_dict = {}
f2_dict = {}
seq_len_dict = {}
error_count = 0

# Walk through all subdirectories and process .npy files
for root, dirs, files in os.walk(base_path):
    for file in files:
        if file.endswith('.npy') and file.split('_')[-2] != "smoothed" and file.split('_')[-2] != "0.01":
            # Construct full path to the .tsv file
            npy_file_path = os.path.join(root, file)
            # print(f"npy_file_path: {npy_file_path}")

            # Calculate the repetition time (TR) depending on the site
            site = file.split('_')[-2]
            if 'Amsterdam-AMC' in site:
                TR = 2.375
            elif 'Amsterdam-VUmc' in site:
                TR = 1.8
            elif 'Barcelona-HCPB' in site:
                TR = 2
            elif 'Bergen' in site:
                TR = 1.8
            elif 'Braga-UMinho-Braga-1.5T' in site:
                TR = 2
            elif 'Braga-UMinho-Braga-1.5T-act' in site:
                TR = 2
            elif 'Braga-UMinho-Braga-3T' in site:
                TR = 1
            elif 'Brazil' in site:
                TR = 2
            elif 'Cape-Town-UCT-Allegra' in site:
                TR = 1.6
            elif 'Cape-Town-UCT-Skyra' in site:
                TR = 1.73
            elif 'Chiba-CHB' in site:
                TR = 2.3
            elif 'Chiba-CHBC' in site:
                TR = 2.3 
            elif 'Chiba-CHBSRPB' in site:
                TR = 2.5 
            elif 'Dresden' in site:
                TR = 0.8 
            elif 'Kyoto-KPU-Kyoto1.5T' in site:
                TR = 2.411 
            elif 'Kyoto-KPU-Kyoto3T' in site:
                TR = 2
            elif 'Kyushu' in site:
                TR = 2.5
            elif 'Milan-HSR' in site:
                TR = 2
            elif 'New-York' in site:
                TR = 1
            elif 'NYSPI-Columbia-Adults' in site:
                TR = 0.85
            elif 'NYSPI-Columbia-Pediatric' in site:
                TR = 0.85
            elif 'Yale-Pittinger-HCP-Prisma' in site:
                TR = 0.8
            elif 'Yale-Pittinger-HCP-Trio' in site:
                TR = 0.7
            elif 'Yale-Pittinger-Yale-2014' in site:
                TR = 2
            elif 'Bangalore-NIMHANS' in site:
                TR = 2 
            elif 'Barcelone-Bellvitge-ANTIGA-1.5T' in site:
                TR = 2
            elif 'Barcelone-Bellvitge-COMPULSE-3T' in site:
                TR = 2
            elif 'Barcelone-Bellvitge-PROV-1.5T' in site:
                TR = 2
            elif 'Barcelone-Bellvitge-RESP-CBT-3T' in site:
                TR = 2
            elif 'Seoul-SNU' in site:
                TR = 3.5
            elif 'Shanghai-SMCH' in site:
                TR = 3
            elif 'UCLA' in site:
                TR = 2
            elif 'Vancouver-BCCHR' in site:
                TR = 2
            elif 'Yale-Gruner' in site:
                TR = 2
            else:
                raise ValueError(f"Site '{site}' does not have a defined TR value in TR_mappings. Please add it.")

            # Load the .npy file and calculate knee frequencies
            y = np.load(npy_file_path).T
            sequence_length = y.shape[1]   # use the original number of points
            # print(f"y: {y}")
            # print(f"y.shape: {y.shape}")

            try: 
                fs = 1 / TR  # Sampling frequency in Hz
                lowcut = 0.01  # Low cutoff frequency in Hz
                highcut = 0.1  # High cutoff frequency in Hz

                # Apply the filter to each row (ROI) in the 2D array `y`
                y = np.array([bandpass_filter(roi, lowcut, highcut, fs) for roi in y])

                # Save the filtered time series
                # Save the filtered time series
                filtered_file_name = f"{os.path.splitext(file)[0]}_filtered_{lowcut}_{highcut}.npy"
                filtered_file_path = os.path.join(root, filtered_file_name)
                np.save(filtered_file_path, y.T)
                print(f"Successfully save {filtered_file_name} file")

                sample_whole = np.zeros(sequence_length,) # originally sequence_length   ## aggregates time-series data across ROIs   # sample_whole.shape = # of timepoints,

                ##### DEBUG STATEMENT #####
                # sample_whole = np.zeros(sequence_length - 20,)
                # print(f"sample_whole.shape: {sample_whole.shape}")
                ###########################

                intermediate_vec = y.shape[0]

                for i in range(intermediate_vec):
                    # print(f"y[i] shape: {y[i].shape}")
                    sample_whole+=y[i]

                sample_whole /= intermediate_vec    # averages the time-series signals (y) across a set number of ROIs

                # Smooth the averaged time series
                # fwhm = 2
                # smoothed_sample_whole = gaussian_smoothing_with_fwhm(sample_whole, fwhm)

                T = TimeSeries(sample_whole, sampling_interval=TR)  # computes power spectral density (PSD) of the averaged time-series signal
                S_original = SpectralAnalyzer(T)

                # Lorentzian function fitting (dividing ultralow ~ low)  ## extracts the PSD data
                xdata = np.array(S_original.spectrum_fourier[0][1:])  # xdata = frequency values  
                ydata = np.abs(S_original.spectrum_fourier[1][1:])    # ydata = corresponding power values
                # print(f"xdata.shape: {xdata.shape}")
                # print(f"ydata.shape: {ydata.shape}")

                # initial parameter setting
                p0 = [0, 0.006]   
                param_bounds = ([-np.inf, 0], [np.inf, 1])

                # fitting Lorentzian function
                popt, pcov = curve_fit(lorentzian_function, xdata, ydata, p0=p0, maxfev = 5000, bounds=param_bounds)   # popt = optimal parameters

                f1 = popt[1]

                knee = round(popt[1]/(1/(sample_whole.shape[0]*TR)))   # calculates knee frequency 
                # print(f"knee: {knee}")

                if knee <= 0:
                    knee = 1

                if knee > ydata.shape[0]:
                    print(f"knee value: {knee}")
                    print(f"ydata.shape: {ydata.shape}")

                # divide low ~ high
                # initial parameter setting
                p1 = [2, 1, 23, 25, 0.16]
            
                # fitting multifractal function
                popt_mo, pcov = curve_fit(multi_fractal_function, xdata[knee:], ydata[knee:], p0=p1, maxfev = 50000)   # fits a multi-fractal model to the high-frequency range (above the knee)
                pink = round(popt_mo[-1]/(1/(sample_whole.shape[0]*TR)))   # pink = an additional boundary
                f2 = popt_mo[-1]

                # if file == "Brazil_sub-C001419_smoothed_2mm.npy":
                #     print("file == 'Brazil_sub-C001419_smoothed_2mm.npy'")
                #     print(f"y: {y[:2,]}")
                #     print(f"sample_whole: {sample_whole[:2,]}")
                #     print(f"knee: {knee}")
                #     print(f"f1: {f1}, f2: {f2}")

                # Save values to the dictionaries
                # Check if the key exists in the dictionary
                if site in f1_dict:
                    # Append the value to the existing list
                    f1_dict[site].append(f1)
                    f2_dict[site].append(f2)
                    seq_len_dict[site].append(sequence_length)
                else:
                    # Create the key and initialize it with a list containing the value
                    f1_dict[site] = [f1]
                    f2_dict[site] = [f2]   
                    seq_len_dict[site] = [sequence_length] 
                print(f"Successfully processed {file}")  
            except Exception as e:
                print(f"Error processing: {file}")
                print(e)
                error_count += 1
                continue  # Skip the subject if an error occurs
            
print(f"Knee frequencies f1: {f1_dict}")
print(f"\nKnee frequencies f2: {f2_dict}")
print(f"Sequence lengths: {seq_len_dict}")
print(f"Error processing {error_count} files")
# Out:
# Successfully save Barcelona-HCPB_sub-008_filtered_0.01_0.1.npy file
# Successfully processed Barcelona-HCPB_sub-008.npy
# Successfully save Brazil_sub-C002061_filtered_0.01_0.1.npy file
# Successfully processed Brazil_sub-C002061.npy
# /tmp/ipykernel_1421614/1867528834.py:2: RuntimeWarning: overflow encountered in power
#   return np.where(x < corner, A * x**beta_low, B * x**beta_high)
# /tmp/ipykernel_1421614/154038384.py:164: OptimizeWarning: Covariance of the parameters could not be estimated
#   popt_mo, pcov = curve_fit(multi_fractal_function, xdata[knee:], ydata[knee:], p0=p1, maxfev = 50000)   # fits a multi-fractal model to the high-frequency range (above the knee)
# Successfully save Yale-Pittinger-HCP-Prisma_sub-YaleHCPPrismapb3225_filtered_0.01_0.1.npy file
# Successfully processed Yale-Pittinger-HCP-Prisma_sub-YaleHCPPrismapb3225.npy
# Successfully save Seoul-SNU_sub-NOR117CSJ_filtered_0.01_0.1.npy file
# Successfully processed Seoul-SNU_sub-NOR117CSJ.npy
# /tmp/ipykernel_1421614/1867528834.py:2: RuntimeWarning: overflow encountered in multiply
#   return np.where(x < corner, A * x**beta_low, B * x**beta_high)
# Successfully save Dresden_sub-GEROME3073_filtered_0.01_0.1.npy file
# Successfully processed Dresden_sub-GEROME3073.npy
# Successfully save Bergen_sub-00059_filtered_0.01_0.1.npy file
# Successfully processed Bergen_sub-00059.npy
# Successfully save Bangalore-NIMHANS_sub-C0181_filtered_0.01_0.1.npy file
# Successfully processed Bangalore-NIMHANS_sub-C0181.npy
# Successfully save Bangalore-NIMHANS_sub-C0128_filtered_0.01_0.1.npy file
# Successfully processed Bangalore-NIMHANS_sub-C0128.npy
# Successfully save Seoul-SNU_sub-DNO23LSM_filtered_0.01_0.1.npy file
# Successfully processed Seoul-SNU_sub-DNO23LSM.npy
# Successfully save Bangalore-NIMHANS_sub-ODP004_filtered_0.01_0.1.npy file
# Successfully processed Bangalore-NIMHANS_sub-ODP004.npy
# Successfully save Bangalore-NIMHANS_sub-ODP203_filtered_0.01_0.1.npy file
# Successfully processed Bangalore-NIMHANS_sub-ODP203.npy
# Successfully save Barcelone-Bellvitge-PROV-1.5T_sub-subIDIBELL15224_filtered_0.01_0.1.npy file
# Successfully processed Barcelone-Bellvitge-PROV-1.5T_sub-subIDIBELL15224.npy
# Successfully save Barcelone-Bellvitge-ANTIGA-1.5T_sub-subIDIBELL15C032_filtered_0.01_0.1.npy file
# Successfully processed Barcelone-Bellvitge-ANTIGA-1.5T_sub-subIDIBELL15C032.npy
# Successfully save Bangalore-NIMHANS_sub-ODP099_filtered_0.01_0.1.npy file
# Successfully processed Bangalore-NIMHANS_sub-ODP099.npy
# Successfully save Chiba-CHB_sub-MADHC010_filtered_0.01_0.1.npy file
# Successfully processed Chiba-CHB_sub-MADHC010.npy
# Successfully save Yale-Pittinger-Yale-2014_sub-Yale2014AdultOCDtr7977_filtered_0.01_0.1.npy file
# Successfully processed Yale-Pittinger-Yale-2014_sub-Yale2014AdultOCDtr7977.npy
# Successfully save Bergen_sub-00066_filtered_0.01_0.1.npy file
# Successfully processed Bergen_sub-00066.npy
# Successfully save Yale-Pittinger-Yale-2014_sub-Yale2014AdultOCDtb0314_filtered_0.01_0.1.npy file
# Successfully processed Yale-Pittinger-Yale-2014_sub-Yale2014AdultOCDtb0314.npy
# Successfully save Barcelona-HCPB_sub-C0071_filtered_0.01_0.1.npy file
# Successfully processed Barcelona-HCPB_sub-C0071.npy
# Successfully save Barcelone-Bellvitge-ANTIGA-1.5T_sub-subIDIBELL15C042_filtered_0.01_0.1.npy file
# Successfully processed Barcelone-Bellvitge-ANTIGA-1.5T_sub-subIDIBELL15C042.npy
# Successfully save Barcelona-HCPB_sub-042_filtered_0.01_0.1.npy file
# Successfully processed Barcelona-HCPB_sub-042.npy
# Successfully save Barcelone-Bellvitge-ANTIGA-1.5T_sub-subIDIBELL15P67_filtered_0.01_0.1.npy file
# Successfully processed Barcelone-Bellvitge-ANTIGA-1.5T_sub-subIDIBELL15P67.npy
# Successfully save Braga-UMinho-Braga-3T_sub-MRI201905211BART003_filtered_0.01_0.1.npy file
# Successfully processed Braga-UMinho-Braga-3T_sub-MRI201905211BART003.npy
# Successfully save Barcelone-Bellvitge-RESP-CBT-3T_sub-RESPCBT25CTRPOST_filtered_0.01_0.1.npy file
# Successfully processed Barcelone-Bellvitge-RESP-CBT-3T_sub-RESPCBT25CTRPOST.npy
# Successfully save Seoul-SNU_sub-DNO39JHJ_filtered_0.01_0.1.npy file
# Successfully processed Seoul-SNU_sub-DNO39JHJ.npy
# Successfully save Chiba-CHBSRPB_sub-SUA004_filtered_0.01_0.1.npy file
# Successfully processed Chiba-CHBSRPB_sub-SUA004.npy
# Successfully save Seoul-SNU_sub-UMO27LCY_filtered_0.01_0.1.npy file
# Successfully processed Seoul-SNU_sub-UMO27LCY.npy
# Successfully save Bangalore-NIMHANS_sub-C0234_filtered_0.01_0.1.npy file
# Successfully processed Bangalore-NIMHANS_sub-C0234.npy
# Successfully save Chiba-CHBSRPB_sub-MADHC054_filtered_0.01_0.1.npy file
# Successfully processed Chiba-CHBSRPB_sub-MADHC054.npy
# Successfully save Yale-Gruner_sub-S4576MHM_filtered_0.01_0.1.npy file
# Successfully processed Yale-Gruner_sub-S4576MHM.npy
# Successfully save NYSPI-Columbia-Adults_sub-simpaocd407000_filtered_0.01_0.1.npy file
# Successfully processed NYSPI-Columbia-Adults_sub-simpaocd407000.npy
# Successfully save Barcelone-Bellvitge-RESP-CBT-3T_sub-RESPCBT09CTRPRE_filtered_0.01_0.1.npy file
# Successfully processed Barcelone-Bellvitge-RESP-CBT-3T_sub-RESPCBT09CTRPRE.npy
# Successfully save Bangalore-NIMHANS_sub-ODP241_filtered_0.01_0.1.npy file
# Successfully processed Bangalore-NIMHANS_sub-ODP241.npy
# Successfully save Amsterdam-VUmc_sub-916088_filtered_0.01_0.1.npy file
# Successfully processed Amsterdam-VUmc_sub-916088.npy
# Successfully save Bangalore-NIMHANS_sub-ODP201_filtered_0.01_0.1.npy file
# Successfully processed Bangalore-NIMHANS_sub-ODP201.npy
# Successfully save Yale-Pittinger-Yale-2014_sub-Yale2014AdultOCDtr8623_filtered_0.01_0.1.npy file
# Successfully processed Yale-Pittinger-Yale-2014_sub-Yale2014AdultOCDtr8623.npy
# Successfully save Bangalore-NIMHANS_sub-C0052_filtered_0.01_0.1.npy file
# Successfully processed Bangalore-NIMHANS_sub-C0052.npy
# Successfully save Bangalore-NIMHANS_sub-ODP122_filtered_0.01_0.1.npy file
# Successfully processed Bangalore-NIMHANS_sub-ODP122.npy
# Successfully save Barcelone-Bellvitge-PROV-1.5T_sub-subIDIBELL15215_filtered_0.01_0.1.npy file
# Successfully processed Barcelone-Bellvitge-PROV-1.5T_sub-subIDIBELL15215.npy
# Successfully save NYSPI-Columbia-Adults_sub-simpaocd577000_filtered_0.01_0.1.npy file
# Successfully processed NYSPI-Columbia-Adults_sub-simpaocd577000.npy
# Successfully save Barcelone-Bellvitge-ANTIGA-1.5T_sub-subIDIBELL15C061_filtered_0.01_0.1.npy file
# Successfully processed Barcelone-Bellvitge-ANTIGA-1.5T_sub-subIDIBELL15C061.npy
# Successfully save Barcelone-Bellvitge-RESP-CBT-3T_sub-RESPCBT11CTRPRE_filtered_0.01_0.1.npy file
# Successfully processed Barcelone-Bellvitge-RESP-CBT-3T_sub-RESPCBT11CTRPRE.npy
# Successfully save Braga-UMinho-Braga-1.5T-act_sub-MRI201211284OCD039_filtered_0.01_0.1.npy file
# Successfully processed Braga-UMinho-Braga-1.5T-act_sub-MRI201211284OCD039.npy
# Successfully save Yale-Pittinger-Yale-2014_sub-Yale2014AdultOCDtb1751_filtered_0.01_0.1.npy file
# Successfully processed Yale-Pittinger-Yale-2014_sub-Yale2014AdultOCDtb1751.npy
# Successfully save Bangalore-NIMHANS_sub-C0235_filtered_0.01_0.1.npy file
# Successfully processed Bangalore-NIMHANS_sub-C0235.npy
# Successfully save Bangalore-NIMHANS_sub-ODP211_filtered_0.01_0.1.npy file
# Successfully processed Bangalore-NIMHANS_sub-ODP211.npy
# Successfully save Bangalore-NIMHANS_sub-C0075_filtered_0.01_0.1.npy file
# Successfully processed Bangalore-NIMHANS_sub-C0075.npy
# Successfully save Chiba-CHBSRPB_sub-OCD151_filtered_0.01_0.1.npy file
# Successfully processed Chiba-CHBSRPB_sub-OCD151.npy
# Successfully save Seoul-SNU_sub-NOR38LSJ_filtered_0.01_0.1.npy file
# Successfully processed Seoul-SNU_sub-NOR38LSJ.npy
# Successfully save Chiba-CHBSRPB_sub-MADHC032_filtered_0.01_0.1.npy file
# Successfully processed Chiba-CHBSRPB_sub-MADHC032.npy
# Successfully save Shanghai-SMCH_sub-045_filtered_0.01_0.1.npy file
# Successfully processed Shanghai-SMCH_sub-045.npy
# Successfully save Chiba-CHB_sub-MADHC022_filtered_0.01_0.1.npy file
# Successfully processed Chiba-CHB_sub-MADHC022.npy
# Successfully save Barcelone-Bellvitge-PROV-1.5T_sub-subIDIBELL15C293_filtered_0.01_0.1.npy file
# Successfully processed Barcelone-Bellvitge-PROV-1.5T_sub-subIDIBELL15C293.npy
# Successfully save Yale-Pittinger-Yale-2014_sub-Yale2014AdultOCDtr9380_filtered_0.01_0.1.npy file
# Successfully processed Yale-Pittinger-Yale-2014_sub-Yale2014AdultOCDtr9380.npy
# Successfully save Bangalore-NIMHANS_sub-C0198_filtered_0.01_0.1.npy file
# Successfully processed Bangalore-NIMHANS_sub-C0198.npy
# Successfully save Chiba-CHB_sub-MADHC023_filtered_0.01_0.1.npy file
# Successfully processed Chiba-CHB_sub-MADHC023.npy
# Successfully save Cape-Town-UCT-Skyra_sub-CIMP127_filtered_0.01_0.1.npy file
# Successfully processed Cape-Town-UCT-Skyra_sub-CIMP127.npy
# Successfully save Braga-UMinho-Braga-3T_sub-MRI201911121BART043_filtered_0.01_0.1.npy file
# Successfully processed Braga-UMinho-Braga-3T_sub-MRI201911121BART043.npy
# Successfully save Brazil_sub-P00222720150526_filtered_0.01_0.1.npy file
# Successfully processed Brazil_sub-P00222720150526.npy
# Successfully save Bangalore-NIMHANS_sub-C0093_filtered_0.01_0.1.npy file
# Successfully processed Bangalore-NIMHANS_sub-C0093.npy
# Successfully save NYSPI-Columbia-Pediatric_sub-KZKLJH_filtered_0.01_0.1.npy file
# Successfully processed NYSPI-Columbia-Pediatric_sub-KZKLJH.npy
# Successfully save Shanghai-SMCH_sub-048_filtered_0.01_0.1.npy file
# Successfully processed Shanghai-SMCH_sub-048.npy
# Successfully save Braga-UMinho-Braga-1.5T-act_sub-MRI201212142OCD042_filtered_0.01_0.1.npy file
# Successfully processed Braga-UMinho-Braga-1.5T-act_sub-MRI
filtered_0.01_0.1.npy file
# Successfully processed Chiba-CHB_sub-OCD096.npy
# Successfully save Brazil_sub-P00196820141124_filtered_0.01_0.1.npy file
# Successfully processed Brazil_sub-P00196820141124.npy
# Successfully save Amsterdam-VUmc_sub-916052_filtered_0.01_0.1.npy file
# Successfully processed Amsterdam-VUmc_sub-916052.npy
# Successfully save Vancouver-BCCHR_sub-014_filtered_0.01_0.1.npy file
# Successfully processed Vancouver-BCCHR_sub-014.npy
# Successfully save Shanghai-SMCH_sub-030_filtered_0.01_0.1.npy file
# Successfully processed Shanghai-SMCH_sub-030.npy
# Successfully save Barcelone-Bellvitge-RESP-CBT-3T_sub-RESPCBT08CTRPRE_filtered_0.01_0.1.npy file
# Successfully processed Barcelone-Bellvitge-RESP-CBT-3T_sub-RESPCBT08CTRPRE.npy
# Successfully save Seoul-SNU_sub-NOR71HRK_filtered_0.01_0.1.npy file
# Successfully processed Seoul-SNU_sub-NOR71HRK.npy
# Successfully save UCLA_sub-AOCD008_filtered_0.01_0.1.npy file
# Successfully processed UCLA_sub-AOCD008.npy
# Successfully save Bangalore-NIMHANS_sub-C0137_filtered_0.01_0.1.npy file
# Successfully processed Bangalore-NIMHANS_sub-C0137.npy
# Successfully save NYSPI-Columbia-Adults_sub-simpaocd317000_filtered_0.01_0.1.npy file
# Successfully processed NYSPI-Columbia-Adults_sub-simpaocd317000.npy
# Successfully save Yale-Pittinger-Yale-2014_sub-Yale2014AdultOCDtr8740_filtered_0.01_0.1.npy file
# Successfully processed Yale-Pittinger-Yale-2014_sub-Yale2014AdultOCDtr8740.npy
# Successfully save Barcelona-HCPB_sub-C0087_filtered_0.01_0.1.npy file
# Successfully processed Barcelona-HCPB_sub-C0087.npy
# Successfully save Bangalore-NIMHANS_sub-ODP156_filtered_0.01_0.1.npy file
# Successfully processed Bangalore-NIMHANS_sub-ODP156.npy
# Successfully save Bangalore-NIMHANS_sub-ODP159_filtered_0.01_0.1.npy file
# Successfully processed Bangalore-NIMHANS_sub-ODP159.npy
# Successfully save Bangalore-NIMHANS_sub-C0151_filtered_0.01_0.1.npy file
# Successfully processed Bangalore-NIMHANS_sub-C0151.npy
# Successfully save Kyoto-KPU-Kyoto1.5T_sub-subKyoto15Tsubj1050_filtered_0.01_0.1.npy file
# Successfully processed Kyoto-KPU-Kyoto1.5T_sub-subKyoto15Tsubj1050.npy
# Successfully save Barcelone-Bellvitge-RESP-CBT-3T_sub-RESPCBT28CTRPOST_filtered_0.01_0.1.npy file
# Successfully processed Barcelone-Bellvitge-RESP-CBT-3T_sub-RESPCBT28CTRPOST.npy
# Successfully save Barcelone-Bellvitge-ANTIGA-1.5T_sub-subIDIBELL15C019_filtered_0.01_0.1.npy file
# Successfully processed Barcelone-Bellvitge-ANTIGA-1.5T_sub-subIDIBELL15C019.npy
# Successfully save Chiba-CHBSRPB_sub-MADHC056_filtered_0.01_0.1.npy file
# Successfully processed Chiba-CHBSRPB_sub-MADHC056.npy
# Successfully save Amsterdam-VUmc_sub-916027_filtered_0.01_0.1.npy file
# Successfully processed Amsterdam-VUmc_sub-916027.npy
# Successfully save Yale-Pittinger-Yale-2014_sub-Yale2014AdultOCDtb1917_filtered_0.01_0.1.npy file
# Successfully processed Yale-Pittinger-Yale-2014_sub-Yale2014AdultOCDtb1917.npy
# Successfully save Barcelone-Bellvitge-ANTIGA-1.5T_sub-subIDIBELL15C051_filtered_0.01_0.1.npy file
# Successfully processed Barcelone-Bellvitge-ANTIGA-1.5T_sub-subIDIBELL15C051.npy
# Successfully save Yale-Gruner_sub-S1163AET_filtered_0.01_0.1.npy file
# Successfully processed Yale-Gruner_sub-S1163AET.npy
# Successfully save Vancouver-BCCHR_sub-038_filtered_0.01_0.1.npy file
# Successfully processed Vancouver-BCCHR_sub-038.npy
# Successfully save Bergen_sub-00060_filtered_0.01_0.1.npy file
# Successfully processed Bergen_sub-00060.npy
# Successfully save Cape-Town-UCT-Skyra_sub-CIMP114_filtered_0.01_0.1.npy file
# Successfully processed Cape-Town-UCT-Skyra_sub-CIMP114.npy
# Successfully save Shanghai-SMCH_sub-006_filtered_0.01_0.1.npy file
# Successfully processed Shanghai-SMCH_sub-006.npy
# Successfully save Bergen_sub-00076_filtered_0.01_0.1.npy file
# Successfully processed Bergen_sub-00076.npy
# Successfully save Chiba-CHBSRPB_sub-OCD134_filtered_0.01_0.1.npy file
# Successfully processed Chiba-CHBSRPB_sub-OCD134.npy
# Successfully save Kyoto-KPU-Kyoto3T_sub-subKyoto3Tsubj1042_filtered_0.01_0.1.npy file
# Successfully processed Kyoto-KPU-Kyoto3T_sub-subKyoto3Tsubj1042.npy
# Successfully save Braga-UMinho-Braga-1.5T-act_sub-MRI201306132OCD065_filtered_0.01_0.1.npy file
# Successfully processed Braga-UMinho-Braga-1.5T-act_sub-MRI201306132OCD065.npy
# Successfully save Bangalore-NIMHANS_sub-C0073_filtered_0.01_0.1.npy file
# Successfully processed Bangalore-NIMHANS_sub-C0073.npy
# Successfully save Dresden_sub-GEROME3028_filtered_0.01_0.1.npy file
# Successfully processed Dresden_sub-GEROME3028.npy
# Successfully save Bangalore-NIMHANS_sub-ODP017_filtered_0.01_0.1.npy file
# Successfully processed Bangalore-NIMHANS_sub-ODP017.npy
# Successfully save Vancouver-BCCHR_sub-066_filtered_0.01_0.1.npy file
# Successfully processed Vancouver-BCCHR_sub-066.npy
# Successfully save UCLA_sub-AOCD052_filtered_0.01_0.1.npy file
# Successfully processed UCLA_sub-AOCD052.npy
# Successfully save Seoul-SNU_sub-UMO03KHK_filtered_0.01_0.1.npy file
# Successfully processed Seoul-SNU_sub-UMO03KHK.npy
# Successfully save Barcelona-HCPB_sub-036_filtered_0.01_0.1.npy file
# Successfully processed Barcelona-HCPB_sub-036.npy
# Successfully save Yale-Pittinger-Yale-2014_sub-Yale2014AdultOCDtr8240_filtered_0.01_0.1.npy file
# Successfully processed Yale-Pittinger-Yale-2014_sub-Yale2014AdultOCDtr8240.npy
# Successfully save Yale-Pittinger-HCP-Trio_sub-YaleHCPTriota6591_filtered_0.01_0.1.npy file
# Successfully processed Yale-Pittinger-HCP-Trio_sub-YaleHCPTriota6591.npy
# Successfully save Bangalore-NIMHANS_sub-C0108_filtered_0.01_0.1.npy file
# Successfully processed Bangalore-NIMHANS_sub-C0108.npy
# Successfully save Bangalore-NIMHANS_sub-ODP057_filtered_0.01_0.1.npy file
# Successfully processed Bangalore-NIMHANS_sub-ODP057.npy
# Successfully save Yale-Pittinger-Yale-2014_sub-Yale2014AdultOCDtb2073_filtered_0.01_0.1.npy file
# Successfully processed Yale-Pittinger-Yale-2014_sub-Yale2014AdultOCDt
filtered_0.01_0.1.npy file
# Successfully processed Barcelone-Bellvitge-ANTIGA-1.5T_sub-subIDIBELL15P25.npy
# Successfully save Amsterdam-VUmc_sub-916037_filtered_0.01_0.1.npy file
# Successfully processed Amsterdam-VUmc_sub-916037.npy
# Successfully save Vancouver-BCCHR_sub-031_filtered_0.01_0.1.npy file
# Successfully processed Vancouver-BCCHR_sub-031.npy
# Successfully save Bangalore-NIMHANS_sub-ODP243_filtered_0.01_0.1.npy file
# Successfully processed Bangalore-NIMHANS_sub-ODP243.npy
# Successfully save Kyoto-KPU-Kyoto1.5T_sub-subKyoto15Tsubj0132_filtered_0.01_0.1.npy file
# Successfully processed Kyoto-KPU-Kyoto1.5T_sub-subKyoto15Tsubj0132.npy
# Successfully save Amsterdam-VUmc_sub-916085_filtered_0.01_0.1.npy file
# Successfully processed Amsterdam-VUmc_sub-916085.npy
# Successfully save Cape-Town-UCT-Skyra_sub-CIMP078_filtered_0.01_0.1.npy file
# Successfully processed Cape-Town-UCT-Skyra_sub-CIMP078.npy
# Successfully save Braga-UMinho-Braga-3T_sub-MRI202009221BART064_filtered_0.01_0.1.npy file
# Successfully processed Braga-UMinho-Braga-3T_sub-MRI202009221BART064.npy
# Successfully save Brazil_sub-C001866_filtered_0.01_0.1.npy file
# Successfully processed Brazil_sub-C001866.npy
# Successfully save NYSPI-Columbia-Adults_sub-simpaocd87000_filtered_0.01_0.1.npy file
# Successfully processed NYSPI-Columbia-Adults_sub-simpaocd87000.npy
# Successfully save Barcelona-HCPB_sub-C0070_filtered_0.01_0.1.npy file
# Successfully processed Barcelona-HCPB_sub-C0070.npy
# Successfully save New-York_sub-subSEQ1NKISENR131_filtered_0.01_0.1.npy file
# Successfully processed New-York_sub-subSEQ1NKISENR131.npy
# Successfully save Bangalore-NIMHANS_sub-C0152_filtered_0.01_0.1.npy file
# Successfully processed Bangalore-NIMHANS_sub-C0152.npy
# Successfully save NYSPI-Columbia-Adults_sub-simpaocd267000_filtered_0.01_0.1.npy file
# Successfully processed NYSPI-Columbia-Adults_sub-simpaocd267000.npy
# Successfully save Braga-UMinho-Braga-1.5T-act_sub-MRI201307312CogTD016_filtered_0.01_0.1.npy file
# Successfully processed Braga-UMinho-Braga-1.5T-act_sub-MRI201307312CogTD016.npy
# Successfully save Bangalore-NIMHANS_sub-C0159_filtered_0.01_0.1.npy file
# Successfully processed Bangalore-NIMHANS_sub-C0159.npy
# Successfully save Chiba-CHBSRPB_sub-OCD152_filtered_0.01_0.1.npy file
# Successfully processed Chiba-CHBSRPB_sub-OCD152.npy
# Successfully save Kyoto-KPU-Kyoto3T_sub-subKyoto3Tsubj0036_filtered_0.01_0.1.npy file
# Successfully processed Kyoto-KPU-Kyoto3T_sub-subKyoto3Tsubj0036.npy
# Successfully save NYSPI-Columbia-Adults_sub-simpaocd167000_filtered_0.01_0.1.npy file
# Successfully processed NYSPI-Columbia-Adults_sub-simpaocd167000.npy
# Successfully save Braga-UMinho-Braga-1.5T-act_sub-MRI201208034OCD019_filtered_0.01_0.1.npy file
# Successfully processed Braga-UMinho-Braga-1.5T-act_sub-MRI201208034OCD019.npy
# Successfully save Bangalore-NIMHANS_sub-C0165_filtered_0.01_0.1.npy file
# Successfully processed Bangalore-NIMHANS_sub-C0165.npy
# Successfully save Cape-Town-UCT-Skyra_sub-CIMP141_filtered_0.01_0.1.npy file
# Successfully processed Cape-Town-UCT-Skyra_sub-CIMP141.npy
# Successfully save UCLA_sub-AOCD068_filtered_0.01_0.1.npy file
# Successfully processed UCLA_sub-AOCD068.npy
# Successfully save Dresden_sub-GEROME4016_filtered_0.01_0.1.npy file
# Successfully processed Dresden_sub-GEROME4016.npy
# Successfully save Barcelone-Bellvitge-PROV-1.5T_sub-subIDIBELL15277_filtered_0.01_0.1.npy file
# Successfully processed Barcelone-Bellvitge-PROV-1.5T_sub-subIDIBELL15277.npy
# Successfully save Cape-Town-UCT-Skyra_sub-CIMP149_filtered_0.01_0.1.npy file
# Successfully processed Cape-Town-UCT-Skyra_sub-CIMP149.npy
# Successfully save Barcelone-Bellvitge-PROV-1.5T_sub-subIDIBELL15262_filtered_0.01_0.1.npy file
# Successfully processed Barcelone-Bellvitge-PROV-1.5T_sub-subIDIBELL15262.npy
# Successfully save Yale-Pittinger-HCP-Trio_sub-YaleHCPTriota7832_filtered_0.01_0.1.npy file
# Successfully processed Yale-Pittinger-HCP-Trio_sub-YaleHCPTriota7832.npy
# Successfully save Bangalore-NIMHANS_sub-C0126_filtered_0.01_0.1.npy file
# Successfully processed Bangalore-NIMHANS_sub-C0126.npy
# Successfully save Yale-Gruner_sub-S2470VCI_filtered_0.01_0.1.npy file
# Successfully processed Yale-Gruner_sub-S2470VCI.npy
# Successfully save Yale-Pittinger-HCP-Trio_sub-YaleHCPTriota7806_filtered_0.01_0.1.npy file
# Successfully processed Yale-Pittinger-HCP-Trio_sub-YaleHCPTriota7806.npy
# Successfully save Bangalore-NIMHANS_sub-ODP209_filtered_0.01_0.1.npy file
# Successfully processed Bangalore-NIMHANS_sub-ODP209.npy
# Successfully save Dresden_sub-GEROME3042_filtered_0.01_0.1.npy file
# Successfully processed Dresden_sub-GEROME3042.npy
# Successfully save Shanghai-SMCH_sub-072_filtered_0.01_0.1.npy file
# Successfully processed Shanghai-SMCH_sub-072.npy
# Successfully save Barcelona-HCPB_sub-C0053_filtered_0.01_0.1.npy file
# Successfully processed Barcelona-HCPB_sub-C0053.npy
# Successfully save Braga-UMinho-Braga-1.5T-act_sub-MRI201506083OCD080_filtered_0.01_0.1.npy file
# Successfully processed Braga-UMinho-Braga-1.5T-act_sub-MRI201506083OCD080.npy
# Successfully save Barcelone-Bellvitge-ANTIGA-1.5T_sub-subIDIBELL15P52_filtered_0.01_0.1.npy file
# Successfully processed Barcelone-Bellvitge-ANTIGA-1.5T_sub-subIDIBELL15P52.npy
# Successfully save Bangalore-NIMHANS_sub-C0182_filtered_0.01_0.1.npy file
# Successfully processed Bangalore-NIMHANS_sub-C0182.npy
# Successfully save UCLA_sub-AOCD061_filtered_0.01_0.1.npy file
# Successfully processed UCLA_sub-AOCD061.npy
# Successfully save Yale-Pittinger-Yale-2014_sub-Yale2014AdultOCDtb0639_filtered_0.01_0.1.npy file
# Successfully processed Yale-Pittinger-Yale-2014_sub-Yale2014AdultOCDtb0639.npy
# Successfully save Bangalore-NIMHANS_sub-C0141_filtered_0.01_0.1.npy file
# Successfully processed Bangalore-NIMHANS_sub-C0141.npy
# Successfully save Chiba-CHBSRPB_sub-OCD139_filtered_0.01_0.1.npy file
# Successfully processed Chiba-CHBSRPB_sub-OCD139.npy
# Successfully save Shanghai-SMCH_sub-025_filtered_0.01_0.1.npy file
# Successfully processed Shanghai-SMCH_sub-025.npy
# Successfully save NYSPI-Columbia-Adults_sub-simpaocd567000_filtered_0.01_0.1.npy file
# Successfully processed NYSPI-Columbia-Adults_sub-simpaocd567000.npy
# Successfully save Chiba-CHB_sub-MADHC008_filtered_0.01_0.1.npy file
# Successfully processed Chiba-CHB_sub-MADHC008.npy
# Successfully save Barcelone-Bellvitge-RESP-CBT-3T_sub-RESPCBT05CTRPRE_filtered_0.01_0.1.npy file
# Successfully processed Barcelone-Bellvitge-RESP-CBT-3T_sub-RESPCBT05CTRPRE.npy
# Successfully save Kyoto-KPU-Kyoto3T_sub-subKyoto3Tsubj1017_filtered_0.01_0.1.npy file
# Successfully processed Kyoto-KPU-Kyoto3T_sub-subKyoto3Tsubj1017.npy
# Successfully save Braga-UMinho-Braga-1.5T-act_sub-MRI201603235OCD124_filtered_0.01_0.1.npy file
# Successfully processed Braga-UMinho-Braga-1.5T-act_sub-MRI201603235OCD124.npy
# Successfully save NYSPI-Columbia-Pediatric_sub-UAQEKH_filtered_0.01_0.1.npy file
# Successfully processed NYSPI-Columbia-Pediatric_sub-UAQEKH.npy
# Successfully save Brazil_sub-P00184120140908_filtered_0.01_0.1.npy file
# Successfully processed Brazil_sub-P00184120140908.npy
# Successfully save Barcelona-HCPB_sub-028_filtered_0.01_0.1.npy file
# Successfully processed Barcelona-HCPB_sub-028.npy
# Successfully save Bangalore-NIMHANS_sub-C0225_filtered_0.01_0.1.npy file
# Successfully processed Bangalore-NIMHANS_sub-C0225.npy
# Successfully save Yale-Pittinger-HCP-Prisma_sub-YaleHCPPrismapb1759_filtered_0.01_0.1.npy file
# Successfully processed Yale-Pittinger-HCP-Prisma_sub-YaleHCPPrismapb1759.npy
# Successfully save Bangalore-NIMHANS_sub-ODP026_filtered_0.01_0.1.npy file
# Successfully processed Bangalore-NIMHANS_sub-ODP026.npy
# Successfully save Bangalore-NIMHANS_sub-ODP071_filtered_0.01_0.1.npy file
# Successfully processed Bangalore-NIMHANS_sub-ODP071.npy
# Successfully save Seoul-SNU_sub-UMO15KHJ_filtered_0.01_0.1.npy file
# Successfully processed Seoul-SNU_sub-UMO15KHJ.npy
# Successfully save NYSPI-Columbia-Adults_sub-simpaocd227000_filtered_0.01_0.1.npy file
# Successfully processed NYSPI-Columbia-Adults_sub-simpaocd227000.npy
# Successfully save Kyoto-KPU-Kyoto1.5T_sub-subKyoto15Tsubj0141_filtered_0.01_0.1.npy file
# Successfully processed Kyoto-KPU-Kyoto1.5T_sub-subKyoto15Tsubj0141.npy
# Successfully save Bergen_sub-00028_filtered_0.01_0.1.npy file
# Successfully processed Bergen_sub-00028.npy
# Successfully save Braga-UMinho-Braga-1.5T-act_sub-MRI201306121OCD064_filtered_0.01_0.1.npy file
# Successfully processed Braga-UMinho-Braga-1.5T-act_sub-MRI201306121OCD064.npy
# Successfully save Bangalore-NIMHANS_sub-C0103_filtered_0.01_0.1.npy file
# Successfully processed Bangalore-NIMHANS_sub-C0103.npy
# Successfully save Amsterdam-VUmc_sub-916011_filtered_0.01_0.1.npy file
# Successfully processed Amsterdam-VUmc_sub-916011.npy
# Successfully save Amsterdam-VUmc_sub-916019_filtered_0.01_0.1.npy file
# Successfully processed Amsterdam-VUmc_sub-916019.npy
# Successfully save Bangalore-NIMHANS_sub-C0047_filtered_0.01_0.1.npy file
# Successfully processed Bangalore-NIMHANS_sub-C0047.npy
# Successfully save Kyoto-KPU-Kyoto3T_sub-subKyoto3Tsubj0006_filtered_0.01_0.1.npy file
# Successfully processed Kyoto-KPU-Kyoto3T_sub-subKyoto3Tsubj0006.npy
# Successfully save Kyoto-KPU-Kyoto3T_sub-subKyoto3Tsubj1041_filtered_0.01_0.1.npy file
# Successfully processed Kyoto-KPU-Kyoto3T_sub-subKyoto3Tsubj1041.npy
# Successfully save Barcelone-Bellvitge-PROV-1.5T_sub-subIDIBELL15216_filtered_0.01_0.1.npy file
# Successfully processed Barcelone-Bellvitge-PROV-1.5T_sub-subIDIBELL15216.npy
# Successfully save Bangalore-NIMHANS_sub-ODP076_filtered_0.01_0.1.npy file
# Successfully processed Bangalore-NIMHANS_sub-ODP076.npy
# Successfully save Brazil_sub-P00331820170705_filtered_0.01_0.1.npy file
# Successfully processed Brazil_sub-P00331820170705.npy
# Successfully save NYSPI-Columbia-Adults_sub-simpaocd337000_filtered_0.01_0.1.npy file
# Successfully processed NYSPI-Columbia-Adults_sub-simpaocd337000.npy
# Successfully save New-York_sub-subSEQ1NKISENR144_filtered_0.01_0.1.npy file
# Successfully processed New-York_sub-subSEQ1NKISENR144.npy
# Successfully save New-York_sub-subSEQ1NKISENR122_filtered_0.01_0.1.npy file
# Successfully processed New-York_sub-subSEQ1NKISENR122.npy
# Successfully save Barcelone-Bellvitge-ANTIGA-1.5T_sub-subIDIBELL15P07_filtered_0.01_0.1.npy file
# Successfully processed Barcelone-Bellvitge-ANTIGA-1.5T_sub-subIDIBELL15P07.npy
# Successfully save Yale-Pittinger-HCP-Prisma_sub-YaleHCPPrismapb1020_filtered_0.01_0.1.npy file
# Successfully processed Yale-Pittinger-HCP-Prisma_sub-YaleHCPPrismapb1020.npy
# Successfully save Barcelone-Bellvitge-RESP-CBT-3T_sub-RESPCBT17CTRPRE_filtered_0.01_0.1.npy file
# Successfully processed Barcelone-Bellvitge-RESP-CBT-3T_sub-RESPCBT17CTRPRE.npy
# Successfully save Seoul-SNU_sub-UMO63KSY_filtered_0.01_0.1.npy file
# Successfully processed Seoul-SNU_sub-UMO63KSY.npy
# Successfully save Bangalore-NIMHANS_sub-ODP196_filtered_0.01_0.1.npy file
# Successfully processed Bangalore-NIMHANS_sub-ODP196.npy
# Successfully save Cape-Town-UCT-Skyra_sub-ESC030_filtered_0.01_0.1.npy file
# Successfully processed Cape-Town-UCT-Skyra_sub-ESC030.npy
# Successfully save Brazil_sub-P00247120151005_filtered_0.01_0.1.npy file
# Successfully processed Brazil_sub-P00247120151005.npy
# Successfully save Barcelone-Bellvitge-PROV-1.5T_sub-subIDIBELL15249_filtered_0.01_0.1.npy file
# Successfully processed Barcelone-Bellvitge-PROV-1.5T_sub-subIDIBELL15249.npy
# Successfully save Chiba-CHBC_sub-OCDC057_filtered_0.01_0.1.npy file
# Successfully processed Chiba-CHBC_sub-OCDC057.npy
# Successfully save NYSPI-Columbia-Pediatric_sub-WDFIFG_filtered_0.01_0.1.npy file
# Successfully processed NYSPI-Columbia-Pediatric_sub-WDFIFG.npy
# Successfully save Chiba-CHBSRPB_sub-MADHC045_filtered_0.01_0.1.npy file
# Successfully processed Chiba-CHBSRPB_sub-MADHC045.npy
# Successfully save Barcelone-Bellvitge-PROV-1.5T_sub-subIDIBELL15201_filtered_0.01_0.1.npy file
# Successfully processed Barcelone-Bellvitge-PROV-1.5T_sub-subIDIBELL15201.npy
# Successfully save Yale-Pittinger-Yale-2014_sub-Yale2014AdultOCDtr9515_filtered_0.01_0.1.npy file
# Successfully processed Yale-Pittinger-Yale-2014_sub-Yale2014AdultOCDtr9515.npy
# Successfully save New-York_sub-subSEQ1NKISENR173_filtered_0.01_0.1.npy file
# Successfully processed New-York_sub-subSEQ1NKISENR173.npy
# Successfully save Kyoto-KPU-Kyoto1.5T_sub-subKyoto15Tsubj1039_filtered_0.01_0.1.npy file
# Successfully processed Kyoto-KPU-Kyoto1.5T_sub-subKyoto15Tsubj1039.npy
# Successfully save UCLA_sub-AOCD025_filtered_0.01_0.1.npy file
# Successfully processed UCLA_sub-AOCD025.npy
# Successfully save Bangalore-NIMHANS_sub-C0130_filtered_0.01_0.1.npy file
# Successfully processed Bangalore-NIMHANS_sub-C0130.npy
# Successfully save Braga-UMinho-Braga-1.5T_sub-MRI201508122OCD087_filtered_0.01_0.1.npy file
# Successfully processed Braga-UMinho-Braga-1.5T_sub-MRI201508122OCD087.npy
# Successfully save Bangalore-NIMHANS_sub-ODP233_filtered_0.01_0.1.npy file
# Successfully processed Bangalore-NIMHANS_sub-ODP233.npy
# Successfully save Bangalore-NIMHANS_sub-ODP025_filtered_0.01_0.1.npy file
# Successfully processed Bangalore-NIMHANS_sub-ODP025.npy
# Successfully save Barcelona-HCPB_sub-023_filtered_0.01_0.1.npy file
# Successfully processed Barcelona-HCPB_sub-023.npy
# Successfully save NYSPI-Columbia-Adults_sub-simpaocd507000_filtered_0.01_0.1.npy file
# Successfully processed NYSPI-Columbia-Adults_sub-simpaocd507000.npy
# Successfully save Barcelona-HCPB_sub-103_filtered_0.01_0.1.npy file
# Successfully processed Barcelona-HCPB_sub-103.npy
# ...
# Successfully processed UCLA_sub-AOCD043.npy
# Successfully save Braga-UMinho-Braga-1.5T-act_sub-MRI201303202OCD047_filtered_0.01_0.1.npy file
# Successfully processed Braga-UMinho-Braga-1.5T-act_sub-MRI201303202OCD047.npy
# Successfully save Bangalore-NIMHANS_sub-ODP188_filtered_0.01_0.1.npy file
# Successfully processed Bangalore-NIMHANS_sub-ODP188.npy
# Successfully save Yale-Pittinger-Yale-2014_sub-Yale2014AdultOCDtb0195_filtered_0.01_0.1.npy file
# Successfully processed Yale-Pittinger-Yale-2014_sub-Yale2014AdultOCDtb0195.npy
# Successfully save Braga-UMinho-Braga-3T_sub-MRI201906171BART009_filtered_0.01_0.1.npy file
# Successfully processed Braga-UMinho-Braga-3T_sub-MRI201906171BART009.npy
# Successfully save Brazil_sub-P00203820150127_filtered_0.01_0.1.npy file
# Successfully processed Brazil_sub-P00203820150127.npy
# Successfully save Yale-Pittinger-Yale-2014_sub-Yale2014AdultOCDtb1366_filtered_0.01_0.1.npy file
# Successfully processed Yale-Pittinger-Yale-2014_sub-Yale2014AdultOCDtb1366.npy
# Successfully save Yale-Pittinger-HCP-Trio_sub-YaleHCPTriopb2759_filtered_0.01_0.1.npy file
# Successfully processed Yale-Pittinger-HCP-Trio_sub-YaleHCPTriopb2759.npy
# Successfully save Amsterdam-VUmc_sub-916008_filtered_0.01_0.1.npy file
# Successfully processed Amsterdam-VUmc_sub-916008.npy
# Successfully save Shanghai-SMCH_sub-015_filtered_0.01_0.1.npy file
# Successfully processed Shanghai-SMCH_sub-015.npy
# Successfully save Vancouver-BCCHR_sub-072_filtered_0.01_0.1.npy file
# Successfully processed Vancouver-BCCHR_sub-072.npy
# Successfully save Vancouver-BCCHR_sub-055_filtered_0.01_0.1.npy file
# Successfully processed Vancouver-BCCHR_sub-055.npy
# Successfully save Yale-Gruner_sub-S8618ECE_filtered_0.01_0.1.npy file
# Successfully processed Yale-Gruner_sub-S8618ECE.npy
# Successfully save Yale-Pittinger-Yale-2014_sub-Yale2014AdultOCDtr7733_filtered_0.01_0.1.npy file
# Successfully processed Yale-Pittinger-Yale-2014_sub-Yale2014AdultOCDtr7733.npy
# Successfully save Bangalore-NIMHANS_sub-ODP072_filtered_0.01_0.1.npy file
# Successfully processed Bangalore-NIMHANS_sub-ODP072.npy
# Successfully save Bangalore-NIMHANS_sub-C0119_filtered_0.01_0.1.npy file
# Successfully processed Bangalore-NIMHANS_sub-C0119.npy
# Successfully save Braga-UMinho-Braga-1.5T-act_sub-MRI201303182OCD046_filtered_0.01_0.1.npy file
# Successfully processed Braga-UMinho-Braga-1.5T-act_sub-MRI201303182OCD046.npy
# Successfully save Bangalore-NIMHANS_sub-C0010_filtered_0.01_0.1.npy file
# Successfully processed Bangalore-NIMHANS_sub-C0010.npy
# Successfully save Bangalore-NIMHANS_sub-C0217_filtered_0.01_0.1.npy file
# Successfully processed Bangalore-NIMHANS_sub-C0217.npy
# Successfully save Barcelone-Bellvitge-RESP-CBT-3T_sub-RESPCBT28CTRPRE_filtered_0.01_0.1.npy file
# Successfully processed Barcelone-Bellvitge-RESP-CBT-3T_sub-RESPCBT28CTRPRE.npy
# Successfully save Barcelone-Bellvitge-ANTIGA-1.5T_sub-subIDIBELL15C095_filtered_0.01_0.1.npy file
# Successfully processed Barcelone-Bellvitge-ANTIGA-1.5T_sub-subIDIBELL15C095.npy
# Successfully save Bergen_sub-00013_filtered_0.01_0.1.npy file
# Successfully processed Bergen_sub-00013.npy
# Successfully save Braga-UMinho-Braga-3T_sub-MRI20200717BART061_filtered_0.01_0.1.npy file
# Successfully processed Braga-UMinho-Braga-3T_sub-MRI20200717BART061.npy
# Successfully save Shanghai-SMCH_sub-076_filtered_0.01_0.1.npy file
# Successfully processed Shanghai-SMCH_sub-076.npy
# Successfully save Barcelone-Bellvitge-ANTIGA-1.5T_sub-subIDIBELL15C003_filtered_0.01_0.1.npy file
# Successfully processed Barcelone-Bellvitge-ANTIGA-1.5T_sub-subIDIBELL15C003.npy
# Successfully save Kyoto-KPU-Kyoto3T_sub-subKyoto3Tsubj0029_filtered_0.01_0.1.npy file
# Successfully processed Kyoto-KPU-Kyoto3T_sub-subKyoto3Tsubj
827680329634308, 0.0790618532782244, 0.06720211184255226, 0.0504826241857032, 0.07075499988305656, 0.061892444692658276, 0.0741710835158688, 0.06072593112770303, 0.058960885131814064, 0.07377110540409677, 0.05679768116550317, 0.07135553873167266, 0.051454739234752134, 0.07664118826164155, 0.06763079164745876], 'Yale-Pittinger-HCP-Prisma': [0.0585903156044986, 0.07230374419211641, 0.06929627809325388, 0.06483291984684388, 0.05326824270471736, 0.05930404247664873, 0.06057232919389802, 0.06844659552946356, 0.04784780867423122, 0.05783291405031517, 0.053525622221310284, 0.06230129448612946, 0.06125376089216774, 0.06363938065906065, 0.03096815872089639, 0.06183337441531454, 0.050849691430144055, 0.07195086191731145, 0.08418695080127037, 0.07342966030044315, 0.0745364821411991, 0.059888774195972286, 0.06204614817259299, 0.07629211523089334, 0.0689978567719231, 0.04820717523160525, 0.06313674655019301, 0.06485147925772976, 0.0582775834293648, 0.05476161115676865 ...
#
# Knee frequencies f2: {'Barcelona-HCPB': [0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16], 'Brazil': [0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16], 'Yale-Pittinger-HCP-Prisma': [0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16], 'Seoul-SNU': [0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16], 'Dresden': [0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16], 'Bergen': [0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16], 'Bangalore-NIMHANS': [0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0.16, 0 ...
# Sequence lengths: {'Barcelona-HCPB': [240, 240, 240, 240, 240, 240, 240, 240, 240, 240, 240, 240, 240, 240, 240, 240, 240, 240, 240, 240, 240, 240, 240, 240, 240, 240, 240, 240, 240, 240, 240, 240, 240, 240, 240, 240, 240, 240, 240, 240, 240, 240, 240, 240, 240, 240, 240, 240, 240, 240, 240, 240, 240, 240, 240, 240, 240, 240, 240, 240, 240, 240, 240, 240], 'Brazil': [130, 130, 130, 130, 130, 130, 130, 130, 130, 130, 130, 130, 130, 130, 130, 130, 130, 130, 130, 130, 130, 130, 130, 130, 130, 130, 130, 130, 130, 130, 130, 130, 130, 130, 130, 130, 130, 130, 130, 130, 130, 130, 130, 130, 130, 130, 130, 130, 130, 130, 130, 130, 130, 130, 130, 130, 130, 130, 130, 130, 130, 130, 130, 130, 130, 130, 130, 130, 130, 130, 130, 130, 130, 130, 130, 130, 130, 130, 130, 130, 130, 130, 130, 130, 130, 130, 130, 130, 130, 130, 130, 130, 130], 'Yale-Pittinger-HCP-Prisma': [770, 770, 770, 770, 770, 770, 770, 770, 770, 770, 770, 770, 770, 770, 770, 770, 770, 770, 770, 770, 770, 770, 770, 770, 770, 770, 770, 770, 770, 770, 770, 770, 770, 770, 770, 770, 770, 770, 770, 770, 770, 770, 770, 770, 770, 770, 770, 770, 770, 770, 770, 770, 770, 770, 770, 770, 770, 770, 770, 770, 770], 'Seoul-SNU': [112, 112, 112, 112, 112, 112, 112, 112, 112, 112, 112, 112, 112, 112, 112, 112, 112, 112, 112, 112, 112, 112, 112, 112, 112, 112, 112, 112, 112, 112, 112, 112, 112, 112, 112, 112, 112, 112, 112, 112, 112, 112, 112, 112, 112, 112, 112, 112, 112, 112, 112, 112, 112, 112, 112, 112, 112, 112, 112, 112, 112, 112, 112, 112, 112, 112, 112, 112, 112, 112, 112, 112, 112, 112, 112, 112, 112, 112, 112, 112, 112, 112, 112, 112, 112, 112, 112, 112, 112, 112, 112, 112, 112, 112, 112], 'Dresden': [840, 840, 840, 840, 840, 840, 840, 840, 840, 840, 840, 840, 840, 844, 840, 840, 840, 840, 840, 840, 840, 840, 840, 840, 840, 840, 840, 840, 840, 840, 840, 840, 840, 840, 840], 'Bergen': [160, 160, 160, 160, 160, 160, 160, 160, 160, 160, 160, 160, 160, 160, 160, 160, 160, 160, 160, 160, 160, 160, 160, 160, 160, 160, 160, 160, 160, 160, 160, 160, 160, 160, 160, 160, 160, 160, 160, 160, 160, 160, 160, 160, 160, 160, 160, 160, 160, 160, 160, 160, 160], 'Bangalore-NIMHANS': [153, 153, 153, 153, 153, 303, 303, 153, 153, 153, 303, 153, 153, 303, 153, 153, 153, 153, 153, 153, 153, 153, 153, 153, 153, 153, 153, 153, 153, 153, 153, 153, 153, 153, 153, 153, 303, 153, 303, 153, 153, 303, 153, 153, 153, 153, 153, 153, 153, 153, 153, 153, 303, 153, 153, 153, 153, 153, 153, 153, 303, 153, 153, 153, 153, 153, 153, 153, 303, 153, 303, 153, 153, 153, 153, 153, 303, 153, 153, 153, 303, 153, 303, 153, 153, 153, 153, 152, 153, 303, 153, 153, 303, 153, 153, 153, 153, 153, 153, 153, 153, 153, 153, 153, 153, 153, 153, 153, 153, 153, 153, 153, 303, 153, 153, 153, 153, 153, 153, 153, 153, 153, 153, 153, 153, 153, 303, 153, 153, 153, 153, 153, 153, 153, 153, 153, 153, 153, 153, 303, 153, 153, 153, 153, 303, 153, 153, 153, 153, 303, 153, 153, 303, 153, 153, 153, 153, 153, 153, 153, 153, 153, 153, 153, 153, 153, 153, 153, 153, 153, 303, 153, 153, 153, 153, 303, 153, 303, 153, 153, 153, 153, 153, 303, 153, 303, 153, 153, 303, 303, 153, 153, 153, 153, 221, 303, 153, 153, 153, 153, 153, 153, 153, 153, 153, 153, 153, 153, 153, 153, 153, 153, 303, 153, 303, 153, 303, 153, 153, 153, 153, 153, 153, 153, 153, 153, 153, 153, 153, 303, 153, 153, 303, 153, 153, 153, 153, 153, 153, 153, 153, 153, 303, 153, 303, 153, 150, 153, 153, 153, 153, 153, 153, 153, 153, 303, 303, 153, 303, 153, 303, 303, 153, 153, 303, 153, 153, 153, 153, 153, 153, 153, 303, 153, 153, 153, 303, 303, 153, 303, 153, 153, 153, 153, 153, 153, 153, 153, 153, 153, 153, 303, 153, 153, 153, 153, 303, 153, 153, 303, 153, 153, 153, 153, 153, 153, 153, 153, 153, 303, 153, 153, 153, 153, 153, 153, 303, 153, 303, 153, 153, 153, 153, 153, 153, 153, 153, 153, 153, 303, 153, 153, 153, 153, 153, 303, 153, 153, 153, 153, 153, 153, 303, 153, 153, 153, 153, 153, 153, 153, 153, 153, 153, 153, 153, 306, 153, 303], 'Barcelone-Bellvitge-PROV-1.5T': [120, 120, 120, 120, 120, 1 ...
# Error processing 0 files

# %%
y = np.load("/pscratch/sd/p/pakmasha/MBBN_data/Amsterdam-VUmc_sub-916002/Amsterdam-VUmc_sub-916002.npy")
print(f"Original data shape: {y.shape}")

y = np.load("/pscratch/sd/p/pakmasha/MBBN_data/Amsterdam-VUmc_sub-916002/Amsterdam-VUmc_sub-916002_filtered_0.01_0.1.npy")
print(f"Filtered data shape: {y.shape}")
# Out:
# Original data shape: (197, 316)
# Filtered data shape: (197, 316)

# %%
# Summarize the data
data = []
for key in f1_dict.keys():
    f1_values = f1_dict[key]
    f2_values = f2_dict[key]
    seq_len_values = seq_len_dict[key]
    
    data.append({
        "key": key,
        "mean_f1": sum(f1_values) / len(f1_values) if f1_values else 0,
        "count_f1": len(f1_values),
        "mean_f2": sum(f2_values) / len(f2_values) if f2_values else 0,
        "count_f2": len(f2_values),
        "mean_seq_len": sum(seq_len_values) / len(seq_len_values) if seq_len_values else 0
    })

# Create DataFrame
df = pd.DataFrame(data)

# Display the DataFrame
print(df)
print(f"\nTotal of {sum(df['count_f1'])} subjects")
# Out:
#                                 key   mean_f1  count_f1  mean_f2  count_f2  \
# 0                    Barcelona-HCPB  0.069746        64     0.16        64
# 1                            Brazil  0.067479        93     0.16        93
# 2         Yale-Pittinger-HCP-Prisma  0.061466        61     0.16        61
# 3                         Seoul-SNU  0.080110        95     0.16        95
# 4                           Dresden  0.062914        35     0.16        35
# 5                            Bergen  0.065793        53     0.16        53
# 6                 Bangalore-NIMHANS  0.065805       358     0.16       358
# 7     Barcelone-Bellvitge-PROV-1.5T  0.067083        64     0.16        64
# 8   Barcelone-Bellvitge-ANTIGA-1.5T  0.066294       137     0.16       137
# 9                         Chiba-CHB  0.065882        42     0.16        42
# 10         Yale-Pittinger-Yale-2014  0.064755        85     0.16        85
# 11            Braga-UMinho-Braga-3T  0.067584        59     0.16        59
# 12  Barcelone-Bellvitge-RESP-CBT-3T  0.068383        57     0.16        57
# 13                    Chiba-CHBSRPB  0.071260        89     0.16        89
# 14                      Yale-Gruner  0.049251        29     0.16        29
# 15            NYSPI-Columbia-Adults  0.053945        70     0.16        70
# 16                   Amsterdam-VUmc  0.067818        57     0.16        57
# 17      Braga-UMinho-Braga-1.5T-act  0.065612        96     0.16        96
# 18                    Shanghai-SMCH  0.074956        84     0.16        84
# 19              Cape-Town-UCT-Skyra  0.064437        39     0.16        39
# 20         NYSPI-Columbia-Pediatric  0.055240        34     0.16        34
# 21          Braga-UMinho-Braga-1.5T  0.064257        46     0.16        46
# 22                  Vancouver-BCCHR  0.067043        45     0.16        45
# 23                         New-York  0.066525        60     0.16        60
# 24              Kyoto-KPU-Kyoto1.5T  0.070775        25     0.16        25
# 25                Kyoto-KPU-Kyoto3T  0.068836        70     0.16        70
# 26          Yale-Pittinger-HCP-Trio  0.060154        43     0.16        43
# 27                             UCLA  0.065078        51     0.16        51
# 28                       Chiba-CHBC  0.069764        53     0.16        53
#
#     mean_seq_len
# 0     240.000000
# 1     130.000000
# 2     770.000000
# 3     112.000000
# 4     840.114286
# 5     160.000000
# 6     177.488827
# 7     120.000000
# 8     120.467153
# 9     196.000000
# 10    299.000000
# 11    720.000000
# 12    240.000000
# 13    239.000000
# 14    150.000000
# 15    528.785714
# 16    197.210526
# 17    179.906250
# 18    170.000000
# 19    298.000000
# 20    526.352941
# 21    180.000000
# 22    150.000000
# 23    480.000000
# 24    195.000000
# 25    194.000000
# 26    500.000000
# 27    208.000000
# 28    196.000000
#
# Total of 2094 subjects

# %% [markdown]
# ### Check the number of valid subjects depending on the sequence length (SKIP for now)

# %%
# Define the base path where the .tsv files are stored
base_path = '/pscratch/sd/p/pakmasha/MBBN_data'

# Create a dictionary to store knee values for each site
f1_dict = {}
f2_dict = {}
seq_len_dict = {}
error_count = 0

# Walk through all subdirectories and process .npy files
for root, dirs, files in os.walk(base_path):
    for file in files:
        if file.endswith('_smoothed_4mm.npy'):
            # Construct full path to the .tsv file
            npy_file_path = os.path.join(root, file)
            # print(f"npy_file_path: {npy_file_path}")

            # Calculate the repetition time (TR) depending on the site
            site = file.split('_')[-4]
            if 'Amsterdam-AMC' in site:
                TR = 2.375
            elif 'Amsterdam-VUmc' in site:
                TR = 1.8
            elif 'Barcelona-HCPB' in site:
                TR = 2
            elif 'Bergen' in site:
                TR = 1.8
            elif 'Braga-UMinho-Braga-1.5T' in site:
                TR = 2
            elif 'Braga-UMinho-Braga-1.5T-act' in site:
                TR = 2
            elif 'Braga-UMinho-Braga-3T' in site:
                TR = 1
            elif 'Brazil' in site:
                TR = 2
            elif 'Cape-Town-UCT-Allegra' in site:
                TR = 1.6
            elif 'Cape-Town-UCT-Skyra' in site:
                TR = 1.73
            elif 'Chiba-CHB' in site:
                TR = 2.3
            elif 'Chiba-CHBC' in site:
                TR = 2.3 
            elif 'Chiba-CHBSRPB' in site:
                TR = 2.5 
            elif 'Dresden' in site:
                TR = 0.8 
            elif 'Kyoto-KPU-Kyoto1.5T' in site:
                TR = 2.411 
            elif 'Kyoto-KPU-Kyoto3T' in site:
                TR = 2
            elif 'Kyushu' in site:
                TR = 2.5
            elif 'Milan-HSR' in site:
                TR = 2
            elif 'New-York' in site:
                TR = 1
            elif 'NYSPI-Columbia-Adults' in site:
                TR = 0.85
            elif 'NYSPI-Columbia-Pediatric' in site:
                TR = 0.85
            elif 'Yale-Pittinger-HCP-Prisma' in site:
                TR = 0.8
            elif 'Yale-Pittinger-HCP-Trio' in site:
                TR = 0.7
            elif 'Yale-Pittinger-Yale-2014' in site:
                TR = 2
            elif 'Bangalore-NIMHANS' in site:
                TR = 2 
            elif 'Barcelone-Bellvitge-ANTIGA-1.5T' in site:
                TR = 2
            elif 'Barcelone-Bellvitge-COMPULSE-3T' in site:
                TR = 2
            elif 'Barcelone-Bellvitge-PROV-1.5T' in site:
                TR = 2
            elif 'Barcelone-Bellvitge-RESP-CBT-3T' in site:
                TR = 2
            elif 'Seoul-SNU' in site:
                TR = 3.5
            elif 'Shanghai-SMCH' in site:
                TR = 3
            elif 'UCLA' in site:
                TR = 2
            elif 'Vancouver-BCCHR' in site:
                TR = 2
            elif 'Yale-Gruner' in site:
                TR = 2
            else:
                raise ValueError(f"Site '{site}' does not have a defined TR value in TR_mappings. Please add it.")

            # Load the .npy file and calculate knee frequencies
            sequence_length = 100
            y = np.load(npy_file_path)[20:20+sequence_length].T   
            # print(f"y: {y}")
            # print(f"y.shape: {y.shape}")

            try: 
                fs = 1 / TR  # Sampling frequency in Hz
                lowcut = 0.01  # Low cutoff frequency in Hz
                highcut = 0.1  # High cutoff frequency in Hz

                # Apply the filter to each row (ROI) in the 2D array `y`
                y = np.array([bandpass_filter(roi, lowcut, highcut, fs) for roi in y])

                sample_whole = np.zeros(sequence_length,) # originally sequence_length   ## aggregates time-series data across ROIs   # sample_whole.shape = # of timepoints,

                ##### DEBUG STATEMENT #####
                # sample_whole = np.zeros(sequence_length - 20,)
                # print(f"sample_whole.shape: {sample_whole.shape}")
                ###########################

                intermediate_vec = y.shape[0]

                for i in range(intermediate_vec):
                    # print(f"y[i] shape: {y[i].shape}")
                    sample_whole+=y[i]

                sample_whole /= intermediate_vec    # averages the time-series signals (y) across a set number of ROIs

                # Smooth the averaged time series
                # fwhm = 2
                # smoothed_sample_whole = gaussian_smoothing_with_fwhm(sample_whole, fwhm)
                sample_whole = sample_whole

                T = TimeSeries(sample_whole, sampling_interval=TR)  # computes power spectral density (PSD) of the averaged time-series signal
                S_original = SpectralAnalyzer(T)

                # Lorentzian function fitting (dividing ultralow ~ low)  ## extracts the PSD data
                xdata = np.array(S_original.spectrum_fourier[0][1:])  # xdata = frequency values  
                ydata = np.abs(S_original.spectrum_fourier[1][1:])    # ydata = corresponding power values
                # print(f"xdata.shape: {xdata.shape}")
                # print(f"ydata.shape: {ydata.shape}")

                # initial parameter setting
                p0 = [0, 0.006]   
                param_bounds = ([-np.inf, 0], [np.inf, 1])

                # fitting Lorentzian function
                popt, pcov = curve_fit(lorentzian_function, xdata, ydata, p0=p0, maxfev = 5000, bounds=param_bounds)   # popt = optimal parameters

                f1 = popt[1]

                knee = round(popt[1]/(1/(sample_whole.shape[0]*TR)))   # calculates knee frequency 
                # print(f"knee: {knee}")

                if knee <= 0:
                    knee = 1

                if knee > ydata.shape[0]:
                    print(f"knee value: {knee}")
                    print(f"ydata.shape: {ydata.shape}")

                # divide low ~ high
                # initial parameter setting
                p1 = [2, 1, 23, 25, 0.16]
            
                # fitting multifractal function
                popt_mo, pcov = curve_fit(multi_fractal_function, xdata[knee:], ydata[knee:], p0=p1, maxfev = 50000)   # fits a multi-fractal model to the high-frequency range (above the knee)
                pink = round(popt_mo[-1]/(1/(sample_whole.shape[0]*TR)))   # pink = an additional boundary
                f2 = popt_mo[-1]

                # Save values to the dictionaries
                # Check if the key exists in the dictionary
                if site in f1_dict:
                    # Append the value to the existing list
                    f1_dict[site].append(f1)
                    f2_dict[site].append(f2)
                    seq_len_dict[site].append(sequence_length)
                else:
                    # Create the key and initialize it with a list containing the value
                    f1_dict[site] = [f1]
                    f2_dict[site] = [f2]   
                    seq_len_dict[site] = [sequence_length] 
                print(f"Successfully processed {file}")  
            except Exception as e:
                print(f"Error processing: {file}")
                print(e)
                error_count += 1
                continue  # Skip the subject if an error occurs
            
print(f"Knee frequencies f1: {f1_dict}")
print(f"\nKnee frequencies f2: {f2_dict}")
print(f"Sequence lengths: {seq_len_dict}")
print(f"Error processing {error_count} files")
# Out:
# /tmp/ipykernel_808400/1867528834.py:2: RuntimeWarning: overflow encountered in power
#   return np.where(x < corner, A * x**beta_low, B * x**beta_high)
# /tmp/ipykernel_808400/1867528834.py:2: RuntimeWarning: overflow encountered in multiply
#   return np.where(x < corner, A * x**beta_low, B * x**beta_high)
# /tmp/ipykernel_808400/2934793644.py:151: OptimizeWarning: Covariance of the parameters could not be estimated
#   popt_mo, pcov = curve_fit(multi_fractal_function, xdata[knee:], ydata[knee:], p0=p1, maxfev = 50000)   # fits a multi-fractal model to the high-frequency range (above the knee)
# Successfully processed Barcelona-HCPB_sub-008_smoothed_4mm.npy
# Successfully processed Brazil_sub-C002061_smoothed_4mm.npy
# Successfully processed Yale-Pittinger-HCP-Prisma_sub-YaleHCPPrismapb3225_smoothed_4mm.npy
# Error processing: Seoul-SNU_sub-NOR117CSJ_smoothed_4mm.npy
# operands could not be broadcast together with shapes (100,) (92,) (100,)
# Successfully processed Dresden_sub-GEROME3073_smoothed_4mm.npy
# Successfully processed Bergen_sub-00059_smoothed_4mm.npy
# Successfully processed Bangalore-NIMHANS_sub-C0181_smoothed_4mm.npy
# Successfully processed Bangalore-NIMHANS_sub-C0128_smoothed_4mm.npy
# Error processing: Seoul-SNU_sub-DNO23LSM_smoothed_4mm.npy
# operands could not be broadcast together with shapes (100,) (92,) (100,)
# Successfully processed Bangalore-NIMHANS_sub-ODP004_smoothed_4mm.npy
# Successfully processed Bangalore-NIMHANS_sub-ODP203_smoothed_4mm.npy
# Successfully processed Barcelone-Bellvitge-PROV-1.5T_sub-subIDIBELL15224_smoothed_4mm.npy
# Successfully processed Barcelone-Bellvitge-ANTIGA-1.5T_sub-subIDIBELL15C032_smoothed_4mm.npy
# Successfully processed Bangalore-NIMHANS_sub-ODP099_smoothed_4mm.npy
# Successfully processed Chiba-CHB_sub-MADHC010_smoothed_4mm.npy
# Successfully processed Yale-Pittinger-Yale-2014_sub-Yale2014AdultOCDtr7977_smoothed_4mm.npy
# Successfully processed Bergen_sub-00066_smoothed_4mm.npy
# Successfully processed Yale-Pittinger-Yale-2014_sub-Yale2014AdultOCDtb
100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100], 'Bergen': [100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100], 'Bangalore-NIMHANS': [100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100], 'Barcelone-Bellvitge-PROV-1.5T': [100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100], 'Barcelone-Bellvitge-ANTIGA-1.5T': [100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, ...
# Error processing 96 files

# %%
# Summarize the data
data = []
for key in f1_dict.keys():
    f1_values = f1_dict[key]
    f2_values = f2_dict[key]
    seq_len_values = seq_len_dict[key]
    
    data.append({
        "key": key,
        "mean_f1": sum(f1_values) / len(f1_values) if f1_values else 0,
        "count_f1": len(f1_values),
        "mean_f2": sum(f2_values) / len(f2_values) if f2_values else 0,
        "count_f2": len(f2_values),
        "mean_seq_len": sum(seq_len_values) / len(seq_len_values) if seq_len_values else 0
    })

# Create DataFrame
df = pd.DataFrame(data)

# Display the DataFrame
print(df)
print(f"\nTotal of {sum(df['count_f1'])} subjects")
# Out:
#                                 key   mean_f1  count_f1  mean_f2  count_f2  \
# 0                    Barcelona-HCPB  0.035169        64     0.16        64
# 1                            Brazil  0.036814        93     0.16        93
# 2         Yale-Pittinger-HCP-Prisma  0.061213        61     0.16        61
# 3                           Dresden  0.059800        35     0.16        35
# 4                            Bergen  0.035305        58     0.16        58
# 5                 Bangalore-NIMHANS  0.037332       358     0.16       358
# 6     Barcelone-Bellvitge-PROV-1.5T  0.037758        62     0.16        62
# 7   Barcelone-Bellvitge-ANTIGA-1.5T  0.037059       131     0.16       131
# 8                         Chiba-CHB  0.024788        44     0.16        44
# 9          Yale-Pittinger-Yale-2014  0.035559        85     0.16        85
# 10            Braga-UMinho-Braga-3T  0.064156        56     0.16        56
# 11  Barcelone-Bellvitge-RESP-CBT-3T  0.029350        57     0.16        57
# 12                    Chiba-CHBSRPB  0.027045        92     0.16        92
# 13                      Yale-Gruner  0.032567        27     0.16        27
# 14            NYSPI-Columbia-Adults  0.068645        70     0.16        70
# 15      Braga-UMinho-Braga-1.5T-act  0.027690        96     0.16        96
# 16                    Shanghai-SMCH  0.024802        82     0.16        82
# 17              Cape-Town-UCT-Skyra  0.035053        39     0.16        39
# 18         NYSPI-Columbia-Pediatric  0.069000        34     0.16        34
# 19          Braga-UMinho-Braga-1.5T  0.029736        46     0.16        46
# 20                  Vancouver-BCCHR  0.033947        45     0.16        45
# 21                         New-York  0.061508        60     0.16        60
# 22              Kyoto-KPU-Kyoto1.5T  0.024721        25     0.16        25
# 23                   Amsterdam-VUmc  0.033985        57     0.16        57
# 24                Kyoto-KPU-Kyoto3T  0.023459        70     0.16        70
# 25          Yale-Pittinger-HCP-Trio  0.082604        42     0.16        42
# 26                             UCLA  0.034437        51     0.16        51
# 27                       Chiba-CHBC  0.028789        57     0.16        57
#
#     mean_seq_len
# 0          100.0
# 1          100.0
# 2          100.0
# 3          100.0
# 4          100.0
# 5          100.0
# 6          100.0
# 7          100.0
# 8          100.0
# 9          100.0
# 10         100.0
# 11         100.0
# 12         100.0
# 13         100.0
# 14         100.0
# 15         100.0
# 16         100.0
# 17         100.0
# 18         100.0
# 19         100.0
# 20         100.0
# 21         100.0
# 22         100.0
# 23         100.0
# 24         100.0
# 25         100.0
# 26         100.0
# 27         100.0
#
# Total of 1997 subjects
