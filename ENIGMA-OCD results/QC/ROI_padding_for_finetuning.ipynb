# %% [markdown]
# ### Libraries

# %%
import numpy as np
import torch
import torch.nn.functional as F
import pandas as pd
import os

# %% [markdown]
# ### Load and transpose the time-series file

# %%
seq_len = 100
file = np.load("/pscratch/sd/p/pakmasha/MBBN_data/Amsterdam-VUmc_sub-916002/Amsterdam-VUmc_sub-916002_filtered_0.01_0.1.npy")[20:20+seq_len].T
print(file.shape)
# Out:
# (316, 100)

# %% [markdown]
# ### Create a mapping of indices where padding should be inserted

# %% [markdown]
# ##### Load the full list of Schaefer labels

# %%
# Load the look-up table
roi_lut = pd.read_csv("/global/homes/p/pakmasha/ENIGMA-OCD results/QC/all_regions_Schaefer2018_400Parcels_17Networks_LUT.csv", sep=",")
print(roi_lut.head())

# Save the ROI names
roi_names = roi_lut['Schaeffer_Yeon_labels'].values
# Out:
#    roi_ID        R         G         B          Schaeffer_Yeon_labels  \
# 0       1  0.47059  0.070588  0.535294  17Networks_LH_VisCent_ExStr_1
# 1       2  0.47059  0.070588  0.535294  17Networks_LH_VisCent_ExStr_2
# 2       3  0.47059  0.070588  0.535294  17Networks_LH_VisCent_ExStr_3
# 3       4  0.47059  0.070588  0.535294  17Networks_LH_VisCent_ExStr_4
# 4       5  0.47059  0.070588  0.535294  17Networks_LH_VisCent_ExStr_5
#
#                  halfpipe_labels Schaeffer_Yeon_17_networks  \
# 0  17Networks_LH_VisCent_ExStr_1                    VisCent
# 1  17Networks_LH_VisCent_ExStr_2                    VisCent
# 2  17Networks_LH_VisCent_ExStr_3                    VisCent
# 3  17Networks_LH_VisCent_ExStr_4                    VisCent
# 4  17Networks_LH_VisCent_ExStr_5                    VisCent
#
#   halfpipe_17_networks
# 0              VisCent
# 1              VisCent
# 2              VisCent
# 3              VisCent
# 4              VisCent

# %% [markdown]
# ##### Remove subcortical and cerebellar ROIs

# %%
print(f"{len(roi_names)} Schaefer, subcortical, and cerebellar ROIs")

roi_names = roi_names[:400]
print(f"{len(roi_names)} Schaefer ROIs")
print(f"Last ROIs: {roi_names[-5:]}")
# Out:
# 438 Schaefer, subcortical, and cerebellar ROIs
# 400 Schaefer ROIs
# Last ROIs: ['17Networks_RH_TempPar_6' '17Networks_RH_TempPar_7'
#  '17Networks_RH_TempPar_8' '17Networks_RH_TempPar_9'
#  '17Networks_RH_TempPar_10']

# %% [markdown]
# ##### Load the ROI list of the ENIGMA-OCD dataset

# %%
# File path
file_path = "/pscratch/sd/p/pakmasha/MBBN_data/Amsterdam-VUmc_sub-916002/Amsterdam-VUmc_sub-916002.tsv"

# Load the TSV file
data = pd.read_csv(file_path, sep="\t")

# Get the column names
column_names = data.columns.tolist()

# Print the column names
print("Column (ROI) names:", column_names)
print(f"Total of {len(column_names)} ROIs")
# Out:
# Column (ROI) names: ['17Networks_LH_VisCent_ExStr_1', '17Networks_LH_VisCent_ExStr_2', '17Networks_LH_VisCent_ExStr_4', '17Networks_LH_VisCent_ExStr_6', '17Networks_LH_VisCent_ExStr_7', '17Networks_LH_VisCent_ExStr_9', '17Networks_LH_VisCent_ExStr_11', '17Networks_LH_VisPeri_ExStrInf_1', '17Networks_LH_VisPeri_ExStrInf_2', '17Networks_LH_VisPeri_ExStr
ks_LH_SalVentAttnA_FrMed_1', '17Networks_LH_SalVentAttnA_FrMed_2', '17Networks_LH_SalVentAttnB_PFCl_1', '17Networks_LH_SalVentAttnB_PFCl_2', '17Networks_LH_SalVentAttnB_PFCl_3', '17Networks_LH_SalVentAttnB_Ins_1', '17Networks_LH_SalVentAttnB_Ins_2', '17Networks_LH_SalVentAttnB_Ins_3', '17Networks_LH_SalVentAttnB_PFCmp_1', '17Networks_LH_LimbicA_TempPole_7', '17Networks_LH_ContA_Temp_1', '17Networks_LH_ContA_IPS_1', '17Networks_LH_ContA_IPS_3', '17Networks_LH_ContA_IPS_4', '17Networks_LH_ContA_IPS_5', '17Networks_LH_ContA_PFCd_1', '17Networks_LH_ContA_PFClv_1', '17Networks_LH_ContA_PFClv_2', '17Networks_LH_ContA_PFCl_1', '17Networks_LH_ContA_PFCl_2', '17Networks_LH_ContA_PFCl_3', '17Networks_LH_ContA_Cingm_1', '17Networks_LH_ContB_IPL_1', '17Networks_LH_ContB_IPL_2', '17Networks_LH_ContB_IPL_3', '17Networks_LH_ContB_PFCd_1', '17Networks_LH_ContB_PFClv_2', '17Networks_LH_ContB_PFClv_3', '17Networks_LH_ContB_PFCmp_1', '17Networks_LH_ContC_pCun_1', '17Networks_LH_ContC_pCun_2', '17Networks_LH_ContC_pCun_3', '17Networks_LH_ContC_Cingp_1', '17Networks_LH_ContC_Cingp_2', '17Networks_LH_DefaultA_IPL_1', '17Networks_LH_DefaultA_PFCd_1', '17Networks_LH_DefaultA_PFCd_2', '17Networks_LH_DefaultA_PFCd_3', '17Networks_LH_DefaultA_pCunPCC_1', '17Networks_LH_DefaultA_pCunPCC_2', '17Networks_LH_DefaultA_pCunPCC_3 ...
# Total of 318 ROIs

# %% [markdown]
# ##### Identify indices of columns that should be removed (subcortical and cerebellar ROIs)

# %%
# Identify ROIs in column_names but not in roi_names
unmatched_rois = [roi for roi in column_names if roi not in roi_names]

# Get the indices of these unmatched ROIs in column_names
unmatched_indices = [i for i, roi in enumerate(column_names) if roi not in roi_names]

# Print the results
print("Unmatched ROIs (subcortical and cerebellar):", unmatched_rois)
print("Indices of unmatched ROIs:", unmatched_indices)
print(f"Total of {len(unmatched_rois)} unmatched ROIs")
# Out:
# Unmatched ROIs (subcortical and cerebellar): ['FreeSurfer_Left-Thalamus', 'FreeSurfer_Left-Caudate', 'FreeSurfer_Left-Putamen', 'FreeSurfer_Left-Pallidum', 'FreeSurfer_Left-Hippocampus', 'FreeSurfer_Right-Thalamus', 'FreeSurfer_Right-Caudate', 'FreeSurfer_Right-Putamen', 'FreeSurfer_Right-Pallidum', 'FreeSurfer_Right-Hippocampus', 'Buckner2011_17Networks_4']
# Indices of unmatched ROIs: [307, 308, 309, 310, 311, 312, 313, 314, 315, 316, 
Oper_3', '17Networks_LH_SalVentAttnA_Ins_1', '17Networks_LH_SalVentAttnA_Ins_2', '17Networks_LH_SalVentAttnA_Ins_3', '17Networks_LH_SalVentAttnA_Ins_4', '17Networks_LH_SalVentAttnA_FrOper_1', '17Networks_LH_SalVentAttnA_FrOper_2', '17Networks_LH_SalVentAttnA_ParMed_1', '17Networks_LH_SalVentAttnA_ParMed_2', '17Networks_LH_SalVentAttnA_ParMed_3', '17Networks_LH_SalVentAttnA_FrMed_1', '17Networks_LH_SalVentAttnA_FrMed_2', '17Networks_LH_SalVentAttnB_PFCl_1', '17Networks_LH_SalVentAttnB_PFCl_2', '17Networks_LH_SalVentAttnB_PFCl_3', '17Networks_LH_SalVentAttnB_Ins_1', '17Networks_LH_SalVentAttnB_Ins_2', '17Networks_LH_SalVentAttnB_Ins_3', '17Networks_LH_SalVentAttnB_PFCmp_1', '17Networks_LH_LimbicA_TempPole_7', '17Networks_LH_ContA_Temp_1', '17Networks_LH_ContA_IPS_1', '17Networks_LH_ContA_IPS_3', '17Networks_LH_ContA_IPS_4', '17Networks_LH_ContA_IPS_5', '17Networks_LH_ContA_PFCd_1', '17Networks_LH_ContA_PFClv_1', '17Networks_LH_ContA_PFClv_2', '17Networks_LH_ContA_PFCl_1', '17Networks_LH_ContA_PFCl_2', '17Networks_LH_ContA_PFCl_3', '17Networks_LH_ContA_Cingm_1', '17Networks_LH_ContB_IPL_1', '17Networks_LH_ContB_IPL_2', '17Networks_LH_ContB_IPL_3', '17Networks_LH_ContB_PFCd_1', '17Networks_LH_ContB_PFClv_2', '17Networks_LH_ContB_PFClv_3', '17Networks_LH_ContB_PFCmp_1', '17Networks_LH_ContC_pCun_1', '17Networks_LH_ContC_pCun_2', '17Networks_LH_ContC_pCun_3', '17Networks_LH_ContC_Cingp_1', '17Networks_LH_ContC_Cingp_2', '17Networks_LH_DefaultA_IPL_1', '17Networks_LH_DefaultA_PFCd_1', '17Networks_LH_DefaultA_PFCd_2', '17Networks_LH_DefaultA_PFCd_3', '17Networks_LH_DefaultA_pCunPCC_1', '17Networks_LH_DefaultA_pCunPCC_2', '17Networks_LH_DefaultA_pCunPC ...
# Total of 307 ROIs

# %% [markdown]
# ##### Identify indices of columns where zero-padding should be applied

# %%
# Get the indices in roi_names that are not in filtered_column_names
padding_indices = [i for i, roi in enumerate(roi_names) if roi not in filtered_column_names]

# Print the results
print("Indices for zero padding:", padding_indices)
print(f"Total of {len(padding_indices)} zero-padded ROIs")
# Out:
# Indices for zero padding: [2, 4, 6, 8, 10, 22, 26, 37, 39, 41, 42, 59, 61, 70, 71, 79, 80, 99, 106, 108, 109, 110, 111, 112, 113, 114, 115, 116, 117, 118, 122, 133, 134, 139, 149, 160, 161, 164, 166, 167, 168, 177, 178, 180, 183, 184, 191, 204, 205, 208, 210, 222, 238, 239, 240, 241, 242, 258, 259, 266, 271, 279, 280, 302, 312, 313, 314, 315, 316, 317, 318, 319, 320, 321, 322, 323, 335, 336, 338, 346, 347, 348, 357, 367, 368, 371, 373, 375, 379, 380, 385, 388, 390]
# Total of 93 zero-padded ROIs

# %% [markdown]
# ### Apply zero-padding and remove subcortical and cerebellar ROIs from MBBN_data files

# %%
# Paths and indices
base_path = "/pscratch/sd/p/pakmasha/MBBN_data"
target_num_rois = 400      # Total number of ROIs after padding

# Function to process and save the modified data
def process_data_file(tsv_file_path, output_dir):
    # Read the .tsv file into a DataFrame
    data = pd.read_csv(tsv_file_path, sep="\t")
    
    # Convert to a NumPy array
    data_array = data.to_numpy()  # Shape: [# of timepoints x # of ROIs]
    
    # Step 1: Remove ROIs corresponding to unmatched_indices
    filtered_data = np.delete(data_array, unmatched_indices, axis=1)  # Remove columns
    
    # Step 2: Add zero-padding at positions specified by padding_indices
    padded_data = np.zeros((filtered_data.shape[0], target_num_rois))  # Initialize padded array
    existing_indices = [i for i in range(target_num_rois) if i not in padding_indices]  # Indices for valid ROIs
    padded_data[:, existing_indices] = filtered_data  # Copy data to the padded array
    
    # Step 3: Save the modified data as a .npy file
    output_file_path = os.path.join(output_dir, os.path.basename(tsv_file_path).replace(".tsv", ".npy"))
    np.save(output_file_path, padded_data)
    print(f"Processed and saved: {output_file_path}")

# Walk through the subject folders and process .tsv files
for root, dirs, files in os.walk(base_path):
    for file in files:
        if file.endswith(".tsv"):
            tsv_file_path = os.path.join(root, file)
            process_data_file(tsv_file_path, root)
# Out:
# Processed and saved: /pscratch/sd/p/pakmasha/MBBN_data/Barcelona-HCPB_sub-008/Barcelona-HCPB_sub-008.npy
# Successfully processed Barcelona-HCPB_sub-008.tsv
# Processed and saved: /pscratch/sd/p/pakmasha/MBBN_data/Brazil_sub-C002061/Brazil_sub-C002061.npy
# Successfully processed Brazil_sub-C002061.tsv
# Processed and saved: /pscratch/sd/p/pakmasha/MBBN_data/Yale-Pittinger-HCP-Prisma_sub-YaleHCPPrismapb3225/Yale-Pittinger-HCP-Prisma_sub-YaleHCPPrismapb3225.npy
# Successfully processed Yale-Pittinger-HCP-Prisma_sub-YaleHCPPrismapb3225.tsv
# Processed and saved: /pscratch/sd/p/pakmasha/MBBN_data/Seoul-SNU_sub-NOR117CSJ/Seoul-SNU_sub-NOR117CSJ.npy
# Successfully processed Seoul-SNU_sub-NOR117CSJ.tsv
# Processed and saved: /pscratch/sd/p/pakmasha/MBBN_data/Dresden_sub-GEROME3073/Dresden_sub-GEROME3073.npy
# Successfully processed Dresden_sub-GEROME3073.tsv
# Processed and saved: /pscratch/sd/p/pakmasha/MBBN_data/Bergen_sub-00059/Bergen_sub-00059.npy
# Successfully processed Bergen_sub-00059.tsv
# Processed and saved: /pscratch/sd/p/pakmasha/MBBN_data/Bangalore-NIMHANS_sub-C0181/Bangalore-NIMHANS_sub-C0181.npy
# Successfully processed Bangalore-NIMHANS_sub-C0181.tsv
# Processed and saved: /pscratch/sd/p/pakmasha/MBBN_data/Bangalore-NIMHANS_sub-C0128/Bangalore-NIMHANS_sub-C0128.npy
# Successfully processed Bangalore-NIMHANS_sub-C0128.tsv
# Processed and saved: /pscratch/sd/p/pakmasha/MBBN_data/Seoul-SNU_sub-DNO23LSM/Seoul-SNU_sub-DNO23LSM.npy
# Successfully processed Seoul-SNU_sub-DNO23LSM.tsv
# Processed and saved: /pscratch/sd/p/pakmasha/MBBN_data/Bangalore-NIMHANS_sub-ODP004/Bangalore-NIMHANS_sub-ODP004.npy
# Successfully processed Bangalore-NIMHANS_sub-ODP004.tsv
# Processed and saved: /pscratch/sd/p/pakmasha/MBBN_data/Bangalore-NIMHANS_sub-ODP203/Bangalore-NIMHANS_sub-ODP203.npy
# Successfully processed Bangalore-NIMHANS_sub-ODP203.tsv
# Processed and saved: /pscratch/sd/p/pakmasha/MBBN_data/Barcelone-Bellvitge-PROV-1.5T_sub-subIDIBELL15224/Barcelone-Bellvitge-PROV-1.5T_sub-subIDIBELL15224.npy
# Successfully processed Barcelone-Bellvitge-PROV-1.5T_sub-subIDIBELL15224.tsv
# Processed and saved: /pscratch/sd/p/pakmasha/MBBN_data/Barcelone-Bellvitge-ANTIGA-1.5T_sub-subIDIBELL15C032/Barcelone-Bellvitge-ANTIGA-1.5T_sub-subIDIBELL15C032.npy
# Successfully processed Barcelone-Bellvitge-ANTIGA-1.5T_sub-subIDIBELL15C032.tsv
# Processed and saved: /pscratch/sd/p/pakmasha/MBBN_data/Bangalore-NIMHANS_sub-ODP099/Bangalore-NIMHANS_sub-ODP099.npy
# Successfully processed Bangalore-NIMHANS_sub-ODP099.tsv
# Processed and saved: /pscratch/sd/p/pakmasha/MBBN_data/Chiba-CHB_sub-MADHC010/Chiba-CHB_sub-MADHC010.npy
# Successfully processed Chiba-CHB_sub-MADHC010.tsv
# Processed and saved: /pscratch/sd/p/pakmasha/MBBN_data/Yale-Pittinger-Yale-2014_sub-Yale2014AdultOCDtr7977/Yale-Pittinger-Yale-2014_sub-Yale2014AdultOCDtr7977.npy
# Successfully processed Yale-Pittinger-Yale-2014_sub-Yale2014AdultOCDtr7977.tsv
# Processed and saved: /pscratch/sd/p/pakmasha/MBBN_data/Bergen_sub-00066/Bergen_sub-00066.npy
# Successfully processed Bergen_sub-00066.tsv
# Processed and saved: /pscratch/sd/p/pakmasha/MBBN_data/Yale-Pittinger-Yale-2014_sub-Yale2014AdultOCDtb0314/Yale-Pittinger-Yale-2014_sub-Yale2014AdultOCDtb0314.npy
# Successfully processed Yale-Pittinger-Yale-2014_sub-Yale2014AdultOCDtb0314.tsv
# Processed and saved: /pscratch/sd/p/pakmasha/MBBN_data/Barcelona-HCPB_sub-C0071/Barcelona-HCPB_sub-C0071.npy
# Successfully processed Barcelona-HCPB_sub-C0071.tsv
# Processed and saved: /pscratch/sd/p/pakmasha/MBBN_data/Barcelone-Bellvitge-ANTIGA-1.5T_sub-subIDIBELL15C042/Barcelone-Bellvitge-ANTIGA-1.5T_sub-subIDIBELL15C042.npy
# Successfully processed Barcelone-Bellvitge-ANTIGA-1.5T_sub-subIDIBELL15C042.tsv
# Processed and saved: /pscratch/sd/p/pakmasha/MBBN_data/Barcelona-HCPB_sub-042/Barcelona-HCPB_sub-042.npy
# Successfully processed Barcelona-HCPB_sub-042.tsv
# Processed and saved: /pscratch/sd/p/pakmasha/MBBN_data/Barcelone-Bellvitge-ANTIGA-1.5T_sub-subIDIBELL15P67/Barcelone-Bellvitge-ANTIGA-1.5T_sub-subIDIBELL15P67.npy
# Successfully processed Barcelone-Bellvitge-ANTIGA-1.5T_sub-subIDIBELL15P67.tsv
# Processed and saved: /pscratch/sd/p/pakmasha/MBBN_data/Braga-UMinho-Braga-3T_sub-MRI201905211BART003/Braga-UMinho-Braga-3T_sub-MRI201905211BART003.npy
# Successfully processed Braga-UMinho-Braga-3T_sub-MRI201905211BART003.tsv
# Processed and saved: /pscratch/sd/p/pakmasha/MBBN_data/Barcelone-Bellvitge-RESP-CBT-3T_sub-RESPCBT25CTRPOST/Barcelone-Bellvitge-RESP-CBT-3T_sub-RESPCBT25CTRPOST.npy
# Successfully processed Barcelone-Bellvitge-RESP-CBT-3T_sub-RESPCB
tsv
# Processed and saved: /pscratch/sd/p/pakmasha/MBBN_data/Shanghai-SMCH_sub-015/Shanghai-SMCH_sub-015.npy
# Successfully processed Shanghai-SMCH_sub-015.tsv
# Processed and saved: /pscratch/sd/p/pakmasha/MBBN_data/Vancouver-BCCHR_sub-072/Vancouver-BCCHR_sub-072.npy
# Successfully processed Vancouver-BCCHR_sub-072.tsv
# Processed and saved: /pscratch/sd/p/pakmasha/MBBN_data/Vancouver-BCCHR_sub-055/Vancouver-BCCHR_sub-055.npy
# Successfully processed Vancouver-BCCHR_sub-055.tsv
# Processed and saved: /pscratch/sd/p/pakmasha/MBBN_data/Yale-Gruner_sub-S8618ECE/Yale-Gruner_sub-S8618ECE.npy
# Successfully processed Yale-Gruner_sub-S8618ECE.tsv
# Processed and saved: /pscratch/sd/p/pakmasha/MBBN_data/Yale-Pittinger-Yale-2014_sub-Yale2014AdultOCDtr7733/Yale-Pittinger-Yale-2014_sub-Yale2014AdultOCDtr7733.npy
# Successfully processed Yale-Pittinger-Yale-2014_sub-Yale2014AdultOCDtr7733.tsv
# Processed and saved: /pscratch/sd/p/pakmasha/MBBN_data/Bangalore-NIMHANS_sub-ODP072/Bangalore-NIMHANS_sub-ODP072.npy
# Successfully processed Bangalore-NIMHANS_sub-ODP072.tsv
# Processed and saved: /pscratch/sd/p/pakmasha/MBBN_data/Bangalore-NIMHANS_sub-C0119/Bangalore-NIMHANS_sub-C0119.npy
# Successfully processed Bangalore-NIMHANS_sub-C0119.tsv
# Processed and saved: /pscratch/sd/p/pakmasha/MBBN_data/Braga-UMinho-Braga-1.5T-act_sub-MRI201303182OCD046/Braga-UMinho-Braga-1.5T-act_sub-MRI201303182OCD046.npy
# Successfully processed Braga-UMinho-Braga-1.5T-act_sub-MRI201303182OCD046.tsv
# Processed and saved: /pscratch/sd/p/pakmasha/MBBN_data/Bangalore-NIMHANS_sub-C0010/Bangalore-NIMHANS_sub-C0010.npy
# Successfully processed Bangalore-NIMHANS_sub-C0010.tsv
# Processed and saved: /pscratch/sd/p/pakmasha/MBBN_data/Bangalore-NIMHANS_sub-C0217/Bangalore-NIMHANS_sub-C0217.npy
# Successfully processed Bangalore-NIMHANS_sub-C0217.tsv
# Processed and saved: /pscratch/sd/p/pakmasha/MBBN_data/Barcelone-Bellvitge-RESP-CBT-3T_sub-RESPCBT28CTRPRE/Barcelone-Bellvitge-RESP-CBT-3T_sub-RESPCBT28CTRPRE.npy
# Successfully processed Barcelone-Bellvitge-RESP-CBT-3T_sub-RESPCBT28CTRPRE.tsv
# Processed and saved: /pscratch/sd/p/pakmasha/MBBN_data/Barcelone-Bellvitge-ANTIGA-1.5T_sub-subIDIBELL15C095/Barcelone-Bellvitge-ANTIGA-1.5T_sub-subIDIBELL15C095.npy
# Successfully processed Barcelone-Bellvitge-ANTIGA-1.5T_sub-subIDIBELL15C095.tsv
# Processed and saved: /pscratch/sd/p/pakmasha/MBBN_data/Bergen_sub-00013/Bergen_sub-00013.npy
# Successfully processed Bergen_sub-00013.tsv
# Processed and saved: /pscratch/sd/p/pakmasha/MBBN_data/Braga-UMinho-Braga-3T_sub-MRI20200717BART061/Braga-UMinho-Braga-3T_sub-MRI20200717BART061.npy
# Successfully processed Braga-UMinho-Braga-3T_sub-MRI20200717BART061.tsv
# Processed and saved: /pscratch/sd/p/pakmasha/MBBN_data/Shanghai-SMCH_sub-076/Shanghai-SMCH_sub-076.npy
# Successfully processed Shanghai-SMCH_sub-076.tsv
# Processed and saved: /pscratch/sd/p/pakmasha/MBBN_data/Barcelone-Bellvitge-ANTIGA-1.5T_sub-subIDIBELL15C003/Barcelone-Bellvitge-ANTIGA-1.5T_sub-subIDIBELL15C003.npy
# Successfully processed Barcelone-Bellvitge-ANTIGA-1.5T_sub-subIDIBELL15C003.tsv
# Processed and saved: /pscratch/sd/p/pakmasha/MBBN_data/Kyoto-KPU-Kyoto3T_sub-subKyoto3Tsubj0029/Kyoto-KPU-Kyoto3T_sub-subKyoto3Tsubj0029.npy
# Successfully processed Kyoto-KPU-Kyoto3T_sub-subKyoto3Tsubj0029.tsv
# Processed and saved: /pscratch/sd/p/pakmasha/MBBN_data/Vancouver-BCCHR_sub-061/Vancouver-BCCHR_sub-061.npy
# Successfully processed Vancouver-BCCHR_sub-061.tsv
# Processed and saved: /pscratch/sd/p/pakmasha/MBBN_data/Bergen_sub-00055/Bergen_sub-00055.npy
# Successfully processed Bergen_sub-00055.tsv

# %%
pad = 400 - 316

# Convert to PyTorch tensor
data_tensor = torch.from_numpy(file)

# Apply padding to the ROI dimension
padded_data = F.pad(data_tensor, (0, 0, pad // 2, pad // 2), "constant", 0)  # (time, time, ROI, ROI)

# Convert back to NumPy (optional)
padded_data_numpy = padded_data.numpy()

# %%
print(f"Before padding: {file[:,:1]}")
print(f"\nAfter padding: {padded_data_numpy[:,:1]}")
# Out:
# Before padding: [[ 1.53256367e+01]
#  [-6.17037989e+00]
#  [ 2.42531307e+00]
#  [ 2.25608207e+00]
#  [ 7.28538826e+00]
#  [ 5.72790600e-01]
#  [-1.46230566e+01]
#  [-1.26545591e+01]
#  [-2.74412824e+00]
#  [-1.97037792e+01]
#  [-1.17004657e+01]
#  [ 8.00839931e+00]
#  [ 6.95879902e+00]
#  [ 7.49275508e+00]
#  [ 3.25638599e+00]
#  [ 5.79628680e+00]
#  [-2.26465024e+00]
#  [ 1.14184302e+01]
#  [ 4.57214133e+00]
#  [-3.99674915e+00]
#  [-8.30907861e+00]
#  [ 2.64638379e+00]
#  [-3.63461737e+00]
#  [ 2.19149795e+01]
#  [-6.56320167e-01]
#  [-7.86497405e+00]
#  [-8.88970519e+00]
#  [ 1.10641103e+01]
#  [-1.21983270e+01]
#  [-1.20452727e+01]
#  [-5.17294042e+00]
#  [ 1.41164908e+00]
#  [ 1.16259915e+01]
#  [ 1.70307401e+01]
#  [ 3.89560206e+01]
#  [ 3.86261995e+00]
#  [ 2.31193925e+01]
#  [ 1.28329634e+01]
#  [ 4.54117720e+01]
#  [-2.43034122e+00]
#  [-1.19849922e+01]
#  [-1.15398425e+01]
#  [-3.88623797e+00]
#  [-2.23987900e+01]
#  [-7.81042165e+00]
#  [-1.60202959e+00]
#  [ 3.10054244e+00]
#  [ 6.02443375e+00]
#  [-5.82007802e+00]
#  [ 9.48546146e+00]
#  [ 6.60391618e-01]
#  [-3.52488825e+01]
#  [-3.92067010e+01]
#  [-3.04597554e+01]
#  [-2.36211414e+01]
#  [ 2.32021467e+01]
#  [ 2.11415074e+01]
#  [-1.53082843e+01]
#  [ 1.78449949e+01]
#  [ 5.07287742e+01]
#  [ 1.19647244e+01]
#  [ 1.76037500e+00]
#  [-3.43079032e+00]
#  [-1.84309173e+00]
#  [-1.24673743e+01]
#  [-2.81185550e+01]
#  [-3.06603364e+00]
#  [ 8.68653178e+00]
#  [ 2.25687919e+01]
#  [ 1.95928993e+01]
#  [-9.40956475e+00]
#  [ 2.49283980e+01]
#  [ 7.74234399e+00]
#  [ 4.86168858e+00]
#  [ 6.41500664e+00]
#  [ 9.06410998e+00]
#  [ 4.08348471e-01]
#  [-4.35177693e+00]
#  [-3.38838341e+00]
#  [-4.35324701e+00]
#  [ 4.84372046e+00]
#  [-3.54903953e-02]
#  [ 3.42094700e+00]
#  [-9.35843033e+00]
#  [ 3.98225188e+00]
#  [-2.07736447e+00]
#  [ 7.66925409e+00]
#  [ 2.85503060e+01]
#  [ 1.14438132e+01]
#  [ 1.60892651e+01]
#  [ 1.32251344e+01]
#  [-3.57617110e+01]
#  [ 4.28735766e+01]
#  [ 2.31821682e+01]
#  [-9.03566561e+00]
#  [-1.32252216e+00]
#  [ 1.83142748e+01]
#  [ 9.14098606e+00]
#  [ 8.98995283e+00]
#  [ 1.61021184e+01]
#  [ 1.26841945e+01]
#  [ 1.95166755e+01]
#  [ 4.94329175e+01]
#  [ 2.82087143e+01]
#  [ 1.49291925e+01]
#  [ 8.75480753e+00]
#  [ 4.24804023e-01]
#  [ 6.85730376e+00]
#  [ 3.31520830e+01]
#  [-6.66708040e+01]
#  [-3.69704748e+01]
#  [-8.89116030e+00]
#  [-7.51130078e+00]
#  [-2.71065501e+01]
#  [ 4.31846151e+01]
#  [-1.36570120e+01]
#  [ 1.96750486e+01]
#  [ 1.95104188e+01]
#  [-1.54571708e+01]
#  [ 5.73630929e+00]
#  [ 6.71535030e+00]
#  [-5.66393841e+00]
#  [ 3.19922364e+01]
#  [-2.50134639e+01]
#  [ 3.36880157e+01]
#  [ 7.19108759e+00]
#  [ 5.11709532e+00]
#  [ 4.09261887e+00]
#  [ 1.10070413e+01]
#  [ 2.95963450e+01]
#  [ 2.51881361e+01]
#  [ 3.31613483e+01]
#  [ 3.34332072e+01]
#  [ 3.51221095e+01]
#  [ 2.12212159e+01]
#  [ 3.22754612e+01]
#  [ 6.14884514e+00]
#  [ 2.03526845e+01]
#  [ 1.16428783e+01]
#  [ 7.10759969e+00]
#  [ 1.40598513e+01]
#  [ 1.44969229e+00]
#  [-2.66771722e+01]
#  [-4.90938840e+01]
#  [-3.66673360e+01]
#  [-2.44024745e+01]
#  [-7.60060962e+00]
#  [ 2.09000542e+01]
#  [ 1.66256208e+01]
#  [ 5.44241082e+00]
#  [ 2.64164577e+01]
#  [ 3.61152939e+01]
#  [ 2.95743295e+01]
#  [-1.24145225e+01]
#  [ 2.30527460e+00]
#  [-5.93202781e-01]
#  [ 2.38961062e+01]
#  [-4.38580011e+00]
#  [ 3.71588655e+00]
#  [-7.06175004e+00]
#  [ 1.29209941e+00]
#  [-1.25122131e+01]
#  [-1.61824757e+01]
#  [-1.11782653e+01]
#  [-1.22996872e+01]
#  [ 8.21027839e+00]
#  [-1.33531345e+00]
#  [ 1.23992493e+01]
#  [-2.82547425e+01]
#  [ 1.47565796e+00]
#  [-6.92635906e+00]
#  [-1.25242793e+01]
#  [-1.53676302e+01]
#  [-1.17631437e+01]
#  [ 5.11100651e+00]
#  [ 2.05285144e+00]
#  [-6.25646444e+00]
#  [-9.15118537e+00]
#  [ 7.48459982e+00]
#  [ 1.11936547e+01]
#  [ 6.60221738e+00]
#  [ 2.13359495e+01]
#  [-2.27616649e+01]
#  [ 1.94942806e+01]
#  [ 1.93928808e+01]
#  [ 2.66612038e+01]
#  [ 1.70322563e+01]
#  [ 2.55013002e+01]
#  [ 2.75804749e+00]
#  [-1.28893310e+01]
#  [ 1.35101643e+01]
#  [ 3.13986737e+01]
#  [ 1.72032170e+01]
#  [ 1.52550805e+00]
#  [ 1.31587263e+00]
#  [ 2.43450001e+01]
#  [ 6.28484146e+00]
#  [ 1.05063323e+01]
#  [ 1.45105302e-01]
#  [ 3.41721345e+00]
#  [ 8.59004744e+00]
#  [ 1.23363733e+01]
#  [ 7.91948555e+00]
#  [ 1.80505164e+01]
#  [ 2.54417650e+01]
#  [-5.59340877e+00]
#  [-1.09271786e+01]
#  [ 2.24442462e+01]
#  [ 9.00430020e+00]
#  [ 1.97550068e+01]
#  [ 9.32584568e+00]
#  [ 3.51954877e+01]
#  [ 1.57109164e+01]
#  [ 1.91282120e+01]
#  [ 1.61931735e+01]
#  [-2.36245364e+00]
#  [-7.69428392e+00]
#  [ 1.85419611e+00]
#  [-8.97016850e+00]
#  [ 7.61619810e+00]
#  [-6.36012475e+00]
#  [ 6.86501733e+00]
#  [ 2.01734670e+01]
#  [ 8.91354472e+00]
#  [ 1.47000711e+01]
#  [ 1.06751697e+01]
#  [ 2.60499429e+00]
#  [ 2.42381597e+01]
#  [ 3.08792289e+01]
#  [ 1.27240184e+01]
#  [ 9.96662474e+00]
#  [ 2.48287359e+01]
#  [ 5.23572049e+00]
#  [ 1.68177731e+01]
#  [-5.46103122e+00]
#  [ 2.74133510e+01]
#  [ 4.87454243e+00]
#  [ 1.04253462e+01]
#  [-1.51332983e+01]
#  [ 5.61963198e+00]
#  [ 4.29641531e+01]
#  [ 1.59206286e+01]
#  [ 5.81305773e-01]
#  [ 5.14193631e-01]
#  [-4.06071962e+00]
#  [ 1.38627649e+01]
#  [ 9.09013627e+00]
#  [ 6.54540840e-01]
#  [ 3.65481347e+01]
#  [ 4.29420717e+01]
#  [ 1.26858817e+01]
#  [ 8.59997218e+00]
#  [ 1.06108701e+01]
#  [ 3.64443877e+01]
#  [ 1.87151782e+01]
#  [ 1.71218881e+01]
#  [ 1.61590320e+01]
#  [ 1.40793419e+01]
#  [-1.12715183e+00]
#  [-1.88825850e+01]
#  [ 2.82282572e+01]
#  [ 2.45984636e+01]
#  [ 8.12687830e-01]
#  [-8.46960528e-01]
#  [ 2.56682790e+01]
#  [ 2.11916084e+01]
#  [ 1.12537104e+01]
#  [ 7.21860376e+00]
#  [-4.18212319e+01]
#  [-4.21545304e+01]
#  [-2.64513629e+01]
#  [ 1.76109495e+01]
#  [-1.67509988e+01]
#  [-2.17620973e+01]
#  [-3.32138015e+01]
#  [ 8.51448766e+00]
#  [ 2.80519044e+00]
#  [-4.24363056e+00]
#  [ 1.09519906e+01]
#  [ 2.45440798e+00]
#  [-5.21383884e+00]
#  [-1.03517908e+01]
#  [-9.51325964e+00]
#  [ 1.57319772e+01]
#  [-2.99905056e+00]
#  [-1.36573161e+00]
#  [ 1.41851466e+01]
#  [ 2.68476126e+01]
#  [ 1.74146115e-01]
#  [ 1.25709567e+01]
#  [-1.03315489e+01]
#  [ 1.12646183e+01]
#  [-7.64301410e-01]
#  [ 9.31814915e+00]
#  [ 1.24194152e+01]
#  [ 9.32641534e+00]
#  [-3.44442423e+01]
#  [-3.01731889e+01]
#  [-4.15829761e+00]
#  [ 3.15127111e+00]
#  [ 7.39480714e+00]
#  [ 1.30916529e+01]
#  [ 1.79830813e+01]
#  [ 3.90681279e+01]
#  [ 2.77388699e+01]
#  [ 8.53147478e+00]
#  [ 2.90593495e+00]
#  [ 1.09407910e+01]
#  [ 1.81326254e+01]
#  [ 7.10902930e+00]
#  [-4.10769275e+00]
#  [ 6.17098409e+00]
#  [ 1.31353848e+01]
#  [ 1.20871237e+01]
#  [-1.45124714e+00]
#  [-5.97838941e+00]]
#
# After padding: [[ 0.00000000e+00]
#  [ 0.00000000e+00]
#  [ 0.00000000e+00]
#  [ 0.00000000e+00]
#  [ 0.00000000e+00]
#  [ 0.00000000e+00]
#  [ 0.00000000e+00]
#  [ 0.00000000e+00]
#  [ 0.00000000e+00]
#  [ 0.00000000e+00]
#  [ 0.00000000e+00]
#  [ 0.00000000e+00]
#  [ 0.00000000e+00]
#  [ 0.00000000e+00]
#  [ 0.00000000e+00]
#  [ 0.00000000e+00]
#  [ 0.00000000e+00]
#  [ 0.00000000e+00]
#  [ 0.00000000e+00]
#  [ 0.00000000e+00]
#  [ 0.00000000e+00]
#  [ 0.00000000e+00]
#  [ 0.00000000e+00]
#  [ 0.00000000e+00]
#  [ 0.00000000e+00]
#  [ 0.00000000e+00]
#  [ 0.00000000e+00]
#  [ 0.00000000e+00]
#  [ 0.00000000e+00]
#  [ 0.00000000e+00]
#  [ 0.00000000e+00]
#  [ 0.00000000e+00]
#  [ 0.00000000e+00]
#  [ 0.00000000e+00]
#  [ 0.00000000e+00]
#  [ 0.00000000e+00]
#  [ 0.00000000e+00]
#  [ 0.00000000e+00]
#  [ 0.00000000e+00]
#  [ 0.00000000e+00]
#  [ 0.00000000e+00]
#  [ 0.00000000e+00]
#  [ 1.53256367e+01]
#  [-6.17037989e+00]
#  [ 2.42531307e+00]
#  [ 2.25608207e+00]
#  [ 7.28538826e+00]
#  [ 5.72790600e-01]
#  [-1.46230566e+01]
#  [-1.26545591e+01]
#  [-2.74412824e+00]
#  [-1.97037792e+01]
#  [-1.17004657e+01]
#  [ 8.00839931e+00]
#  [ 6.95879902e+00]
#  [ 7.49275508e+00]
#  [ 3.25638599e+00]
#  [ 5.79628680e+00]
#  [-2.26465024e+00]
#  [ 1.14184302e+01]
#  [ 4.57214133e+00]
#  [-3.99674915e+00]
#  [-8.30907861e+00]
#  [ 2.64638379e+00]
#  [-3.63461737e+00]
#  [ 2.19149795e+01]
#  [-6.56320167e-01]
#  [-7.86497405e+00]
#  [-8.88970519e+00]
#  [ 1.10641103e+01]
#  [-1.21983270e+01]
#  [-1.20452727e+01]
#  [-5.17294042e+00]
#  [ 1.41164908e+00]
#  [ 1.16259915e+01]
#  [ 1.70307401e+01]
#  [ 3.89560206e+01]
#  [ 3.86261995e+00]
#  [ 2.31193925e+01]
#  [ 1.28329634e+01]
#  [ 4.54117720e+01]
#  [-2.43034122e+00]
#  [-1.19849922e+01]
#  [-1.15398425e+01]
#  [-3.88623797e+00]
#  [-2.23987900e+01]
#  [-7.81042165e+00]
#  [-1.60202959e+00]
#  [ 3.10054244e+00]
#  [ 6.02443375e+00]
#  [-5.82007802e+00]
#  [ 9.48546146e+00]
#  [ 6.60391618e-01]
#  [-3.52488825e+01]
#  [-3.92067010e+01]
#  [-3.04597554e+01]
#  [-2.36211414e+01]
#  [ 2.32021467e+01]
#  [ 2.11415074e+01]
#  [-1.53082843e+01]
#  [ 1.78449949e+01]
#  [ 5.07287742e+01]
#  [ 1.19647244e+01]
#  [ 1.76037500e+00]
#  [-3.43079032e+00]
#  [-1.84309173e+00]
#  [-1.24673743e+01]
#  [-2.81185550e+01]
#  [-3.06603364e+00]
#  [ 8.68653178e+00]
#  [ 2.25687919e+01]
#  [ 1.95928993e+01]
#  [-9.40956475e+00]
#  [ 2.49283980e+01]
#  [ 7.74234399e+00]
#  [ 4.86168858e+00]
#  [ 6.41500664e+00]
#  [ 9.06410998e+00]
#  [ 4.08348471e-01]
#  [-4.35177693e+00]
#  [-3.38838341e+00]
#  [-4.35324701e+00]
#  [ 4.84372046e+00]
#  [-3.54903953e-02]
#  [ 3.42094700e+00]
#  [-9.35843033e+00]
#  [ 3.98225188e+00]
#  [-2.07736447e+00]
#  [ 7.66925409e+00]
#  [ 2.85503060e+01]
#  [ 1.14438132e+01]
#  [ 1.60892651e+01]
#  [ 1.32251344e+01]
#  [-3.57617110e+01]
#  [ 4.28735766e+01]
#  [ 2.31821682e+01]
#  [-9.03566561e+00]
#  [-1.32252216e+00]
#  [ 1.83142748e+01]
#  [ 9.14098606e+00]
#  [ 8.98995283e+00]
#  [ 1.61021184e+01]
#  [ 1.26841945e+01]
#  [ 1.95166755e+01]
#  [ 4.94329175e+01]
#  [ 2.82087143e+01]
#  [ 1.49291925e+01]
#  [ 8.75480753e+00]
#  [ 4.24804023e-01]
#  [ 6.85730376e+00]
#  [ 3.31520830e+01]
#  [-6.66708040e+01]
#  [-3.69704748e+01]
#  [-8.89116030e+00]
#  [-7.51130078e+00]
#  [-2.71065501e+01]
#  [ 4.31846151e+01]
#  [-1.36570120e+01]
#  [ 1.96750486e+01]
#  [ 1.95104188e+01]
#  [-1.54571708e+01]
#  [ 5.73630929e+00]
#  [ 6.71535030e+00]
#  [-5.66393841e+00]
#  [ 3.19922364e+01]
#  [-2.50134639e+01]
#  [ 3.36880157e+01]
#  [ 7.19108759e+00]
#  [ 5.11709532e+00]
#  [ 4.09261887e+00]
#  [ 1.10070413e+01]
#  [ 2.95963450e+01]
#  [ 2.51881361e+01]
#  [ 3.31613483e+01]
#  [ 3.34332072e+01]
#  [ 3.51221095e+01]
#  [ 2.12212159e+01]
#  [ 3.22754612e+01]
#  [ 6.14884514e+00]
#  [ 2.03526845e+01]
#  [ 1.16428783e+01]
#  [ 7.10759969e+00]
#  [ 1.40598513e+01]
#  [ 1.44969229e+00]
#  [-2.66771722e+01]
#  [-4.90938840e+01]
#  [-3.66673360e+01]
#  [-2.44024745e+01]
#  [-7.60060962e+00]
#  [ 2.09000542e+01]
#  [ 1.66256208e+01]
#  [ 5.44241082e+00]
#  [ 2.64164577e+01]
#  [ 3.61152939e+01]
#  [ 2.95743295e+01]
#  [-1.24145225e+01]
#  [ 2.30527460e+00]
#  [-5.93202781e-01]
#  [ 2.38961062e+01]
#  [-4.38580011e+00]
#  [ 3.71588655e+00]
#  [-7.06175004e+00]
#  [ 1.29209941e+00]
#  [-1.25122131e+01]
#  [-1.61824757e+01]
#  [-1.11782653e+01]
#  [-1.22996872e+01]
#  [ 8.21027839e+00]
#  [-1.33531345e+00]
#  [ 1.23992493e+01]
#  [-2.82547425e+01]
#  [ 1.47565796e+00]
#  [-6.92635906e+00]
#  [-1.25242793e+01]
#  [-1.53676302e+01]
#  [-1.17631437e+01]
#  [ 5.11100651e+00]
#  [ 2.05285144e+00]
#  [-6.25646444e+00]
#  [-9.15118537e+00]
#  [ 7.48459982e+00]
#  [ 1.11936547e+01]
#  [ 6.60221738e+00]
#  [ 2.13359495e+01]
#  [-2.27616649e+01]
#  [ 1.94942806e+01]
#  [ 1.93928808e+01]
#  [ 2.66612038e+01]
#  [ 1.70322563e+01]
#  [ 2.55013002e+01]
#  [ 2.75804749e+00]
#  [-1.28893310e+01]
#  [ 1.35101643e+01]
#  [ 3.13986737e+01]
#  [ 1.72032170e+01]
#  [ 1.52550805e+00]
#  [ 1.31587263e+00]
#  [ 2.43450001e+01]
#  [ 6.28484146e+00]
#  [ 1.05063323e+01]
#  [ 1.45105302e-01]
#  [ 3.41721345e+00]
#  [ 8.59004744e+00]
#  [ 1.23363733e+01]
#  [ 7.91948555e+00]
#  [ 1.80505164e+01]
#  [ 2.54417650e+01]
#  [-5.59340877e+00]
#  [-1.09271786e+01]
#  [ 2.24442462e+01]
#  [ 9.00430020e+00]
#  [ 1.97550068e+01]
#  [ 9.32584568e+00]
#  [ 3.51954877e+01]
#  [ 1.57109164e+01]
#  [ 1.91282120e+01]
#  [ 1.61931735e+01]
#  [-2.36245364e+00]
#  [-7.69428392e+00]
#  [ 1.85419611e+00]
#  [-8.97016850e+00]
#  [ 7.61619810e+00]
#  [-6.36012475e+00]
#  [ 6.86501733e+00]
#  [ 2.01734670e+01]
#  [ 8.91354472e+00]
#  [ 1.47000711e+01]
#  [ 1.06751697e+01]
#  [ 2.60499429e+00]
#  [ 2.42381597e+01]
#  [ 3.08792289e+01]
#  [ 1.27240184e+01]
#  [ 9.96662474e+00]
#  [ 2.48287359e+01]
#  [ 5.23572049e+00]
#  [ 1.68177731e+01]
#  [-5.46103122e+00]
#  [ 2.74133510e+01]
#  [ 4.87454243e+00]
#  [ 1.04253462e+01]
#  [-1.51332983e+01]
#  [ 5.61963198e+00]
#  [ 4.29641531e+01]
#  [ 1.59206286e+01]
#  [ 5.81305773e-01]
#  [ 5.14193631e-01]
#  [-4.06071962e+00]
#  [ 1.38627649e+01]
#  [ 9.09013627e+00]
#  [ 6.54540840e-01]
#  [ 3.65481347e+01]
#  [ 4.29420717e+01]
#  [ 1.26858817e+01]
#  [ 8.59997218e+00]
#  [ 1.06108701e+01]
#  [ 3.64443877e+01]
#  [ 1.87151782e+01]
#  [ 1.71218881e+01]
#  [ 1.61590320e+01]
#  [ 1.40793419e+01]
#  [-1.12715183e+00]
#  [-1.88825850e+01]
#  [ 2.82282572e+01]
#  [ 2.45984636e+01]
#  [ 8.12687830e-01]
#  [-8.46960528e-01]
#  [ 2.56682790e+01]
#  [ 2.11916084e+01]
#  [ 1.12537104e+01]
#  [ 7.21860376e+00]
#  [-4.18212319e+01]
#  [-4.21545304e+01]
#  [-2.64513629e+01]
#  [ 1.76109495e+01]
#  [-1.67509988e+01]
#  [-2.17620973e+01]
#  [-3.32138015e+01]
#  [ 8.51448766e+00]
#  [ 2.80519044e+00]
#  [-4.24363056e+00]
#  [ 1.09519906e+01]
#  [ 2.45440798e+00]
#  [-5.21383884e+00]
#  [-1.03517908e+01]
#  [-9.51325964e+00]
#  [ 1.57319772e+01]
#  [-2.99905056e+00]
#  [-1.36573161e+00]
#  [ 1.41851466e+01]
#  [ 2.68476126e+01]
#  [ 1.74146115e-01]
#  [ 1.25709567e+01]
#  [-1.03315489e+01]
#  [ 1.12646183e+01]
#  [-7.64301410e-01]
#  [ 9.31814915e+00]
#  [ 1.24194152e+01]
#  [ 9.32641534e+00]
#  [-3.44442423e+01]
#  [-3.01731889e+01]
#  [-4.15829761e+00]
#  [ 3.15127111e+00]
#  [ 7.39480714e+00]
#  [ 1.30916529e+01]
#  [ 1.79830813e+01]
#  [ 3.90681279e+01]
#  [ 2.77388699e+01]
#  [ 8.53147478e+00]
#  [ 2.90593495e+00]
#  [ 1.09407910e+01]
#  [ 1.81326254e+01]
#  [ 7.10902930e+00]
#  [-4.10769275e+00]
#  [ 6.17098409e+00]
#  [ 1.31353848e+01]
#  [ 1.20871237e+01]
#  [-1.45124714e+00]
#  [-5.97838941e+00]
#  [ 0.00000000e+00]
#  [ 0.00000000e+00]
#  [ 0.00000000e+00]
#  [ 0.00000000e+00]
#  [ 0.00000000e+00]
#  [ 0.00000000e+00]
#  [ 0.00000000e+00]
#  [ 0.00000000e+00]
#  [ 0.00000000e+00]
#  [ 0.00000000e+00]
#  [ 0.00000000e+00]
#  [ 0.00000000e+00]
#  [ 0.00000000e+00]
#  [ 0.00000000e+00]
#  [ 0.00000000e+00]
#  [ 0.00000000e+00]
#  [ 0.00000000e+00]
#  [ 0.00000000e+00]
#  [ 0.00000000e+00]
#  [ 0.00000000e+00]
#  [ 0.00000000e+00]
#  [ 0.00000000e+00]
#  [ 0.00000000e+00]
#  [ 0.00000000e+00]
#  [ 0.00000000e+00]
#  [ 0.00000000e+00]
#  [ 0.00000000e+00]
#  [ 0.00000000e+00]
#  [ 0.00000000e+00]
#  [ 0.00000000e+00]
#  [ 0.00000000e+00]
#  [ 0.00000000e+00]
#  [ 0.00000000e+00]
#  [ 0.00000000e+00]
#  [ 0.00000000e+00]
#  [ 0.00000000e+00]
#  [ 0.00000000e+00]
#  [ 0.00000000e+00]
#  [ 0.00000000e+00]
#  [ 0.00000000e+00]
#  [ 0.00000000e+00]
#  [ 0.00000000e+00]]

# %%
print(f"Before padding: {file.shape}")
print(f"\nAfter padding: {padded_data_numpy.shape}")
# Out:
# Before padding: (316, 100)
#
# After padding: (400, 100)
